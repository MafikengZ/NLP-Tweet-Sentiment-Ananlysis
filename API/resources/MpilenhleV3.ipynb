# %% [markdown]
# ## Overview
#
# Many companies are built around lessening one’s environmental impact or carbon footprint. They offer products and services that are environmentally friendly and sustainable, in line with their values and ideals. They would like to determine how people perceive climate change and whether or not they believe it is a real threat. This would add to their market research efforts in gauging how their product/service may be received.
#
# <img src="https://github.com/MafikengZ/NLP-Tweet-Sentiment-Ananlysis/blob/main/API/resources/imgs/worl.jpg?raw=true" width=75%/>
#
# With this context, EDSA is challenging you during the Classification Sprint with the task of creating a Machine Learning model that is able to classify whether or not a person believes in climate change, based on their novel tweet data.
#
# Providing an accurate and robust solution to this task gives companies access to a broad base of consumer sentiment, spanning multiple demographic and geographic categories - thus increasing their insights and informing future marketing strategies.
#
#
#
#
# The structure of this notebook is as follows:
#
#  - First, we'll load our data to get a view of the predictor and response variables we will be modeling.
#
#  - We'll then preprocess our data, cleaning or removing unwanted charecters such as `Hashtags #` `RT` `@ mentions` `urls` `emojis`.
#
#  - We'll then preprocess our data, Normalising the tokens in the tweets using processes such as  `Stemming` `Lemmatizing`.
#
#  - We'll then preprocess our data, vectorise the tweets and splitting up the data into train and test sets.
#
#  - We then model our data using a various models `SVC` `Naive Bayes` `Linear Logistics` of course using the multiclass options for some.
#
#  - Following this modeling, we use the f1 score from the charts.
#
#  - Using this metric, we then take several steps to improve our base model's performance by optimising the hyperparameters of the model through a `grid search strategy` , then use the `K best` for best feature selection

# %%
# import relevant libraries
import nltk
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd

from textblob import TextBlob
from wordcloud import WordCloud

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
pd.set_option('display.max_rows', 100)
from sklearn.utils import resample
from sklearn.pipeline import Pipeline


from nltk.corpus import stopwords
from sklearn.metrics import classification_report

# set plot style
# Style
import matplotlib.style as style 
sns.set(font_scale=1.5)
style.use('seaborn-pastel')
style.use('seaborn-poster')
from PIL import Image
from wordcloud import WordCloud

# %% [markdown]
# # Loading the data
#
# getting the kaggle data from git hub repo

# %%
# Loading Data
df_train = pd.read_csv('https://raw.githubusercontent.com/MafikengZ/NLP-Tweet-Sentiment-Ananlysis/main/data/train.csv')
df_test = pd.read_csv('https://raw.githubusercontent.com/MafikengZ/NLP-Tweet-Sentiment-Ananlysis/main/data/test.csv')

# %% [markdown]
# ## The Dataset
#
# Data The collection of this data was funded by a Canada Foundation for Innovation JELF Grant to Chris Bauch, University of Waterloo. The dataset aggregates tweets pertaining to climate change collected between Apr 27, 2015 and Feb 21, 2018. In total, 43943 tweets were collected. Each tweet is labelled as one of the following classes:
# ## Class description:
#
#  - 0 -->  Neutral: the tweet neither supports nor refutes the belief of man-made climate change
#  - 1 -->  Pro: the tweet supports the belief of man-made climate change
#  - 2 -->  News: the tweet links to factual news about climate change
#  - -1 --> Anti: the tweet does not believe in man-made climate change
#
#
# ## Columns of the training data:
# This dataset consists of the following Columns:
#
#  - sentiments --> the sentiment the tweet falls in positive / Negative
#  - message    --> the tweet messages from tweet
#  - tweetid    --> the unique  id every tweeted tweet gets

# %% [markdown]
# ## Looking at the Train and Test data frames

# %%
# looking at the data
df_train.head()
# Out:
#    sentiment                                            message  tweetid
# 0          1  PolySciMajor EPA chief doesn't think carbon di...   625221
# 1          1  It's not like we lack evidence of anthropogeni...   126103
# 2          2  RT @RawStory: Researchers say we have three ye...   698562
# 3          1  #TodayinMaker# WIRED : 2016 was a pivotal year...   573736
# 4          1  RT @SoyNovioDeTodas: It's 2016, and a racist, ...   466954

# %%
df_test.head()
# Out:
#                                              message  tweetid
# 0  Europe will now be looking to China to make su...   169760
# 1  Combine this with the polling of staffers re c...    35326
# 2  The scary, unimpeachable evidence that climate...   224985
# 3  @Karoli @morgfair @OsborneInk @dailykos \nPuti...   476263
# 4  RT @FakeWillMoore: 'Female orgasms cause globa...   872928

# %% [markdown]
# # Data distribution of classes
#
#  By looking at the value count of classes we suddenly see imbalance in the data

# %%
labels = ['Pro', 'News', 'Neutral', 'Anti'] 

# Get all possible labels
plt.bar(labels,df_train['sentiment'].value_counts() ,color='green')
plt.xticks(labels, ['Pro', 'News', 'Neutral', 'Anti'] )
plt.ylabel("# of observations")
plt.show()

# %% [markdown]
# # Data Cleaning
# The tweets have a lot of charecters that might cause noise in our data, with the use of regualr expressions we can remove those charecters which include:
#  - Hashtags
#  - RT for retweets
#  - @ for mentions
#  - url webs
#  - emojis
#  - digits
#  - spelling charecters eg. ã¢â‚¬â¦
#
# By removing these charecters we atrying to remove words that do not make sense for the model, the lesser the noise the more precise the results we are getting, this is also done to avoid learning wrong patterns from the data

# %%
                        """
                        The function uses some of the functions remove_emoji() which removes
                        emojis in a tweet
                        it also uses the function remove_punctuation() which removes
                        punctuations

                        The function data_cleaner() implements both these functions to make a 
                        clean data frame, with the use of the regular expressions it removes
                        noise or unwanted charecters in the tweets


                        """

import string
import re
#creating a function for removing emojis
def remove_emoji(string):
    emoji_pattern = re.compile("[" 
                u"\U0001F600-\U0001F64F"  # emoticons
                u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                u"\U0001F680-\U0001F6FF"  # transport & map symbols
                u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                u"\U00002702-\U000027B0"
                u"\U000024C2-\U0001F251"
                u"\U0001f926-\U0001f937"
                u'\U00010000-\U0010ffff'
                u"\u200d"
                u"\u2640-\u2642"
                u"\u2600-\u2B55"
                u"\u23cf"
                u"\u23e9"
                u"\u231a"
                u"\u3030"
                u"\ufe0f"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)


# punctuation remover function
def remove_punctuation(tweets):
    return ''.join([l for l in tweets if l not in string.punctuation])



def data_cleaner(df, column):
    
    # turn all to lower
    df[column] = df[column].str.lower()
    #remmoving the urls
    
    pattern_url = r'http[s]?://[A-Za-z0-9/.]+'
    subs_url = r'url-web'
    df[column] = df[column].replace(to_replace = pattern_url, value = subs_url, regex = True)
    
    #remmoving the Re Tweets 
    pattern_url = r'rt\s'
    subs_url = r''
    df[column] = df[column].replace(to_replace = pattern_url, value = subs_url, regex = True)
    

    #remmoving the mentions 
    pattern_url = r'@'
    subs_url = r''
    df[column] = df[column].replace(to_replace = pattern_url, value = subs_url, regex = True)


    #remmoving the Hashtags 
    pattern_url = r'\#'
    subs_url = r''
    df[column] = df[column].replace(to_replace = pattern_url, value = subs_url, regex = True)
    

    #remmoving the remaining https
    pattern_url = r'https:[.*?]+'
    subs_url = r''
    df[column] = df[column].replace(to_replace = pattern_url, value = subs_url, regex = True)

    #remmoving the digits
    pattern_url = r'\d'
    subs_url = r''
    df[column] = df[column].replace(to_replace = pattern_url, value = subs_url, regex = True)

    # using apply method to remove the punctuation marks
    df[column] = df[column].apply(remove_punctuation)
    
    # Removing the emojis using the apply method
    df[column] = df[column].apply(remove_emoji)
    
    #remmoving the uknown charecters from words
    pattern_url = r'[^A-Za-z ]'
    subs_url = r''
    df[column] = df[column].replace(to_replace = pattern_url, value = subs_url, regex = True)
    
    
    return df

# %% [markdown]
# Applying the `data_cleaner` function to clean both the training and testing

# %%
# Call the function data_cleaner() and clean the training data frame 
clean_df_train = data_cleaner(df_train, 'message')

# %%
# Call the function data_cleaner and clean the testing data frame 
clean_df_test = data_cleaner(df_test, 'message')

# %% [markdown]
# ## Looking at the clean Tweets Data frames
# both the Training and Testing data frames are cleaned

# %%
# looking at the clean training data
clean_df_train
# Out:
#        sentiment                                            message  tweetid
# 0              1  polyscimajor epa chief doesnt think carbon dio...   625221
# 1              1  its not like we lack evidence of anthropogenic...   126103
# 2              2  rawstory researchers say we have three years t...   698562
# 3              1  todayinmaker wired   was a pivotal year in the...   573736
# 4              1  soynoviodetodas its  and a racist sexist clima...   466954
# ...          ...                                                ...      ...
# 15814          1  ezlusztig they took down the material on globa...    22001
# 15815          2  washingtonpost how climate change could be bre...    17856
# 15816          0  notiven rt nytimesworld what does trump actual...   384248
# 15817         -1  sarasmiles hey liberals the climate change cra...   819732
# 15818          0  chetcannon kurteichenwalds climate change equa...   806319
#
# [15819 rows x 3 columns]

# %%
# looking at the clean testing data
clean_df_test
# Out:
#                                                  message  tweetid
# 0      europe will now be looking to china to make su...   169760
# 1      combine this with the polling of staffers re c...    35326
# 2      the scary unimpeachable evidence that climate ...   224985
# 3      karoli morgfair osborneink dailykos putin got ...   476263
# 4      fakewillmoore female orgasms cause global warm...   872928
# ...                                                  ...      ...
# 10541  brittanybohrer brb writing a poem about climat...   895714
# 10542   the year climate change came home during the ...   875167
# 10543  loopvanuatu pacific countries positive about f...    78329
# 10544  xanria youre so hot you must be the cause for ...   867455
# 10545  chloebalaoing climate change is a global issue...   470892
#
# [10546 rows x 2 columns]

# %% [markdown]
# # Data Normalization
#
# The tweets have a lot of words that might mean the same thing but depending on the grammar of the language the word can be used to describe a state or a doing ability of someone e.g coded, code and coder, mean the same thing code and that is what we want the machine to learn rather than letting it learn them as different words. There are two precesses used here the lemma and stemmer and the original words as they are, the choice of the word normalization technique will depend on the perfomance of that column, we are going to create a column for each normalization technique used and for the original words. The columns are:
#
#
#   - tokens --> the tokens columns
#   - token_no_stop_word --> tokens with no dictionary stopwords
#   - lemma --> lemmatized tokens from the column token_no_stop_word
#   - stem --> stemmed tokens from the column token_no_stop_word
#   - clean_sentences --> original tokens column joined to form a sentence
#   - stem_clean_sentences --> stem tokens column joined to form a sentence
#   - lemma_clean_sentences --> lemma tokens column joined to form a sentence
#
#
# Using the following functions we are able to create a column for each normalization techniques done on each word,
# and thus can investigate each perfomance, all the columns will not have stop words.

# %%
            """
                Pre processing the data by creating new columns each with feature
                normalization technique applied, the use of outer functions also help
                in cleaning and removing the stop words
                first tokenise tweets
                then remove stop words
                we then lemmatize the tokens
                we then stem the words
                we finally join the tokens to form a sentence
                
                all this is done by creating a new column for each technique used
            """



# importing tokenizing library
from nltk.tokenize import word_tokenize, TreebankWordTokenizer
from nltk.stem import WordNetLemmatizer
#importing stemmer library
from nltk import SnowballStemmer
#importing stemmer library
from nltk import SnowballStemmer



# lemmatizing function
lemmatizer = WordNetLemmatizer()
def tweet_lemma(words, lemmatizer):
    return [lemmatizer.lemmatize(word) for word in words]    

#Stemmer function
stemmer = SnowballStemmer('english')
def token_stemmer(words, stemmer):
    return [stemmer.stem(word) for word in words]


# remove the stop words in the tokens
def remove_stop_words(tokens):    
    return [t for t in tokens if t not in stopwords.words('english')]

def token_lemmatizer_stemmer(df):
    
    #tokenise the tweets and create a column of tokens
    tokeniser = TreebankWordTokenizer()
    df['tokens'] = df['message'].apply(tokeniser.tokenize)
    
     # Remove stop words first 
    df['token_no_stop_word'] = df['tokens'].apply(remove_stop_words)
    
    # Remove stop words first
    df['lemma'] = df['token_no_stop_word'].apply(tweet_lemma, args=(lemmatizer, ))
    
    # Remove stop words first
    df['stem'] = df['token_no_stop_word'].apply(token_stemmer, args=(stemmer, ))
    
    # join the tokens to form a sentence
    clean_sentences = [" ".join(i) for i in df['token_no_stop_word']]
    df['clean_sentences'] = clean_sentences
    
    # join the stemmed tokens to form a sentence
    stem_clean_sentences = [" ".join(i) for i in df['stem']]
    df['stem_clean_sentences'] = stem_clean_sentences
    
    
    # creating polarity list
    df['polarity'] = [TextBlob(tweet_text).sentiment[0] for tweet_text in df['message']]

    # creating subjectivity list
    df['subjectivity'] = [TextBlob(tweet_text).sentiment[1] for tweet_text in df['message']]
    
    # join the lemma tokens to form a sentence
    lemma_clean_sentences = [" ".join(i) for i in df['lemma']]
    df['lemma_clean_sentences'] = lemma_clean_sentences
    
    
    
    return df

# %%
# getting the processed for training data
processed_df_train = token_lemmatizer_stemmer(clean_df_train)
processed_df_train.head()
# Out:
#    sentiment                                            message  tweetid  \
# 0          1  polyscimajor epa chief doesnt think carbon dio...   625221
# 1          1  its not like we lack evidence of anthropogenic...   126103
# 2          2  rawstory researchers say we have three years t...   698562
# 3          1  todayinmaker wired   was a pivotal year in the...   573736
# 4          1  soynoviodetodas its  and a racist sexist clima...   466954
#
#                                               tokens  \
# 0  [polyscimajor, epa, chief, doesnt, think, carb...
# 1  [its, not, like, we, lack, evidence, of, anthr...
# 2  [rawstory, researchers, say, we, have, three, ...
# 3  [todayinmaker, wired, was, a, pivotal, year, i...
# 4  [soynoviodetodas, its, and, a, racist, sexist,...
#
#                                   token_no_stop_word  \
# 0  [polyscimajor, epa, chief, doesnt, think, carb...
# 1  [like, lack, evidence, anthropogenic, global, ...
# 2  [rawstory, researchers, say, three, years, act...
# 3  [todayinmaker, wired, pivotal, year, war, clim...
# 4  [soynoviodetodas, racist, sexist, climate, cha...
#
#                                                lemma  \
# 0  [polyscimajor, epa, chief, doesnt, think, carb...
# 1  [like, lack, evidence, anthropogenic, global, ...
# 2  [rawstory, researcher, say, three, year, act, ...
# 3  [todayinmaker, wired, pivotal, year, war, clim...
# 4  [soynoviodetodas, racist, sexist, climate, cha...
#
#                                                 stem  \
# 0  [polyscimajor, epa, chief, doesnt, think, carb...
# 1      [like, lack, evid, anthropogen, global, warm]
# 2  [rawstori, research, say, three, year, act, cl...
# 3  [todayinmak, wire, pivot, year, war, climat, c...
# 4  [soynoviodetoda, racist, sexist, climat, chang...
#
#                                      clean_sentences  \
# 0  polyscimajor epa chief doesnt think carbon dio...
# 1    like lack evidence anthropogenic global warming
# 2  rawstory researchers say three years act clima...
# 3  todayinmaker wired pivotal year war climate ch...
# 4  soynoviodetodas racist sexist climate change d...
#
#                                 stem_clean_sentences  polarity  subjectivity  \
# 0  polyscimajor epa chief doesnt think carbon dio...  0.083333      0.166667
# 1             like lack evid anthropogen global warm  0.000000      0.000000
# 2  rawstori research say three year act climat ch... -0.300000      0.600000
# 3  todayinmak wire pivot year war climat chang ur...  0.500000      0.800000
# 4  soynoviodetoda racist sexist climat chang deni...  0.000000      0.000000
#
#                                lemma_clean_sentences
# 0  polyscimajor epa chief doesnt think carbon dio...
# 1    like lack evidence anthropogenic global warming
# 2  rawstory researcher say three year act climate...
# 3  todayinmaker wired pivotal year war climate ch...
# 4  soynoviodetodas racist sexist climate change d...

# %%
processed_df_train.head(5)
# Out:
#    sentiment                                            message  tweetid  \
# 0          1  PolySciMajor EPA chief doesnt think carbon dio...   625221
# 1          1  Its not like we lack evidence of anthropogenic...   126103
# 2          2  RawStory Researchers say we have three years t...   698562
# 3          1  TodayinMaker WIRED   was a pivotal year in the...   573736
# 4          1  SoyNovioDeTodas Its  and a racist sexist clima...   466954
#
#                                               tokens  \
# 0  [PolySciMajor, EPA, chief, doesnt, think, carb...
# 1  [Its, not, like, we, lack, evidence, of, anthr...
# 2  [RawStory, Researchers, say, we, have, three, ...
# 3  [TodayinMaker, WIRED, was, a, pivotal, year, i...
# 4  [SoyNovioDeTodas, Its, and, a, racist, sexist,...
#
#                                   token_no_stop_word  \
# 0  [PolySciMajor, EPA, chief, doesnt, think, carb...
# 1  [Its, like, lack, evidence, anthropogenic, glo...
# 2  [RawStory, Researchers, say, three, years, act...
# 3  [TodayinMaker, WIRED, pivotal, year, war, clim...
# 4  [SoyNovioDeTodas, Its, racist, sexist, climate...
#
#                                                lemma  \
# 0  [PolySciMajor, EPA, chief, doesnt, think, carb...
# 1  [Its, like, lack, evidence, anthropogenic, glo...
# 2  [RawStory, Researchers, say, three, year, act,...
# 3  [TodayinMaker, WIRED, pivotal, year, war, clim...
# 4  [SoyNovioDeTodas, Its, racist, sexist, climate...
#
#                                                 stem  \
# 0  [polyscimajor, epa, chief, doesnt, think, carb...
# 1  [it, like, lack, evid, anthropogen, global, warm]
# 2  [rawstori, research, say, three, year, act, cl...
# 3  [todayinmak, wire, pivot, year, war, climat, c...
# 4  [soynoviodetoda, it, racist, sexist, climat, c...
#
#                                      clean_sentences  \
# 0  PolySciMajor EPA chief doesnt think carbon dio...
# 1  Its like lack evidence anthropogenic global wa...
# 2  RawStory Researchers say three years act clima...
# 3  TodayinMaker WIRED pivotal year war climate ch...
# 4  SoyNovioDeTodas Its racist sexist climate chan...
#
#                                 stem_clean_sentences  polarity  subjectivity  \
# 0  polyscimajor epa chief doesnt think carbon dio...  0.083333      0.166667
# 1          it like lack evid anthropogen global warm  0.000000      0.000000
# 2  rawstori research say three year act climat ch... -0.300000      0.600000
# 3  todayinmak wire pivot year war climat chang ur...  0.500000      0.800000
# 4  soynoviodetoda it racist sexist climat chang d...  0.000000      0.000000
#
#                                lemma_clean_sentences
# 0  PolySciMajor EPA chief doesnt think carbon dio...
# 1  Its like lack evidence anthropogenic global wa...
# 2  RawStory Researchers say three year act climat...
# 3  TodayinMaker WIRED pivotal year war climate ch...
# 4  SoyNovioDeTodas Its racist sexist climate chan...

# %%
# getting the processed columns for testing data
processed_df_test = token_lemmatizer_stemmer(clean_df_test)
processed_df_test.head()
# Out:
#                                              message  tweetid  \
# 0  europe will now be looking to china to make su...   169760
# 1  combine this with the polling of staffers re c...    35326
# 2  the scary unimpeachable evidence that climate ...   224985
# 3  karoli morgfair osborneink dailykos putin got ...   476263
# 4  fakewillmoore female orgasms cause global warm...   872928
#
#                                               tokens  \
# 0  [europe, will, now, be, looking, to, china, to...
# 1  [combine, this, with, the, polling, of, staffe...
# 2  [the, scary, unimpeachable, evidence, that, cl...
# 3  [karoli, morgfair, osborneink, dailykos, putin...
# 4  [fakewillmoore, female, orgasms, cause, global...
#
#                                   token_no_stop_word  \
# 0  [europe, looking, china, make, sure, alone, fi...
# 1  [combine, polling, staffers, climate, change, ...
# 2  [scary, unimpeachable, evidence, climate, chan...
# 3  [karoli, morgfair, osborneink, dailykos, putin...
# 4  [fakewillmoore, female, orgasms, cause, global...
#
#                                                lemma  \
# 0  [europe, looking, china, make, sure, alone, fi...
# 1  [combine, polling, staffer, climate, change, w...
# 2  [scary, unimpeachable, evidence, climate, chan...
# 3  [karoli, morgfair, osborneink, dailykos, putin...
# 4  [fakewillmoore, female, orgasm, cause, global,...
#
#                                                 stem  \
# 0  [europ, look, china, make, sure, alon, fight, ...
# 1  [combin, poll, staffer, climat, chang, women, ...
# 2  [scari, unimpeach, evid, climat, chang, alread...
# 3  [karoli, morgfair, osborneink, dailyko, putin,...
# 4  [fakewillmoor, femal, orgasm, caus, global, wa...
#
#                                      clean_sentences  \
# 0  europe looking china make sure alone fighting ...
# 1  combine polling staffers climate change womens...
# 2  scary unimpeachable evidence climate change al...
# 3  karoli morgfair osborneink dailykos putin got ...
# 4  fakewillmoore female orgasms cause global warm...
#
#                                 stem_clean_sentences  polarity  subjectivity  \
# 0  europ look china make sure alon fight climat c...       0.5      0.888889
# 1  combin poll staffer climat chang women right f...       0.0      0.000000
# 2  scari unimpeach evid climat chang alreadi urlw...      -0.5      1.000000
# 3  karoli morgfair osborneink dailyko putin got j...       0.0      0.000000
# 4  fakewillmoor femal orgasm caus global warmings...       0.0      0.083333
#
#                                lemma_clean_sentences
# 0  europe looking china make sure alone fighting ...
# 1  combine polling staffer climate change woman r...
# 2  scary unimpeachable evidence climate change al...
# 3  karoli morgfair osborneink dailykos putin got ...
# 4  fakewillmoore female orgasm cause global warmi...

# %% [markdown]
# # Exploratory Data Analysis
#
# Looking at the token lengths and the number of times a token appears in a text can help us extract those tokens that do not add value to the model prediction

# %%
def bag_of_words_count(words, word_dict={}):
    """ this function takes in a list of words and returns a dictionary 
        with each word as a key, and the value represents the number of 
        times that word appeared"""
    for word in words:
        if word in word_dict.keys():
            word_dict[word] += 1
        else:
            word_dict[word] = 1
    return word_dict

# %%
type_labels = processed_df_train.sentiment.unique()
type_labels
# Out:
# array([ 1,  2,  0, -1], dtype=int64)

# %%
beliver = {}
for pp in type_labels:
    df_label = processed_df_train.groupby('sentiment')
    beliver[pp] = {}
    for row in df_label.get_group(pp)['token_no_stop_word']:
        beliver[pp] = bag_of_words_count(row, beliver[pp])

# %%
beliver
# Out:
# {1: {'polyscimajor': 1,
#   'epa': 271,
#   'chief': 66,
#   'doesnt': 785,
#   'think': 236,
#   'carbon': 98,
#   'dioxide': 35,
#   'main': 25,
#   'cause': 108,
#   'global': 1593,
#   'warming': 1430,
#   'wait': 25,
#   'urlweb': 4014,
#   'via': 199,
#   'mashable': 19,
#   'like': 310,
#   'lack': 15,
#   'evidence': 74,
#   'anthropogenic': 10,
#   'todayinmaker': 1,
#   'wired': 14,
#   'pivotal': 3,
#   'year': 84,
#   'war': 60,
#   'climate': 7340,
#   'change': 7077,
#   'soynoviodetodas': 1,
#   'racist': 31,
#   'sexist': 12,
#   'denying': 120,
#   'bigot': 6,
#   'leading': 60,
#   'polls': 4,
#   'electionnight': 8,
#   'worth': 12,
#   'read': 70,
#   'whether': 34,
#   'dont': 386,
#   'believe': 1004,
#   'thenation': 2,
#   'mike': 8,
#   'pence': 10,
#   'smoking': 5,
#   'causes': 40,
#   'lung': 1,
#   'cancer': 3,
#   'makeandmendlife': 1,
#   'six': 11,
#   'big': 88,
#   'things': 78,
#   'today': 107,
#   'fight': 286,
#   'activist': 4,
#   'h': 29,
#   'aceofspadeshq': 1,
#   'yo': 11,
#   'nephew': 1,
#   'inconsolable': 1,
#   'wants': 70,
#   'die': 394,
#   'old': 48,
#   'age': 33,
#   'perish': 1,
#   'fiery': 1,
#   'hellscape': 1,
#   'paigetweedy': 1,
#   'offense': 3,
#   'stephenschlegel': 307,
#   'shes': 627,
#   'thinking': 338,
#   'going': 590,
#   'husband': 312,
#   'hope': 72,
#   'people': 454,
#   'vocal': 1,
#   'also': 117,
#   'powering': 1,
#   'homes': 4,
#   'renewable': 24,
#   'energy': 113,
#   'goodenergy': 2,
#   'alifaith': 1,
#   'oh': 29,
#   'godtrumps': 1,
#   'government': 66,
#   'removes': 4,
#   'page': 22,
#   'website': 41,
#   'hours': 3,
#   'ahead': 9,
#   'climatemarchurlweb': 1,
#   'glblctzn': 6,
#   'wan': 27,
#   'na': 66,
#   'live': 35,
#   'forever': 1,
#   'nothing': 55,
#   'taylorswift': 1,
#   'zaynmalik': 1,
#   'jackholmes': 1,
#   'issues': 49,
#   'scrubbed': 1,
#   'civil': 13,
#   'rights': 82,
#   'lgbt': 25,
#   'healthcare': 23,
#   'patagonia': 6,
#   'elected': 70,
#   'leaders': 46,
#   'fail': 13,
#   'approach': 18,
#   'environment': 108,
#   'amp': 659,
#   'serious': 47,
#   'worthy': 5,
#   'urgency': 10,
#   'action': 201,
#   'wi': 13,
#   'sensanders': 248,
#   'presidentelect': 193,
#   'millions': 154,
#   'say': 246,
#   'mr': 151,
#   'ccities': 21,
#   'c': 57,
#   'mayors': 6,
#   'representing': 3,
#   'citizens': 16,
#   'urged': 1,
#   'g': 22,
#   'saveourplanet': 1,
#   'worldwildlife': 10,
#   'impacts': 73,
#   'wildlife': 12,
#   'cop': 83,
#   'earthtomarrakech': 9,
#   'urlwebscientists': 1,
#   'wiped': 5,
#   'entire': 31,
#   'underwater': 15,
#   'ecosystem': 8,
#   'againclimate': 1,
#   'tammygrubb': 1,
#   'obama': 44,
#   'raises': 3,
#   'better': 49,
#   'vote': 81,
#   'candidates': 5,
#   'science': 236,
#   'obamaunc': 1,
#   'hate': 21,
#   'mental': 4,
#   'health': 75,
#   'pretty': 17,
#   'low': 8,
#   'menu': 2,
#   'hits': 9,
#   'food': 47,
#   'production': 16,
#   'hey': 38,
#   'michaels': 1,
#   'vetted': 1,
#   'approved': 2,
#   'marketbased': 2,
#   'strategies': 6,
#   'tackling': 35,
#   'supported': 7,
#   'majority': 29,
#   'cdns': 1,
#   'cdnpoli': 5,
#   'startalkradio': 1,
#   'first': 126,
#   'public': 41,
#   'understands': 13,
#   'congress': 18,
#   'johnholdren': 1,
#   'corybooker': 3,
#   'neiltyson': 8,
#   'explain': 29,
#   'htt': 129,
#   'honey': 5,
#   'guide': 2,
#   'paris': 58,
#   'pact': 6,
#   'us': 445,
#   'role': 39,
#   'demforce': 1,
#   'theresistance': 7,
#   'uniteblue': 2,
#   'ignores': 8,
#   'basic': 7,
#   'bgr': 1,
#   'china': 105,
#   'practically': 1,
#   'says': 124,
#   'trump': 889,
#   'lied': 9,
#   'berniesanders': 124,
#   'imvotingbecause': 62,
#   'future': 154,
#   'planet': 186,
#   'stake': 70,
#   'hillary': 85,
#   'clinton': 81,
#   'combat': 133,
#   'donald': 194,
#   'thinks': 219,
#   'deborahehatoxic': 1,
#   'soils': 11,
#   'aquifers': 1,
#   'vast': 4,
#   'amts': 1,
#   'wasted': 6,
#   'waste': 31,
#   'water': 90,
#   'runaway': 5,
#   'paof': 37,
#   'gas': 21,
#   'fracking': 14,
#   'bettybowers': 1,
#   'america': 111,
#   'unproven': 1,
#   'sure': 29,
#   'guy': 41,
#   'called': 52,
#   'noah': 2,
#   'fit': 3,
#   'worlds': 50,
#   'animals': 25,
#   'hi': 7,
#   'foramerica': 1,
#   'protested': 1,
#   'suppoof': 5,
#   'womansmarch': 1,
#   'pato': 3,
#   'help': 126,
#   'https': 275,
#   'thedailybeast': 4,
#   'trumps': 191,
#   'denial': 124,
#   'could': 135,
#   'cost': 26,
#   'trillion': 5,
#   'anyone': 30,
#   'supports': 17,
#   'view': 25,
#   'non': 1,
#   'polluter': 6,
#   'cronie': 1,
#   'please': 77,
#   'step': 24,
#   'forward': 23,
#   'resist': 17,
#   'impeach': 3,
#   'hes': 78,
#   'president': 207,
#   'united': 45,
#   'states': 68,
#   'fuck': 29,
#   'kelkulus': 11,
#   'irony': 13,
#   'florida': 60,
#   'state': 48,
#   'danger': 26,
#   'washed': 13,
#   'away': 30,
#   'due': 112,
#   'rising': 44,
#   'sea': 68,
#   'levels': 40,
#   'denies': 85,
#   'greenpeaceeasia': 1,
#   'pollution': 46,
#   'india': 20,
#   'reached': 6,
#   'stratosphere': 1,
#   'speed': 6,
#   'unep': 18,
#   'citiesclimfin': 1,
#   'lays': 2,
#   'cities': 68,
#   'subnational': 1,
#   'bodies': 2,
#   'finance': 1,
#   'solutions': 41,
#   'hoax': 318,
#   'though': 16,
#   'two': 21,
#   'cents': 2,
#   'political': 50,
#   'leadership': 29,
#   'era': 5,
#   'motherjones': 11,
#   'races': 4,
#   'watch': 152,
#   'care': 103,
#   'profpcdoherty': 1,
#   'need': 235,
#   'economists': 1,
#   'incorporate': 2,
#   'reality': 48,
#   'listen': 40,
#   'ushrn': 1,
#   'human': 89,
#   'facing': 21,
#   'disastrous': 3,
#   'ahamiltonspirit': 1,
#   'question': 25,
#   'manmade': 45,
#   'doubts': 5,
#   'havent': 9,
#   'seen': 14,
#   'inconvenient': 10,
#   'truth': 30,
#   'alphageekstr': 1,
#   'process': 4,
#   'occurs': 1,
#   'naturally': 2,
#   'extreme': 35,
#   'well': 92,
#   'eventually': 4,
#   'severe': 9,
#   'droughts': 10,
#   'roschneider': 1,
#   'neoliberalism': 8,
#   'conned': 7,
#   'fighting': 102,
#   'individuals': 10,
#   'martin': 10,
#   'lukacs': 4,
#   'davidsirota': 19,
#   'must': 164,
#   'rick': 18,
#   'perry': 21,
#   'ordered': 3,
#   'texas': 14,
#   'legislature': 1,
#   'kill': 46,
#   'bill': 29,
#   'requiring': 2,
#   'agencies': 6,
#   'prepare': 13,
#   'thats': 132,
#   'frightening': 38,
#   'country': 108,
#   'world': 446,
#   'hot': 30,
#   'verge': 9,
#   'google': 12,
#   'earths': 12,
#   'timelapse': 7,
#   'update': 4,
#   'illustrates': 3,
#   'years': 133,
#   'sethmacfarlane': 66,
#   'hrc': 62,
#   'proposes': 57,
#   'installing': 56,
#   'half': 74,
#   'billion': 82,
#   'solar': 73,
#   'panels': 60,
#   'end': 121,
#   'term': 70,
#   'beforetheflood': 145,
#   'everyone': 53,
#   'understand': 47,
#   'real': 502,
#   'leodicaprio': 122,
#   'shake': 1,
#   'ever': 58,
#   'earthjustice': 3,
#   'noaa': 15,
#   'repo': 2,
#   'nd': 13,
#   'hottest': 21,
#   'history': 26,
#   'one': 172,
#   'reason': 28,
#   'deniers': 179,
#   'admin': 25,
#   'gt': 12,
#   'conservatives': 29,
#   'love': 25,
#   'huh': 6,
#   'believing': 17,
#   'fertilization': 1,
#   'egg': 2,
#   'automatic': 1,
#   'life': 22,
#   'come': 42,
#   'check': 32,
#   'events': 14,
#   'srhpl': 1,
#   'million': 21,
#   'gone': 17,
#   'towards': 17,
#   'alleviating': 1,
#   'poverty': 22,
#   'reducing': 11,
#   'improving': 3,
#   'call': 47,
#   'mad': 11,
#   'ronaldklain': 1,
#   'decides': 2,
#   'briancdeese': 1,
#   'team': 24,
#   'washingtonpost': 27,
#   'warn': 5,
#   'epidemics': 1,
#   'savingoceans': 2,
#   'potentially': 2,
#   'hufuture': 1,
#   'fishermen': 3,
#   'jobs': 52,
#   'yet': 55,
#   'another': 64,
#   'advisor': 7,
#   'clueless': 5,
#   'climateprogress': 6,
#   'director': 8,
#   'denier': 186,
#   'coal': 54,
#   'lobbies': 1,
#   'deputy': 3,
#   'irisrimon': 1,
#   'chinese': 157,
#   'broke': 12,
#   'massive': 15,
#   'iceberg': 9,
#   'antarctica': 10,
#   'ndenicolamd': 1,
#   'doctors': 5,
#   'agree': 52,
#   'making': 56,
#   'sick': 12,
#   'earthday': 12,
#   'marchforscience': 8,
#   'healthandclimate': 1,
#   'tristinc': 2,
#   'made': 69,
#   'vice': 9,
#   'gay': 25,
#   'curable': 2,
#   'disease': 7,
#   'looking': 30,
#   'officially': 10,
#   'believes': 90,
#   'sorry': 23,
#   'everybody': 11,
#   'else': 18,
#   'realdonaldtrump': 163,
#   'potus': 43,
#   'fucking': 46,
#   'idiot': 13,
#   'im': 178,
#   'geologist': 1,
#   'studied': 4,
#   'college': 11,
#   'coauthored': 1,
#   'papers': 2,
#   'natgeochannel': 122,
#   'right': 195,
#   'travels': 76,
#   'tackle': 126,
#   'peta': 6,
#   'meat': 27,
#   'deforestation': 21,
#   'extinction': 20,
#   'worldveganday': 5,
#   'lexiprez': 2,
#   'literally': 51,
#   'denierrip': 1,
#   'kloppholic': 3,
#   'imagine': 22,
#   'trying': 29,
#   'convince': 11,
#   'isnt': 197,
#   'instead': 40,
#   'conspiracy': 23,
#   'wake': 16,
#   'docrock': 1,
#   'saying': 47,
#   'every': 94,
#   'major': 72,
#   'scientific': 56,
#   'organization': 5,
#   'follow': 15,
#   'projectarcc': 2,
#   'want': 134,
#   'hear': 25,
#   'av': 1,
#   'digital': 5,
#   'archivists': 1,
#   'activism': 1,
#   'avhack': 1,
#   'look': 89,
#   'polar': 34,
#   'bears': 25,
#   'extinct': 11,
#   'land': 10,
#   'antivaccersclimate': 1,
#   'deniersaca': 1,
#   'killers': 1,
#   'stop': 164,
#   'using': 18,
#   'stupidity': 4,
#   'try': 24,
#   'kil': 1,
#   'see': 130,
#   'way': 92,
#   'aveclimate': 2,
#   'apply': 6,
#   'method': 3,
#   'samjamesvelde': 2,
#   'degrees': 84,
#   'early': 9,
#   'november': 53,
#   'los': 4,
#   'angeles': 2,
#   'know': 190,
#   'according': 12,
#   'artclimate': 1,
#   'larsenc': 1,
#   'climatechangeaurlweb': 1,
#   'youths': 3,
#   'almost': 29,
#   'kenyas': 1,
#   'pop': 3,
#   'best': 59,
#   'line': 17,
#   'defense': 27,
#   'securityrobertmburia': 1,
#   'richardmunang': 7,
#   'geographerjay': 1,
#   'nasa': 54,
#   'research': 62,
#   'estate': 3,
#   'markets': 3,
#   'stato': 4,
#   'slump': 1,
#   'jeffdsachs': 2,
#   'cnn': 60,
#   'panelists': 1,
#   'erupt': 1,
#   'video': 22,
#   'time': 141,
#   'lies': 9,
#   'koch': 5,
#   'brothers': 3,
#   'heritage': 3,
#   'worried': 33,
#   'effect': 24,
#   'methane': 10,
#   'greater': 5,
#   'thought': 23,
#   'physorgcom': 2,
#   'astrokatie': 27,
#   'governments': 8,
#   'several': 4,
#   'powers': 2,
#   'failing': 11,
#   'act': 71,
#   'without': 45,
#   'kamalaharris': 38,
#   'stand': 36,
#   'jerrybrowngov': 12,
#   'california': 32,
#   'back': 76,
#   'steveengland': 1,
#   'u': 81,
#   'considered': 4,
#   'piece': 15,
#   'column': 6,
#   'steve': 6,
#   'inform': 2,
#   'ppl': 36,
#   'impact': 62,
#   'species': 32,
#   'habitats': 2,
#   'benwikler': 1,
#   'worry': 41,
#   'natural': 42,
#   'rendering': 2,
#   'earth': 150,
#   'uninhabitable': 4,
#   'alanresnicks': 1,
#   'horsemen': 1,
#   'apocalypse': 3,
#   'famine': 9,
#   'death': 12,
#   'pestilence': 1,
#   'hawaiidelilah': 2,
#   'went': 11,
#   'ivanka': 9,
#   'reporter': 1,
#   'insights': 3,
#   'scientists': 170,
#   'women': 63,
#   'expertis': 1,
#   'wqs': 1,
#   'pakistan': 10,
#   'th': 44,
#   'vulnerable': 24,
#   'terms': 13,
#   'whats': 30,
#   'experienced': 6,
#   'prime': 4,
#   'minister': 9,
#   'ajb': 1,
#   'knock': 1,
#   'brexit': 7,
#   'bury': 4,
#   'issuesbut': 1,
#   'really': 133,
#   'w': 53,
#   'drop': 5,
#   'dead': 19,
#   'nobel': 2,
#   'scientist': 49,
#   'ignorance': 17,
#   'shocking': 8,
#   'lastweektonight': 16,
#   'silly': 16,
#   'issue': 112,
#   'give': 73,
#   'resources': 56,
#   'council': 17,
#   'deanofcomedy': 4,
#   'followed': 2,
#   'closely': 3,
#   'wall': 19,
#   'street': 5,
#   'executives': 3,
#   'sdg': 3,
#   'take': 147,
#   'urgent': 20,
#   'join': 75,
#   'movement': 11,
#   'bradleym': 1,
#   'juddlegum': 3,
#   'kid': 4,
#   'changekid': 1,
#   'fact': 70,
#   'matte': 1,
#   'calls': 34,
#   'bad': 58,
#   'billmckibben': 22,
#   'exxonmobil': 9,
#   'long': 23,
#   'peddling': 2,
#   'misinformation': 6,
#   'elizkolbein': 1,
#   'newyorker': 2,
#   'exxonknew': 9,
#   'mrdenmore': 4,
#   'apafrom': 4,
#   'taking': 53,
#   'brink': 1,
#   'recession': 1,
#   'doubling': 2,
#   'deficit': 1,
#   'pariah': 3,
#   'refugees': 14,
#   'easiest': 4,
#   'ways': 41,
#   'daily': 19,
#   'eating': 15,
#   'beef': 7,
#   'heres': 94,
#   'effects': 93,
#   'marcuschown': 1,
#   'white': 65,
#   'house': 50,
#   'deal': 56,
#   'catastrophe': 13,
#   'threatens': 14,
#   'argue': 13,
#   'new': 283,
#   'turnscoat': 1,
#   'cant': 113,
#   'number': 18,
#   'priority': 10,
#   'mobilizeclimate': 2,
#   'treating': 5,
#   'far': 28,
#   'doomsday': 2,
#   'nowurlweb': 1,
#   'jacobwhitesides': 4,
#   'christmas': 16,
#   'chejackson': 1,
#   'anything': 34,
#   'columbus': 1,
#   'rex': 14,
#   'tillerson': 17,
#   'refuses': 11,
#   'admit': 11,
#   'decades': 27,
#   'ago': 27,
#   'huffpostpol': 14,
#   'wakmax': 1,
#   'talk': 87,
#   'alicebell': 2,
#   'itll': 5,
#   'make': 160,
#   'feel': 18,
#   'go': 94,
#   'duycks': 1,
#   'tomorrow': 12,
#   'event': 9,
#   'childrenrights': 1,
#   'context': 8,
#   'key': 31,
#   'message': 15,
#   'protect': 45,
#   'empower': 3,
#   'boost': 4,
#   'funding': 30,
#   'developing': 4,
#   'countries': 54,
#   'adapt': 14,
#   'paulhbeckwith': 2,
#   'folks': 10,
#   'storyabout': 1,
#   'evil': 3,
#   'twinof': 1,
#   'changethe': 2,
#   'oceans': 20,
#   'acidurlweb': 1,
#   'adriangeolopez': 1,
#   'still': 165,
#   'especially': 15,
#   'pulling': 3,
#   'p': 24,
#   'fitness': 1,
#   'late': 20,
#   'reverse': 18,
#   'warmingampquot': 1,
#   'scholaurship': 1,
#   'motherfucker': 1,
#   'arizonapatriot': 1,
#   'joelpollak': 1,
#   'gabyendingstory': 1,
#   'least': 23,
#   'christianextremist': 1,
#   'evolution': 28,
#   'hoaxes': 3,
#   'natgeophotos': 3,
#   'although': 4,
#   'scary': 18,
#   'topic': 9,
#   'ice': 85,
#   'insanely': 1,
#   'unimaginably': 1,
#   'beautifulurlweb': 1,
#   'everyones': 4,
#   'something': 49,
#   'progressive': 7,
#   'env': 3,
#   'exxon': 38,
#   'hero': 2,
#   'kicked': 1,
#   'saving': 5,
#   'selected': 1,
#   'money': 41,
#   'include': 5,
#   'job': 16,
#   'losses': 3,
#   'business': 26,
#   'interruptions': 1,
#   'worsening': 9,
#   'working': 38,
#   'un': 55,
#   'cnvey': 9,
#   'taylorandbrown': 1,
#   'thing': 96,
#   'bothers': 2,
#   'defund': 2,
#   'illuminateboys': 1,
#   'politicians': 39,
#   'fake': 47,
#   'jamespeshaw': 2,
#   'nzgreens': 2,
#   'gets': 26,
#   'zealand': 4,
#   'clean': 52,
#   'shadbase': 2,
#   'conversationedu': 2,
#   'turtles': 1,
#   'around': 62,
#   'pace': 4,
#   'existential': 10,
#   'challenge': 25,
#   'lawlib': 1,
#   'board': 11,
#   'bouncing': 3,
#   'ideas': 15,
#   'interested': 10,
#   'lisalsong': 1,
#   'horrifying': 6,
#   'outcomes': 1,
#   'stevevsninjas': 1,
#   'f': 18,
#   'liethats': 1,
#   'data': 56,
#   'point': 45,
#   'met': 8,
#   'concluded': 4,
#   'men': 11,
#   'speak': 15,
#   'englis': 1,
#   'sierraclubwi': 1,
#   'pollutingpruitt': 7,
#   'subject': 6,
#   'continued': 5,
#   'debate': 56,
#   'climatefacts': 3,
#   'yayitsrob': 4,
#   'twostep': 1,
#   'kinda': 3,
#   'moderate': 3,
#   'extremely': 7,
#   'radical': 4,
#   'race': 15,
#   'curb': 17,
#   'outpace': 1,
#   'governmentsparisagreement': 1,
#   'globalcovenant': 1,
#   'citiesclimateurlweb': 1,
#   'jellybeatles': 1,
#   'climatehome': 2,
#   'week': 22,
#   'save': 58,
#   'talks': 11,
#   'aleszubajak': 1,
#   'chile': 1,
#   'space': 9,
#   'threatening': 8,
#   'multiple': 2,
#   'shapes': 1,
#   'michaelawat': 2,
#   'much': 64,
#   'department': 11,
#   'office': 13,
#   'bans': 6,
#   'use': 42,
#   'phrase': 6,
#   'classicgrrl': 1,
#   'nuclear': 51,
#   'annihilation': 1,
#   'slowly': 4,
#   'wondering': 15,
#   'climatechange': 114,
#   'billnye': 9,
#   'francehillary': 1,
#   'agent': 3,
#   'ignoring': 27,
#   'benefits': 6,
#   'helps': 11,
#   'weak': 5,
#   'named': 3,
#   'lead': 47,
#   'agency': 8,
#   'fights': 9,
#   'proud': 12,
#   'represent': 8,
#   'finding': 6,
#   'creative': 2,
#   'changeurlweb': 19,
#   'palmerreponodapl': 1,
#   'golden': 2,
#   'gate': 2,
#   'park': 15,
#   'joins': 4,
#   'badlands': 4,
#   'national': 69,
#   'defying': 5,
#   'tweeting': 11,
#   'creationists': 2,
#   'never': 38,
#   'listened': 2,
#   'nye': 14,
#   'fusion': 31,
#   'become': 32,
#   'leader': 76,
#   'watching': 18,
#   'scott': 89,
#   'pruitt': 116,
#   'nonsense': 5,
#   'raising': 31,
#   'bp': 2,
#   'fool': 5,
#   'parisagreement': 52,
#   'watched': 6,
#   'get': 130,
#   'worse': 40,
#   'ralphnortham': 1,
#   'biggest': 66,
#   'opponent': 1,
#   'changeits': 3,
#   'followernodad': 21,
#   'parent': 16,
#   'id': 24,
#   'childrenscientist': 15,
#   'stave': 17,
#   'children': 33,
#   'stay': 28,
#   'voxdotcom': 21,
#   'election': 44,
#   'marks': 11,
#   'limiting': 15,
#   'moron': 12,
#   'lol': 26,
#   'cineversitytv': 1,
#   'ff': 4,
#   'corrupt': 10,
#   'co': 94,
#   'fossil': 45,
#   'fuels': 19,
#   'scoopit': 1,
#   'iansomerhalder': 24,
#   'speaking': 22,
#   'changetonight': 11,
#   'killer': 13,
#   'episode': 14,
#   'yearsofliving': 23,
#   'concept': 47,
#   'created': 72,
#   'order': 62,
#   'manufacturing': 46,
#   'noncompetiti': 44,
#   'per': 7,
#   'cent': 1,
#   'sad': 32,
#   'head': 86,
#   'suggests': 3,
#   'primary': 37,
#   'contributor': 46,
#   'engadget': 1,
#   'cmon': 2,
#   'nhla': 1,
#   'efforts': 32,
#   'markmagana': 1,
#   'nhlamember': 1,
#   'greenlatino': 1,
#   'latinopriorities': 1,
#   'ddlovato': 33,
#   'ivotedbecause': 33,
#   'equality': 47,
#   'comprehensive': 33,
#   'immigration': 40,
#   'reform': 50,
#   'prochoice': 33,
#   'magnitude': 4,
#   'looks': 64,
#   'meteorite': 1,
#   'strike': 2,
#   'gradual': 1,
#   'renewables': 17,
#   'crucia': 1,
#   'brentsullivan': 1,
#   'climatehawk': 36,
#   'shell': 10,
#   'deny': 107,
#   'put': 42,
#   'profit': 11,
#   'joshgad': 5,
#   'mourning': 5,
#   'stage': 8,
#   'putting': 21,
#   'kids': 52,
#   'standup': 3,
#   'globalgoals': 5,
#   'directly': 13,
#   'linked': 12,
#   'crucial': 14,
#   'achieve': 3,
#   'senfeinstein': 3,
#   'breaking': 9,
#   'senate': 11,
#   'appropriations': 1,
#   'committee': 14,
#   'voted': 52,
#   'restore': 4,
#   'vital': 12,
#   'panela': 1,
#   'victo': 1,
#   'epascottpruitt': 26,
#   'drives': 14,
#   'lets': 79,
#   'send': 15,
#   'copy': 10,
#   'dummies': 8,
#   'twelve': 1,
#   'bloody': 1,
#   'shit': 30,
#   'sleep': 3,
#   'raining': 8,
#   'brought': 12,
#   'michaelpielocik': 1,
#   ...},
#  2: {'rawstory': 5,
#   'researchers': 28,
#   'say': 66,
#   'three': 6,
#   'years': 60,
#   'act': 17,
#   'climate': 3345,
#   'change': 3206,
#   'late': 8,
#   'urlweb': 3921,
#   'tveitdal': 10,
#   'percent': 9,
#   'chance': 6,
#   'avoiding': 4,
#   'dangerous': 20,
#   'global': 508,
#   'warming': 436,
#   'study': 98,
#   'finds': 32,
#   'fossil': 8,
#   'fuel': 5,
#   'giant': 7,
#   'exxonmobil': 12,
#   'misled': 9,
#   'public': 20,
#   'harvard': 12,
#   'academics': 2,
#   'conclude': 2,
#   'bangladesh': 5,
#   'confronting': 1,
#   'head': 76,
#   'latimes': 22,
#   'atmospheric': 2,
#   'rivers': 3,
#   'fueled': 4,
#   'could': 133,
#   'decimate': 2,
#   'wild': 5,
#   'oysters': 5,
#   'san': 7,
#   'francisco': 5,
#   'bay': 8,
#   'independent': 52,
#   'trumps': 238,
#   'team': 32,
#   'removed': 5,
#   'data': 31,
#   'white': 55,
#   'house': 69,
#   'website': 64,
#   'may': 93,
#   'breaking': 22,
#   'law': 15,
#   'targets': 8,
#   'nations': 17,
#   'playing': 1,
#   'long': 2,
#   'game': 7,
#   'fighting': 24,
#   'via': 299,
#   'conversationedu': 3,
#   'washingtonpost': 45,
#   'alaskan': 3,
#   'tundra': 2,
#   'filling': 1,
#   'atmosphere': 7,
#   'carbon': 79,
#   'dioxide': 56,
#   'worsening': 1,
#   'thetorontosun': 1,
#   'sunlorrie': 2,
#   'indian': 12,
#   'environmentalist': 3,
#   'calls': 53,
#   'dicaprio': 13,
#   'documentary': 5,
#   'starbuck': 1,
#   'world': 114,
#   'food': 20,
#   'supplies': 4,
#   'risk': 29,
#   'threatens': 13,
#   'international': 21,
#   'trade': 28,
#   'warn': 19,
#   'experts': 44,
#   'foxnews': 14,
#   'macron': 13,
#   'charm': 1,
#   'changed': 3,
#   'mind': 10,
#   'republicans': 22,
#   'real': 39,
#   'time': 47,
#   'fight': 159,
#   'ninaburleighurlweb': 1,
#   'kylegriffin': 9,
#   'nyt': 5,
#   'reviewed': 1,
#   'draft': 3,
#   'rpt': 1,
#   'fed': 1,
#   'scientists': 178,
#   'directly': 3,
#   'contradicting': 2,
#   'admins': 2,
#   'claims': 19,
#   'https': 80,
#   'bbcbreaking': 6,
#   'uk': 39,
#   'government': 55,
#   'signs': 36,
#   'paris': 109,
#   'agreement': 81,
#   'worlds': 39,
#   'first': 26,
#   'comprehensive': 5,
#   'treaty': 11,
#   'tackling': 23,
#   'us': 293,
#   'environmental': 30,
#   'agency': 36,
#   'chief': 100,
#   'says': 234,
#   'humans': 25,
#   'contribute': 2,
#   'thinkprogress': 17,
#   'rex': 57,
#   'tillersons': 5,
#   'emailsurlweb': 1,
#   'ghg': 1,
#   'resevoirs': 2,
#   'methane': 6,
#   'play': 5,
#   'substantial': 1,
#   'role': 36,
#   'greenharvard': 2,
#   'universities': 2,
#   'uniquely': 1,
#   'important': 5,
#   'battle': 26,
#   'popsci': 9,
#   'ten': 1,
#   'ugliest': 1,
#   'animals': 3,
#   'threatened': 12,
#   'syfys': 1,
#   'incorporated': 1,
#   'imagines': 1,
#   'future': 16,
#   'ravaged': 1,
#   'cnn': 80,
#   'nytnational': 2,
#   'budget': 28,
#   'proposal': 7,
#   'spending': 9,
#   'money': 17,
#   'anymore': 5,
#   'air': 15,
#   'pollution': 14,
#   'deaths': 4,
#   'expected': 11,
#   'rise': 20,
#   'due': 59,
#   'labour': 3,
#   'budgeting': 1,
#   'punch': 1,
#   'climatechange': 69,
#   'foxandfriends': 2,
#   'new': 191,
#   'catholic': 1,
#   'priests': 3,
#   'preach': 2,
#   'congregations': 1,
#   'reposays': 6,
#   'foxnation': 1,
#   'sasjabeslik': 2,
#   'meet': 25,
#   'chinas': 20,
#   'ecological': 5,
#   'migrants': 2,
#   'people': 28,
#   'displaced': 4,
#   'china': 143,
#   'warns': 39,
#   'trump': 824,
#   'abandoning': 10,
#   'deal': 47,
#   'ft': 11,
#   'science': 94,
#   'rescue': 5,
#   'chocolate': 1,
#   'europe': 15,
#   'safetypindaily': 15,
#   'federal': 40,
#   'department': 48,
#   'censoring': 7,
#   'use': 28,
#   'term': 10,
#   'emails': 25,
#   'reveal': 9,
#   'olliemilman': 2,
#   'conservative': 6,
#   'columnist': 3,
#   'siege': 2,
#   'ny': 17,
#   'times': 24,
#   'debut': 2,
#   'fox': 9,
#   'news': 127,
#   'indyusa': 4,
#   'director': 6,
#   'said': 18,
#   'combating': 4,
#   'waste': 16,
#   'trudeau': 9,
#   'must': 21,
#   'put': 8,
#   'emphasis': 1,
#   'defence': 3,
#   'wants': 29,
#   'onside': 1,
#   'nationalpost': 3,
#   'thehill': 82,
#   'rahm': 7,
#   'emanuel': 11,
#   'posts': 9,
#   'webpage': 12,
#   'deleted': 21,
#   'administration': 45,
#   'energydesk': 4,
#   'historic': 5,
#   'coal': 31,
#   'fall': 4,
#   'profound': 1,
#   'impact': 43,
#   'efforts': 49,
#   'tackle': 29,
#   'literateliberal': 1,
#   'leading': 16,
#   'deniers': 9,
#   'told': 10,
#   'want': 24,
#   'motherjones': 13,
#   'pablorodas': 14,
#   'p': 14,
#   'west': 6,
#   'coast': 6,
#   'states': 31,
#   'even': 13,
#   'ecointernet': 23,
#   'secretary': 47,
#   'state': 48,
#   'tillerson': 71,
#   'arctic': 55,
#   'action': 57,
#   'antinuclear': 1,
#   'stephen': 8,
#   'hawking': 5,
#   'message': 14,
#   'dont': 30,
#   'ignore': 21,
#   'telesurenglish': 1,
#   'one': 30,
#   'jamaicas': 1,
#   'iconic': 2,
#   'beaches': 3,
#   'vanishing': 2,
#   'thanks': 14,
#   'nzaegel': 1,
#   'effects': 47,
#   'wreak': 1,
#   'havoc': 1,
#   'mental': 13,
#   'health': 34,
#   'doctors': 9,
#   'upi': 1,
#   'brace': 4,
#   'bitterly': 4,
#   'cold': 6,
#   'winter': 16,
#   'shifts': 9,
#   'polar': 22,
#   'vortex': 11,
#   'business': 47,
#   'tells': 41,
#   'isnt': 33,
#   'hoax': 45,
#   'invented': 15,
#   'climatekeith': 1,
#   'saskatchewan': 1,
#   'ag': 18,
#   'provincial': 2,
#   'govt': 13,
#   'plan': 88,
#   'policies': 30,
#   'target': 8,
#   'address': 18,
#   'skpol': 1,
#   'exxon': 81,
#   'shareholders': 6,
#   'moved': 2,
#   'force': 11,
#   'company': 10,
#   'disclose': 6,
#   'poses': 3,
#   'natureorg': 5,
#   'leaders': 58,
#   'reaffirm': 5,
#   'commitment': 9,
#   'parisagreement': 8,
#   'john': 26,
#   'roughan': 1,
#   'miss': 1,
#   'sceptical': 1,
#   'voice': 5,
#   'zealand': 6,
#   'herald': 10,
#   'environment': 76,
#   'huffingtonpost': 17,
#   'chinese': 20,
#   'cmdangelo': 3,
#   'businessinsider': 9,
#   'apple': 6,
#   'borrowing': 1,
#   'billion': 17,
#   'bradydennis': 2,
#   'cdc': 15,
#   'abruptly': 5,
#   'cancels': 11,
#   'longplanned': 4,
#   'conference': 23,
#   'river': 12,
#   'canada': 14,
#   'turned': 4,
#   'piracy': 2,
#   'thedailyclimate': 2,
#   'frogs': 1,
#   'heading': 1,
#   'uphill': 1,
#   'escape': 1,
#   'india': 25,
#   'timesofindia': 1,
#   'campaigner': 7,
#   'dies': 6,
#   'snorkeling': 6,
#   'greatbarrierreef': 14,
#   'climatechangrr': 10,
#   'sends': 6,
#   'much': 19,
#   'smaller': 5,
#   'talks': 27,
#   'bonn': 1,
#   'home': 20,
#   'http': 18,
#   'washtimes': 3,
#   'whistleblower': 5,
#   'alleges': 1,
#   'noaa': 11,
#   'manipulated': 6,
#   'hide': 1,
#   'pause': 6,
#   'reportedly': 2,
#   'used': 51,
#   'alias': 43,
#   'read': 11,
#   'xom': 2,
#   'guardianeco': 25,
#   'stopping': 6,
#   'way': 29,
#   'save': 23,
#   'great': 28,
#   'barrier': 22,
#   'reef': 18,
#   'wsj': 16,
#   'rebuke': 6,
#   'policy': 51,
#   'ge': 8,
#   'ceo': 20,
#   'immelt': 2,
#   'arnold': 8,
#   'schwarzenegger': 10,
#   'teams': 4,
#   'end': 10,
#   'lead': 28,
#   'make': 38,
#   'guardian': 64,
#   'ht': 7,
#   'weneedhillary': 1,
#   'cbs': 8,
#   'evening': 1,
#   'donald': 166,
#   'skeptic': 22,
#   'charge': 4,
#   'protecting': 3,
#   'drbobbullard': 1,
#   'theres': 16,
#   'b': 15,
#   'fear': 29,
#   'consequence': 9,
#   'victory': 15,
#   'googlegirl': 1,
#   'sues': 4,
#   'inaction': 13,
#   'obamas': 41,
#   'legacy': 5,
#   'weakened': 1,
#   'investment': 8,
#   'dirty': 2,
#   'sabrush': 1,
#   'epa': 237,
#   'believe': 21,
#   'primary': 57,
#   'contributor': 50,
#   'picks': 6,
#   'sceptic': 4,
#   'scott': 112,
#   'pruitt': 96,
#   'cop': 19,
#   'gma': 1,
#   'undergoing': 1,
#   'rapid': 12,
#   'ice': 41,
#   'melt': 19,
#   'speed': 2,
#   'vicenews': 6,
#   'rumored': 1,
#   'pick': 18,
#   'everyone': 4,
#   'love': 3,
#   'ajplus': 15,
#   'top': 32,
#   'met': 1,
#   'g': 52,
#   'summit': 26,
#   'today': 14,
#   'countries': 27,
#   'affirmed': 1,
#   'theyd': 1,
#   'except': 1,
#   'antarctica': 14,
#   'starting': 1,
#   'turn': 9,
#   'green': 27,
#   'u': 2,
#   'opens': 2,
#   'water': 25,
#   'research': 54,
#   'facility': 1,
#   'urged': 14,
#   'bbcnews': 2,
#   'geographyteacher': 1,
#   'nytimes': 48,
#   'cooks': 2,
#   'decades': 7,
#   'ahead': 29,
#   'suffer': 5,
#   'equally': 1,
#   'pope': 15,
#   'challenges': 6,
#   'un': 66,
#   'sdogbon': 1,
#   'mgwvjaiye': 1,
#   'changes': 26,
#   'course': 12,
#   'california': 52,
#   'stubbornly': 1,
#   'presses': 1,
#   'forward': 6,
#   'drills': 4,
#   'tibet': 1,
#   'glaciers': 7,
#   'morocco': 6,
#   'record': 30,
#   'humancaused': 15,
#   'rerouted': 6,
#   'entire': 12,
#   'doubts': 12,
#   'dioxides': 2,
#   'bbc': 17,
#   'scrambling': 1,
#   'protect': 13,
#   'energized': 1,
#   'concerns': 5,
#   'appolitics': 7,
#   'national': 43,
#   'park': 25,
#   'service': 4,
#   'defies': 3,
#   'social': 9,
#   'media': 8,
#   'ban': 14,
#   'tweets': 19,
#   'japanese': 1,
#   'interned': 1,
#   'wwii': 1,
#   'danger': 6,
#   'zone': 3,
#   'anothergreen': 1,
#   'kurdish': 1,
#   'response': 5,
#   'communicate': 6,
#   'officials': 12,
#   'risks': 36,
#   'forces': 6,
#   'drop': 16,
#   'mention': 13,
#   'joint': 7,
#   'statement': 10,
#   'defense': 22,
#   'continues': 12,
#   'cleanenergy': 3,
#   'little': 9,
#   'quebec': 1,
#   'municipalities': 1,
#   'discuss': 36,
#   'montreal': 3,
#   'march': 19,
#   'environmentguru': 1,
#   'stance': 18,
#   'softeninghis': 1,
#   'tone': 1,
#   'whether': 12,
#   'kill': 5,
#   'punxsutawneyphil': 1,
#   'wwfaustralia': 1,
#   'nsw': 2,
#   'landclearing': 1,
#   'laws': 6,
#   'loss': 11,
#   'possingham': 1,
#   'radionational': 1,
#   'kids': 34,
#   'taking': 20,
#   'feds': 9,
#   'possibly': 9,
#   'couover': 9,
#   'scientist': 37,
#   'spreads': 1,
#   'word': 2,
#   'biking': 1,
#   'across': 14,
#   'america': 22,
#   'wtop': 2,
#   'ecolocyl': 1,
#   'epenvironment': 1,
#   'ceta': 1,
#   'contraries': 1,
#   'direction': 1,
#   'commitments': 5,
#   'limit': 10,
#   'temperature': 4,
#   'c': 15,
#   'cetat': 1,
#   'creating': 7,
#   'void': 3,
#   'persuade': 3,
#   'help': 42,
#   'fill': 3,
#   'la': 3,
#   'featuremexicos': 1,
#   'maya': 2,
#   'point': 6,
#   'slow': 13,
#   'species': 19,
#   'googleaction': 1,
#   'harmful': 3,
#   'unnecessary': 1,
#   'car': 1,
#   'reports': 15,
#   'heatwaves': 3,
#   'hurricanes': 6,
#   'floods': 18,
#   'famine': 4,
#   'seven': 3,
#   'hotspots': 4,
#   'guardiannews': 7,
#   'minhazmerchant': 1,
#   'ministers': 3,
#   'italy': 5,
#   'pledge': 5,
#   'per': 5,
#   'accord': 12,
#   'without': 20,
#   'democracynow': 2,
#   'chomsky': 2,
#   'every': 10,
#   'republican': 13,
#   'candidate': 8,
#   'either': 2,
#   'denied': 3,
#   'happening': 12,
#   'shouldnt': 1,
#   'pinklphants': 1,
#   'mayor': 11,
#   'chicago': 10,
#   'posted': 1,
#   'epas': 22,
#   'city': 14,
#   'winenewz': 1,
#   'wine': 5,
#   'industry': 7,
#   'trouble': 2,
#   'really': 23,
#   'doesnt': 23,
#   'face': 21,
#   'aggyk': 1,
#   'five': 7,
#   'pacific': 12,
#   'islands': 7,
#   'lost': 12,
#   'rising': 6,
#   'seas': 5,
#   'hits': 7,
#   'nasa': 17,
#   'defiantly': 4,
#   'communicating': 3,
#   'despite': 45,
#   'nasaclimate': 2,
#   'lift': 2,
#   'em': 1,
#   'yall': 1,
#   'fusion': 3,
#   'peru': 5,
#   'suffering': 2,
#   'worst': 14,
#   'recent': 8,
#   'historyand': 2,
#   'blame': 20,
#   'environmentke': 1,
#   'kenya': 1,
#   'ratified': 2,
#   'judiwakhungu': 1,
#   'mygovke': 1,
#   'nemakenya': 1,
#   'keforestservice': 1,
#   'professors': 2,
#   'sign': 25,
#   'open': 9,
#   'letter': 9,
#   'urging': 8,
#   'aireguru': 1,
#   'knocks': 2,
#   'extends': 3,
#   'effosan': 1,
#   'ap': 20,
#   'gov': 26,
#   'causes': 24,
#   'uproar': 10,
#   'contradicts': 14,
#   'washington': 34,
#   'post': 30,
#   'huffpostpol': 18,
#   'wildlife': 8,
#   'far': 6,
#   'worse': 19,
#   'thought': 11,
#   'australia': 21,
#   'left': 11,
#   'behind': 9,
#   'momentum': 5,
#   'appointees': 1,
#   'fake': 7,
#   'big': 11,
#   'pattern': 4,
#   'cloud': 3,
#   'cover': 4,
#   'masked': 3,
#   'deceptively': 2,
#   'simple': 4,
#   'number': 4,
#   'enters': 5,
#   'articles': 5,
#   'last': 14,
#   'hrs': 2,
#   'memo': 5,
#   'alarms': 5,
#   'energy': 100,
#   'staff': 16,
#   'cnbc': 9,
#   'pennsylvania': 1,
#   'fracking': 2,
#   'clash': 2,
#   'attorney': 10,
#   'general': 15,
#   'japan': 3,
#   'pruitts': 25,
#   'office': 28,
#   'deluged': 16,
#   'angry': 16,
#   'callers': 16,
#   'questions': 24,
#   'ajenglish': 8,
#   'worldpenguinday': 2,
#   'penguin': 2,
#   'colony': 2,
#   'meeting': 22,
#   'urges': 34,
#   'highest': 3,
#   'political': 9,
#   'afp': 3,
#   'reindeer': 10,
#   'disappearing': 7,
#   'alarming': 3,
#   'rate': 2,
#   'alaska': 7,
#   'obama': 78,
#   'admin': 10,
#   'sending': 3,
#   'million': 18,
#   'fund': 23,
#   'tongotongoz': 1,
#   'lastnightinsweden': 1,
#   'mass': 5,
#   'immigration': 2,
#   'north': 5,
#   'wef': 12,
#   'cities': 29,
#   'outpacing': 2,
#   'race': 14,
#   'curb': 32,
#   'nbc': 1,
#   'dismissed': 2,
#   'manmade': 9,
#   'many': 9,
#   'young': 6,
#   'poverty': 5,
#   'terrorism': 6,
#   'thebaxterbean': 1,
#   'executive': 42,
#   'order': 64,
#   'dismantling': 4,
#   'president': 100,
#   'combat': 29,
#   'barack': 7,
#   'create': 3,
#   'refugee': 2,
#   'crisis': 8,
#   'unprecedented': 4,
#   'human': 29,
#   'history': 8,
#   'clintonkowach': 1,
#   'ethiopias': 2,
#   'coffee': 5,
#   'bibleprophecy': 1,
#   'truth': 9,
#   'knowledge': 4,
#   'energyboom': 1,
#   'election': 10,
#   'jeopardize': 1,
#   'climatecentral': 24,
#   'cabinet': 6,
#   'nominees': 3,
#   'position': 12,
#   'petraau': 2,
#   'denies': 22,
#   'ordered': 4,
#   'hand': 12,
#   'secret': 5,
#   'prosecutors': 3,
#   'smartnews': 3,
#   'spring': 8,
#   'came': 3,
#   'early': 9,
#   'culprit': 3,
#   'mmcphoto': 1,
#   'recordbreaking': 34,
#   'pushes': 25,
#   'uncharted': 27,
#   'territory': 25,
#   'shellknew': 1,
#   'film': 15,
#   'emerges': 1,
#   'showing': 4,
#   'oil': 25,
#   'firm': 1,
#   'shell': 8,
#   'warning': 16,
#   'amazngebooks': 2,
#   'author': 2,
#   'radio': 8,
#   'host': 4,
#   'suggests': 12,
#   'weve': 4,
#   'already': 18,
#   'war': 13,
#   'malcolm': 3,
#   'roberts': 2,
#   'sbs': 1,
#   'cause': 30,
#   'conflicts': 2,
#   'sahel': 1,
#   'faces': 12,
#   'droughts': 6,
#   'storms': 9,
#   'accelerates': 4,
#   'bill': 19,
#   'gates': 9,
#   'investors': 17,
#   'worth': 8,
#   'launching': 5,
#   'innovation': 6,
#   'stanford': 4,
#   'link': 25,
#   'extreme': 28,
#   'weather': 36,
#   'germany': 10,
#   'together': 4,
#   'presidentelect': 16,
#   'nobody': 12,
#   'knows': 12,
#   'cnni': 9,
#   'implications': 1,
#   'ctvnews': 1,
#   'capitalize': 1,
#   'takes': 18,
#   'step': 6,
#   'back': 65,
#   'cdnpoli': 3,
#   'chairman': 5,
#   'committee': 16,
#   'beneficial': 1,
#   'phannam': 1,
#   'disaster': 17,
#   'alley': 2,
#   'cyclonedebbie': 1,
#   'shows': 26,
#   'test': 4,
#   'australias': 8,
#   'military': 12,
#   'smh': 3,
#   'whysharksmatter': 1,
#   'feedly': 2,
#   'actually': 9,
#   'required': 3,
#   'lawurlweb': 2,
#   'roll': 11,
#   'reviews': 12,
#   'source': 9,
#   'reuters': 68,
#   'companies': 16,
#   'involved': 2,
#   'sector': 4,
#   'problem': 10,
#   'cant': 13,
#   'words': 4,
#   'google': 12,
#   'fresh': 2,
#   'doubt': 6,
#   'dramatically': 15,
#   'approach': 18,
#   'duped': 1,
#   'bloomberg': 25,
#   'grilse': 1,
#   'considering': 2,
#   'ways': 6,
#   'fasttrack': 1,
#   'withdrawal': 3,
#   'administrator': 7,
#   'speech': 9,
#   'delegate': 3,
#   'cdcs': 5,
#   'canceled': 7,
#   'al': 36,
#   'gore': 30,
#   'facethenation': 1,
#   'berniesanders': 2,
#   'icymi': 4,
#   'underlying': 1,
#   'assumptions': 1,
#   'keeping': 4,
#   'finding': 1,
#   'common': 3,
#   'ground': 3,
#   'climatehawk': 30,
#   'biden': 5,
#   'abcnews': 5,
#   'glo': 1,
#   'sweeping': 10,
#   'rollback': 6,
#   'obamaera': 10,
#   'rules': 13,
#   'deptartment': 1,
#   'rejects': 8,
#   'attempt': 3,
#   'single': 1,
#   'working': 5,
#   'year': 19,
#   'become': 10,
#   'refugees': 4,
#   'ocean': 23,
#   'levels': 17,
#   'butterfly': 1,
#   'protector': 1,
#   'informed': 1,
#   'gets': 6,
#   'obe': 1,
#   'try': 3,
#   'care': 11,
#   'jeopardizing': 1,
#   'pentagons': 1,
#   'retired': 2,
#   'markfhand': 1,
#   'closes': 3,
#   'abroad': 1,
#   'ignorance': 1,
#   'diplomacy': 3,
#   'undo': 17,
#   'protections': 4,
#   'thebetterindia': 1,
#   'yearold': 6,
#   'indias': 2,
#   'seat': 1,
#   'bank': 10,
#   'todays': 1,
#   'storieshttps': 1,
#   'bradreason': 1,
#   'revises': 1,
#   'remove': 7,
#   'moments': 2,
#   'michaelemann': 3,
#   'age': 5,
#   'libel': 1,
#   'suit': 2,
#   'heads': 3,
#   'trial': 10,
#   'chelseaeharvey': 1,
#   'fiction': 3,
#   'fact': 1,
#   'announces': 4,
#   'goal': 4,
#   'increase': 10,
#   'meetings': 2,
#   'dallasnews': 2,
#   'restrict': 1,
#   'investor': 4,
#   'activism': 2,
#   'like': 18,
#   'resolution': 1,
#   'jeffmosier': 1,
#   'chile': 1,
#   'see': 16,
#   'greatest': 1,
#   'external': 2,
#   'threat': 37,
#   'nprparallels': 1,
#   'rusty': 1,
#   'patched': 1,
#   'bumblebee': 1,
#   'added': 1,
#   'endangered': 5,
#   'list': 4,
#   'gt': 2,
#   'habitat': 6,
#   'losspesticides': 1,
#   'amp': 35,
#   'rt': 2,
#   'jasonkoebler': 1,
#   'references': 13,
#   'inauguration': 11,
#   'popular': 4,
#   'belief': 7,
#   'paginanuova': 1,
#   'tv': 5,
#   'algae': 8,
#   'altusepa': 4,
#   'documents': 12,
#   'healthurlweb': 1,
#   'billmckibben': 1,
#   'massive': 6,
#   'blooms': 3,
#   'arabian': 6,
#   'sea': 32,
#   'tied': 6,
#   'changein': 1,
#   'oxygenchoked': 1,
#   'waters': 2,
#   'beneath': 1,
#   'fish': 3,
#   'die': 4,
#   'johnvidal': 1,
#   'launches': 3,
#   'triple': 2,
#   'initiative': 3,
#   'challenge': 16,
#   'conservatives': 7,
#   'elected': 3,
#   'abraham': 5,
#   'builds': 1,
#   'wetland': 2,
#   'resilience': 5,
#   'reinforce': 1,
#   'indigenous': 17,
#   'spreading': 6,
#   'case': 10,
#   'acting': 5,
#   'demforce': 1,
#   'cbcnews': 12,
#   'win': 9,
#   'environmentalists': 8,
#   ...},
#  0: {'calum': 1,
#   'tweets': 5,
#   'abt': 5,
#   'reunitingish': 1,
#   'w': 15,
#   'castsees': 1,
#   'replies': 1,
#   'begging': 1,
#   'come': 27,
#   'countriescalum': 1,
#   'goes': 4,
#   'back': 21,
#   'rting': 1,
#   'climate': 1439,
#   'change': 1375,
#   'also': 24,
#   'met': 7,
#   'guy': 11,
#   'let': 6,
#   'us': 101,
#   'truth': 7,
#   'gay': 6,
#   'people': 65,
#   'existing': 1,
#   'urlweb': 830,
#   'jnpftw': 1,
#   'scientists': 24,
#   'denounce': 3,
#   'choice': 4,
#   'dealt': 1,
#   'simple': 5,
#   'issues': 11,
#   'like': 96,
#   'energy': 23,
#   'policy': 15,
#   'complex': 5,
#   'mal': 2,
#   'vs': 4,
#   'tones': 2,
#   'qanda': 4,
#   'andrewsharp': 1,
#   'win': 5,
#   'probability': 1,
#   'bullshit': 5,
#   'man': 30,
#   'saw': 5,
#   'nba': 1,
#   'finals': 1,
#   'thats': 36,
#   'knew': 1,
#   'global': 1036,
#   'warming': 967,
#   'isnt': 58,
#   'real': 94,
#   'chris': 1,
#   'initially': 1,
#   'talked': 8,
#   'changeme': 1,
#   'thinked': 1,
#   'three': 2,
#   'seconds': 2,
#   'europea': 2,
#   'approve': 1,
#   'executive': 4,
#   'order': 6,
#   'realdonaldtrump': 29,
#   'due': 21,
#   'sign': 7,
#   'environmenturlweb': 1,
#   'glennf': 1,
#   'calling': 2,
#   'great': 36,
#   'space': 6,
#   'cylinder': 1,
#   'save': 7,
#   'fuckofflaine': 1,
#   'jjxrry': 1,
#   'spacex': 1,
#   'quebanjesus': 1,
#   'antarctica': 5,
#   'big': 17,
#   'lmao': 5,
#   'nigga': 5,
#   'use': 12,
#   'air': 19,
#   'conditioner': 1,
#   'hope': 7,
#   'china': 26,
#   'tells': 4,
#   'trump': 147,
#   'hoax': 30,
#   'invented': 3,
#   'via': 24,
#   'business': 6,
#   'lol': 22,
#   'schooling': 2,
#   'uscgpacificnw': 1,
#   'nsf': 1,
#   'icebreaking': 1,
#   'ships': 1,
#   'primary': 5,
#   'cause': 56,
#   'arctic': 7,
#   'freeze': 4,
#   'amp': 100,
#   'stay': 5,
#   'away': 11,
#   'doesnt': 53,
#   'exist': 19,
#   'club': 44,
#   'penguin': 84,
#   'shutting': 20,
#   'cernovich': 4,
#   'ldnenvironment': 1,
#   'weve': 4,
#   'shoterm': 1,
#   'opps': 1,
#   'working': 5,
#   'send': 5,
#   'cv': 1,
#   'qs': 1,
#   'environmentlondongovuk': 1,
#   'h': 8,
#   'markbaileymp': 1,
#   'fed': 1,
#   'energyenvt': 1,
#   'minister': 2,
#   'joshfrydenberg': 2,
#   'refused': 1,
#   'allow': 7,
#   'term': 5,
#   'coag': 1,
#   'council': 3,
#   'communique': 1,
#   'despit': 1,
#   'jadorelacouture': 1,
#   'fact': 12,
#   'leonardo': 30,
#   'dicaprio': 20,
#   'discuss': 10,
#   'smithsonianenv': 1,
#   'sercs': 1,
#   'roy': 1,
#   'rich': 2,
#   'colleagues': 1,
#   'create': 3,
#   'buzz': 2,
#   'germany': 1,
#   'simulation': 1,
#   'senior': 3,
#   'quality': 3,
#   'specialist': 1,
#   'airquality': 1,
#   'climatechange': 15,
#   'greenhousegas': 1,
#   'cnn': 18,
#   'protest': 3,
#   'stupid': 7,
#   'mthgd': 1,
#   'shut': 21,
#   'prisonplanet': 2,
#   'wow': 11,
#   'finally': 5,
#   'evil': 3,
#   'wake': 1,
#   'good': 39,
#   'drishtiias': 1,
#   'audio': 2,
#   'article': 14,
#   'environment': 11,
#   'trumps': 24,
#   'decision': 4,
#   'form': 6,
#   'paris': 18,
#   'agreementhttps': 1,
#   'politicalshopiewagn': 1,
#   'dems': 2,
#   'causing': 21,
#   'stfu': 1,
#   'reader': 1,
#   'questions': 8,
#   'science': 29,
#   'theories': 3,
#   'zachheltzel': 1,
#   'believe': 87,
#   'generally': 1,
#   'refuse': 1,
#   'say': 33,
#   'trans': 2,
#   'loud': 1,
#   'youre': 28,
#   'better': 9,
#   'vp': 3,
#   'nasajohnson': 1,
#   'ask': 21,
#   'explain': 16,
#   'jinjjarevil': 1,
#   'way': 20,
#   'seokjin': 1,
#   'blinks': 1,
#   'adorable': 1,
#   'stopstrees': 1,
#   'grow': 1,
#   'crime': 21,
#   'rate': 4,
#   'decreases': 1,
#   'benhulac': 1,
#   'asked': 28,
#   'charges': 1,
#   'exxonmobil': 1,
#   'withheld': 1,
#   'information': 4,
#   'tillerson': 5,
#   'declines': 1,
#   'answer': 9,
#   'twice': 1,
#   'secretaryofst': 1,
#   'rjsalmond': 1,
#   'already': 10,
#   'denial': 10,
#   'either': 10,
#   'would': 43,
#   'loss': 6,
#   'well': 25,
#   'quiz': 2,
#   'cultural': 2,
#   'heritageclimate': 1,
#   'disclaimer': 1,
#   'dont': 73,
#   'agree': 6,
#   'answers': 5,
#   'still': 35,
#   'interesting': 20,
#   'look': 24,
#   'whos': 5,
#   'town': 3,
#   'thank': 13,
#   'enjoying': 4,
#   'quick': 6,
#   'trip': 2,
#   'brown': 2,
#   'county': 1,
#   'state': 5,
#   'park': 4,
#   'degree': 4,
#   'november': 13,
#   'day': 27,
#   'puffnpuffin': 1,
#   'stevemartintogo': 1,
#   'billnye': 5,
#   'bumfonline': 1,
#   'could': 25,
#   'someone': 15,
#   'link': 7,
#   'journal': 3,
#   'reviewed': 3,
#   'one': 49,
#   'guess': 12,
#   'mei': 1,
#   'mains': 1,
#   'jackposobiec': 3,
#   'soon': 10,
#   'altright': 1,
#   'blamed': 6,
#   'gingivitis': 1,
#   'senatormroberts': 2,
#   'much': 31,
#   'finkel': 1,
#   'blueprint': 1,
#   'stop': 32,
#   'none': 4,
#   'deindustrialise': 1,
#   'economy': 9,
#   'fo': 1,
#   'prisionplaneta': 1,
#   'scottadamssays': 5,
#   'studies': 4,
#   'choose': 2,
#   'show': 14,
#   'ones': 3,
#   'htt': 14,
#   'inspiration': 20,
#   'told': 25,
#   'em': 8,
#   'think': 82,
#   'solved': 6,
#   'problem': 13,
#   'kids': 9,
#   'fix': 12,
#   'sit': 3,
#   'wait': 12,
#   'dadlife': 1,
#   'tell': 30,
#   'story': 10,
#   'contest': 1,
#   'petraau': 1,
#   'countries': 6,
#   'subtweeted': 2,
#   'lianamaeby': 1,
#   'plus': 2,
#   'side': 7,
#   'anymore': 6,
#   'robydalvik': 1,
#   'kalem': 1,
#   'ini': 2,
#   'karena': 5,
#   'faktor': 1,
#   'laut': 1,
#   'naik': 2,
#   'conversation': 4,
#   'go': 13,
#   'morning': 5,
#   'arthur': 3,
#   'cold': 26,
#   'yes': 23,
#   'obviously': 5,
#   'fake': 14,
#   'agreed': 2,
#   'thi': 1,
#   'caused': 22,
#   'cabbage': 1,
#   'farts': 3,
#   'simonwest': 1,
#   'brilliant': 1,
#   'cartoon': 2,
#   'sums': 2,
#   'cancel': 16,
#   'barackobama': 1,
#   'policies': 10,
#   'itisreal': 1,
#   'adam': 1,
#   'adamcurry': 1,
#   'maakte': 1,
#   'al': 16,
#   'keer': 1,
#   'zijn': 2,
#   'agenda': 8,
#   'leuk': 1,
#   'info': 3,
#   'erry': 1,
#   'reason': 11,
#   'fight': 21,
#   'ccol': 1,
#   'putting': 3,
#   'ac': 1,
#   'outside': 12,
#   'ineedtakeatwit': 1,
#   'zwash': 1,
#   'foxnews': 9,
#   'thejuanwilliams': 1,
#   'lolololololol': 1,
#   'oceans': 1,
#   'rising': 5,
#   'even': 33,
#   'without': 7,
#   'stand': 3,
#   'successes': 2,
#   'hayleiip': 1,
#   'im': 81,
#   'qualified': 1,
#   'pulled': 2,
#   'pic': 5,
#   'environmental': 5,
#   'ni': 2,
#   'wingsscotland': 2,
#   'belfast': 1,
#   'alone': 2,
#   'probably': 13,
#   'accelerates': 2,
#   'year': 19,
#   'night': 7,
#   'dicapriofdn': 1,
#   'u': 29,
#   'preach': 1,
#   'yacht': 1,
#   'hypocrite': 6,
#   'gesemdicapt': 1,
#   'fuck': 21,
#   'anyone': 9,
#   'lives': 7,
#   'earth': 17,
#   'laughing': 1,
#   'mattis': 3,
#   'says': 45,
#   'proves': 3,
#   'elections': 1,
#   'henningakesson': 1,
#   'interested': 4,
#   'glaciers': 4,
#   'yr': 4,
#   'researcher': 2,
#   'position': 6,
#   'regional': 1,
#   'modeling': 3,
#   'bjerknesbccr': 1,
#   'uib': 1,
#   'right': 36,
#   'significant': 2,
#   'weather': 37,
#   'event': 6,
#   'blindly': 1,
#   'blame': 20,
#   'tahjshaunx': 1,
#   'funnymaine': 1,
#   'black': 8,
#   'men': 5,
#   'hitlers': 1,
#   'main': 8,
#   'target': 1,
#   'holocaust': 1,
#   'women': 9,
#   'amcp': 3,
#   'papers': 3,
#   'cridfxj': 1,
#   'agreement': 15,
#   'isolated': 1,
#   'completely': 1,
#   'elliehighwood': 1,
#   'ok': 8,
#   'crochet': 1,
#   'addict': 1,
#   'blanket': 1,
#   'stripes': 1,
#   'coloured': 1,
#   'according': 5,
#   'last': 13,
#   'years': 26,
#   'cudder': 1,
#   'everyone': 19,
#   'pointedit': 1,
#   'triggers': 1,
#   'rise': 9,
#   'giant': 4,
#   'orchids': 1,
#   'battle': 3,
#   'carniverous': 1,
#   'plants': 1,
#   'devour': 1,
#   'dwindling': 1,
#   'humans': 11,
#   'thefilm': 1,
#   'bringing': 5,
#   'tornadoes': 2,
#   'floods': 2,
#   'god': 11,
#   'america': 9,
#   'plaguing': 1,
#   'farrakhan': 1,
#   'quote': 2,
#   'nuclear': 23,
#   'war': 10,
#   'might': 15,
#   'plunge': 1,
#   'winter': 23,
#   'wont': 14,
#   'worry': 7,
#   'notlinkolafan': 1,
#   'rowanjones': 1,
#   'need': 37,
#   'pay': 7,
#   'kimkardashian': 1,
#   'heaps': 1,
#   'cash': 3,
#   'promote': 1,
#   'solutions': 3,
#   'lets': 8,
#   'boredeaths': 1,
#   'mtthwdvs': 1,
#   'learn': 1,
#   'difference': 5,
#   'shellenbergermd': 1,
#   'new': 44,
#   'leodicaprio': 7,
#   'web': 1,
#   'site': 2,
#   'attacks': 1,
#   'power': 8,
#   'plant': 5,
#   'closures': 1,
#   'increase': 3,
#   'co': 12,
#   'emissions': 7,
#   'ht': 5,
#   'grandma': 1,
#   'said': 44,
#   'aveeuropathend': 1,
#   'pbp': 1,
#   'cling': 1,
#   'idea': 8,
#   'anything': 13,
#   'civil': 4,
#   'rights': 13,
#   'website': 7,
#   'plesscatherine': 1,
#   'team': 10,
#   'energyclimate': 1,
#   'check': 6,
#   'mcggovt': 1,
#   'mariamartmcg': 1,
#   'cocodupepe': 1,
#   'marlapeyre': 1,
#   'eliseffant': 1,
#   'https': 36,
#   'pollrepoto': 1,
#   'address': 5,
#   'isdoing': 1,
#   'enough': 9,
#   'needs': 10,
#   'quinnipiac': 2,
#   'rv': 1,
#   'ezralevant': 5,
#   'sheilagunnreids': 2,
#   'videos': 2,
#   'un': 22,
#   'conference': 20,
#   'marrakech': 2,
#   'weathernetwork': 1,
#   'snow': 19,
#   'joke': 6,
#   'claims': 5,
#   'yet': 9,
#   'another': 9,
#   'casualty': 1,
#   'saveoursnowmen': 1,
#   'thenextweb': 2,
#   'national': 15,
#   'geographics': 6,
#   'documentary': 23,
#   'youtube': 11,
#   'ultravlolence': 20,
#   'interviewer': 21,
#   'warmingmelania': 20,
#   'hello': 23,
#   'hes': 78,
#   'kind': 24,
#   'strong': 21,
#   'c': 28,
#   'nuritben': 1,
#   'world': 39,
#   'ranges': 1,
#   'different': 3,
#   'eural': 1,
#   'india': 3,
#   'africa': 3,
#   'jedrlee': 8,
#   'hey': 17,
#   'girl': 9,
#   'changebecause': 8,
#   'going': 35,
#   'ignore': 10,
#   'denying': 7,
#   'celebrate': 2,
#   'overcome': 1,
#   'obamacare': 4,
#   'million': 4,
#   'becketadams': 3,
#   'journo': 1,
#   'twitter': 10,
#   'seems': 3,
#   'angrier': 1,
#   'bret': 4,
#   'stephens': 4,
#   'oped': 3,
#   'week': 11,
#   'nyt': 13,
#   'publish': 1,
#   'drshow': 1,
#   'amyaharder': 3,
#   'chriscmooney': 1,
#   'surveyfunk': 1,
#   'project': 3,
#   'kfb': 1,
#   'maybe': 22,
#   'messing': 2,
#   'sleep': 2,
#   'cycle': 1,
#   'cuntpanda': 1,
#   'globetoppers': 1,
#   'rickagain': 1,
#   'mercnews': 1,
#   'cartoons': 1,
#   'donald': 19,
#   'kejayurbane': 1,
#   'humid': 2,
#   'hot': 43,
#   'thotkejay': 1,
#   'urbane': 1,
#   'mood': 2,
#   'piece': 3,
#   'yay': 1,
#   'thing': 40,
#   'concerns': 1,
#   'please': 16,
#   'boys': 6,
#   'deny': 9,
#   'get': 45,
#   'bi': 2,
#   'gabrielgrims': 1,
#   'habitat': 1,
#   'driving': 1,
#   'species': 4,
#   'extinction': 4,
#   'crisis': 4,
#   'realpeerreview': 1,
#   'resurgence': 1,
#   'dragonsurlweb': 1,
#   'catalyticrxn': 1,
#   'trend': 4,
#   'toward': 2,
#   'increased': 3,
#   'acceptance': 3,
#   'humancaused': 4,
#   'flat': 2,
#   'scienceelecti': 1,
#   'catbeltane': 2,
#   'cool': 10,
#   'presidential': 2,
#   'debates': 7,
#   'featured': 2,
#   'whatsoever': 2,
#   'repstevensmith': 3,
#   'host': 3,
#   'vote': 8,
#   'hillary': 12,
#   'believes': 15,
#   'make': 30,
#   'actually': 20,
#   'warfare': 1,
#   'hoosierworld': 1,
#   'entertainers': 1,
#   'theyre': 19,
#   'meeting': 7,
#   'lib': 1,
#   'presidents': 1,
#   'work': 13,
#   'dare': 2,
#   'talk': 33,
#   'urban': 3,
#   'classylikekoi': 1,
#   'justinkanew': 1,
#   'keep': 15,
#   'heard': 12,
#   'something': 14,
#   'weeks': 6,
#   'ago': 9,
#   'infothey': 1,
#   'taking': 6,
#   'kid': 3,
#   'named': 3,
#   'naomi': 1,
#   'started': 13,
#   'damn': 13,
#   'mike': 3,
#   'drop': 3,
#   'little': 9,
#   'yo': 5,
#   'question': 9,
#   'amitav': 1,
#   'ghosh': 1,
#   'talks': 8,
#   'book': 8,
#   'standard': 1,
#   'news': 23,
#   'central': 4,
#   'graysekelly': 1,
#   'polar': 14,
#   'bears': 8,
#   'natural': 5,
#   'enemies': 2,
#   'dies': 3,
#   'starvation': 1,
#   'sonofliberty': 1,
#   'poll': 4,
#   'made': 16,
#   'scientific': 4,
#   'djmikerawk': 1,
#   'fireworks': 1,
#   'contribute': 3,
#   'asking': 3,
#   'potus': 5,
#   'ing': 1,
#   'monitoringmodeling': 1,
#   'metrowaterworks': 1,
#   'talking': 18,
#   'programs': 5,
#   'ralucaellis': 1,
#   'thefranklin': 1,
#   'electromegnatic': 1,
#   'inthe': 1,
#   'airpuja': 1,
#   'diya': 2,
#   'ko': 4,
#   'boojate': 1,
#   'hiweather': 1,
#   'technologysehipnotize': 1,
#   'yourmind': 1,
#   'willemjoustra': 1,
#   'waar': 1,
#   'blijft': 1,
#   'die': 16,
#   'fvckrvcism': 1,
#   'presidentelect': 5,
#   'thinks': 13,
#   'nanasranch': 1,
#   'hell': 14,
#   'freezes': 2,
#   'suhshu': 1,
#   'mcm': 5,
#   'myth': 7,
#   'ship': 2,
#   'sailed': 1,
#   'two': 11,
#   'declining': 1,
#   'romans': 1,
#   'caught': 4,
#   'hebrew': 1,
#   'character': 3,
#   'weekend': 2,
#   'bloke': 1,
#   'inspired': 1,
#   'warmingfwm': 1,
#   'pkollar': 1,
#   'rangers': 1,
#   'update': 1,
#   'fighting': 9,
#   'monster': 2,
#   'called': 20,
#   'polluticorn': 1,
#   'unicorn': 1,
#   'pollutes': 1,
#   'stuff': 7,
#   'pr': 1,
#   'alicemolero': 1,
#   'mean': 15,
#   'cooling': 4,
#   'heating': 1,
#   'define': 1,
#   'enzoboschi': 1,
#   'le': 4,
#   'piante': 1,
#   'assorbono': 1,
#   'pi': 2,
#   'non': 4,
#   'hanno': 1,
#   'bisogno': 1,
#   'di': 10,
#   'acqua': 1,
#   'sono': 2,
#   'diventate': 1,
#   'efficienti': 1,
#   'contro': 2,
#   'il': 5,
#   'nature': 1,
#   'tan': 4,
#   'sweeping': 1,
#   'american': 9,
#   'politics': 11,
#   'intolerant': 1,
#   'bullying': 1,
#   'censorshiploving': 1,
#   'groupsbrought': 1,
#   'regards': 2,
#   'lovely': 2,
#   'today': 29,
#   'read': 20,
#   'swrightwestozs': 1,
#   'latest': 6,
#   'insurance': 2,
#   'lending': 1,
#   'featuring': 1,
#   'apra': 1,
#   'speech': 8,
#   'centrepolicydev': 1,
#   'thecosby': 1,
#   'gon': 19,
#   'na': 30,
#   'post': 8,
#   'ig': 2,
#   'snap': 3,
#   'location': 1,
#   'views': 11,
#   'blm': 1,
#   'type': 1,
#   'wha': 2,
#   'skeptical': 1,
#   'environmentalist': 1,
#   'takes': 10,
#   'controversial': 2,
#   'doc': 10,
#   'e': 7,
#   'acha': 1,
#   'que': 1,
#   'nada': 1,
#   'est': 2,
#   'acontecendo': 1,
#   'bbanimals': 1,
#   'effects': 9,
#   'associate': 1,
#   'lots': 3,
#   'poorlowerclass': 1,
#   'rocket': 2,
#   'beautiful': 5,
#   'outin': 1,
#   'february': 6,
#   'lolbut': 1,
#   'justsaying': 1,
#   'ctvtoront': 1,
#   'calis': 1,
#   'endless': 2,
#   'drought': 7,
#   'howstorms': 1,
#   'making': 11,
#   'dent': 1,
#   'californias': 1,
#   'feet': 1,
#   'opositive': 1,
#   'aashi': 1,
#   'iamwithmodiji': 1,
#   'lkoprem': 1,
#   'tum': 2,
#   'muskurae': 1,
#   'sheetal': 1,
#   'hawae': 1,
#   'chal': 1,
#   'gai': 1,
#   'sansar': 1,
#   'kaha': 1,
#   'hai': 1,
#   'stance': 3,
#   'hasnt': 3,
#   'moderated': 1,
#   'forecasterenten': 1,
#   'funny': 7,
#   'becomes': 1,
#   'president': 18,
#   'probablywonthappenbutwhoreallyknows': 1,
#   'aerialwav': 1,
#   'turns': 6,
#   'pin': 1,
#   'hopes': 1,
#   'given': 3,
#   'fires': 2,
#   'australia': 5,
#   'summer': 6,
#   'must': 21,
#   'cnazmul': 1,
#   'starting': 3,
#   'synthesizing': 1,
#   'reports': 3,
#   'community': 2,
#   'projects': 2,
#   'pksf': 1,
#   'saleemulhuq': 1,
#   'gobeshona': 1,
#   'icccad': 1,
#   'theres': 11,
#   'many': 12,
#   'liberal': 8,
#   'snowflakes': 3,
#   'scienceisntreal': 1,
#   'tomi': 1,
#   'lahren': 1,
#   'uspgglobal': 1,
#   'annual': 2,
#   'bray': 1,
#   'service': 1,
#   'founder': 1,
#   'focus': 6,
#   'wed': 1,
#   'feb': 1,
#   'london': 2,
#   'sinow': 1,
#   'sipetethamel': 1,
#   'sea': 10,
#   'came': 4,
#   'earlier': 6,
#   'thought': 17,
#   'wichita': 1,
#   'atlantic': 2,
#   'coast': 3,
#   'spended': 1,
#   'da': 4,
#   'servicing': 1,
#   'snowblowers': 1,
#   'shosleeves': 2,
#   'bright': 2,
#   'whoabrorelax': 1,
#   'hence': 1,
#   'findings': 1,
#   'dad': 4,
#   'really': 34,
#   'cwant': 1,
#   'destroy': 2,
#   'sirwilfreddeath': 1,
#   'alicewoolley': 1,
#   'bonnegreer': 1,
#   'bbc': 7,
#   'gives': 4,
#   'false': 4,
#   'equivalence': 1,
#   'arguments': 3,
#   'eff': 1,
#   'guys': 11,
#   'r': 11,
#   'advocating': 1,
#   'special': 7,
#   'role': 6,
#   'banksusing': 1,
#   'range': 2,
#   'instruments': 3,
#   'changerelated': 1,
#   'discl': 1,
#   'chemists': 1,
#   'find': 15,
#   'spoiling': 1,
#   'series': 6,
#   'causes': 15,
#   'allenwest': 1,
# ...
#   'need': 17,
#   'say': 26,
#   'realdonaldtrump': 70,
#   'carbon': 15,
#   'tax': 32,
#   'globalist': 4,
#   'idea': 5,
#   'enslave': 1,
#   'worlds': 4,
#   'population': 2,
#   'whole': 7,
#   'reason': 6,
#   'propagating': 2,
#   'global': 634,
#   'warming': 604,
#   'stevesgoddard': 44,
#   'winds': 1,
#   'close': 3,
#   'mph': 1,
#   'area': 3,
#   'afternoon': 2,
#   'would': 50,
#   'blame': 17,
#   'except': 4,
#   'happens': 4,
#   'pr': 4,
#   'misslizzynj': 4,
#   'lmao': 4,
#   'snowflakes': 11,
#   'complaining': 2,
#   'winter': 6,
#   'dawndawn': 1,
#   'one': 33,
#   'arnold': 1,
#   'schwarzeneggers': 1,
#   'vehicles': 1,
#   'whining': 1,
#   'changehows': 1,
#   'maidillegal': 1,
#   'orhttp': 1,
#   'fruitloopian': 1,
#   'snow': 17,
#   'march': 8,
#   'someone': 6,
#   'pls': 2,
#   'explain': 12,
#   'advocates': 2,
#   'tomilahren': 4,
#   'kinda': 2,
#   'funny': 6,
#   'professors': 1,
#   'talk': 6,
#   'shit': 11,
#   'trumpstersomg': 1,
#   'f': 7,
#   'scientist': 28,
#   'trumpserst': 1,
#   'idots': 1,
#   'shows': 3,
#   'base': 2,
#   'signordal': 1,
#   'new': 23,
#   'study': 9,
#   'terrible': 2,
#   'news': 36,
#   'alarmists': 20,
#   'good': 28,
#   'plants': 3,
#   'animals': 3,
#   'anurlweb': 1,
#   'https': 25,
#   'cbsnews': 1,
#   'youre': 12,
#   'going': 28,
#   'get': 25,
#   'away': 10,
#   'call': 14,
#   'every': 12,
#   'single': 4,
#   'time': 24,
#   'pages': 2,
#   'gone': 1,
#   'inc': 1,
#   'fake': 48,
#   'charliedaniels': 2,
#   'im': 20,
#   'worried': 11,
#   'terrified': 2,
#   'government': 9,
#   'hoax': 50,
#   'perpetrated': 3,
#   'chinese': 31,
#   'carbongate': 7,
#   'physicist': 3,
#   'co': 21,
#   'cause': 33,
#   'responds': 3,
#   'video': 6,
#   'agreed': 1,
#   'manmade': 45,
#   'innit': 1,
#   'tamorley': 1,
#   'zekejmiller': 1,
#   'isnt': 29,
#   'stuff': 2,
#   'hokum': 1,
#   'mikebeacham': 1,
#   'fed': 2,
#   'cooked': 8,
#   'books': 7,
#   'ahead': 5,
#   'obama': 41,
#   'presentation': 4,
#   'nomorescamsnomoredemocratsdraintheswamp': 1,
#   'http': 18,
#   'countermoonbat': 16,
#   'people': 57,
#   'predicted': 16,
#   'parts': 14,
#   'manhattan': 13,
#   'underwater': 14,
#   'due': 26,
#   'concerned': 17,
#   'zrastall': 1,
#   'fakenews': 4,
#   'mrbrexit': 1,
#   'looking': 3,
#   'ditch': 1,
#   'paris': 13,
#   'agreement': 7,
#   'bust': 2,
#   'open': 5,
#   'myth': 18,
#   'maga': 13,
#   'stepfo': 1,
#   'thinking': 3,
#   'thing': 15,
#   'goes': 5,
#   'important': 11,
#   'issues': 4,
#   'effect': 3,
#   'amer': 1,
#   'uniocracy': 3,
#   'theyll': 6,
#   'tell': 15,
#   'theyre': 7,
#   'save': 10,
#   'lying': 8,
#   'opchemtrails': 7,
#   'newsfakenews': 1,
#   'todd': 2,
#   'starnes': 2,
#   'hey': 11,
#   'npr': 2,
#   'take': 14,
#   'nonsense': 5,
#   'kids': 9,
#   'blow': 3,
#   'tailpipe': 2,
#   'nobamadotcom': 1,
#   'libbyrafferty': 1,
#   'bizpacreview': 2,
#   'left': 29,
#   'scream': 1,
#   'allegiance': 1,
#   'science': 77,
#   'issue': 13,
#   'concept': 26,
#   'created': 28,
#   'order': 27,
#   'make': 42,
#   'us': 63,
#   'manufacturing': 25,
#   'noncompetitive': 23,
#   'natural': 15,
#   'wins': 1,
#   'harmlessyarddog': 1,
#   'aged': 1,
#   'suing': 2,
#   'trump': 56,
#   'gtleftist': 1,
#   'disease': 1,
#   'selling': 2,
#   'scientific': 17,
#   'vs': 2,
#   'governments': 1,
#   'control': 14,
#   'everything': 11,
#   'terrifying': 1,
#   'public': 1,
#   'earthday': 1,
#   'sallykohn': 1,
#   'related': 1,
#   'paof': 6,
#   'larger': 1,
#   'pattern': 1,
#   'doesnt': 23,
#   'prove': 8,
#   'q': 1,
#   'much': 19,
#   'affect': 1,
#   'randomsavage': 1,
#   'frmatthewlc': 1,
#   'crazy': 7,
#   'two': 6,
#   'days': 5,
#   'ago': 11,
#   'bezerk': 1,
#   'blizzard': 5,
#   'hits': 3,
#   'katieworth': 1,
#   'story': 7,
#   'campaign': 1,
#   'persuade': 1,
#   'teacher': 1,
#   'debatable': 1,
#   'frontlinepbs': 1,
#   'evolution': 1,
#   'planet': 7,
#   'upset': 3,
#   'try': 5,
#   'stop': 25,
#   'albertstienstra': 1,
#   'climaterealists': 3,
#   'almost': 3,
#   'democrat': 2,
#   'vote': 3,
#   'young': 3,
#   'caused': 26,
#   'scaremongering': 1,
#   'indoct': 1,
#   'revkin': 1,
#   'got': 11,
#   'point': 9,
#   'still': 16,
#   'stupid': 4,
#   'absurd': 1,
#   'tornado': 1,
#   'hurricane': 4,
#   'etc': 5,
#   'result': 2,
#   'man': 53,
#   'made': 48,
#   'danieljhannan': 2,
#   'accept': 4,
#   'consensus': 7,
#   'often': 3,
#   'dismiss': 2,
#   'frackin': 1,
#   'tuckercarlson': 8,
#   'forget': 3,
#   'poverty': 3,
#   'exploding': 2,
#   'crime': 3,
#   'rate': 2,
#   'mayor': 4,
#   'orleans': 2,
#   'making': 14,
#   'top': 9,
#   'priorit': 1,
#   'jwilla': 1,
#   'sethmacfarlane': 2,
#   'real': 60,
#   'name': 6,
#   'weather': 29,
#   'changes': 4,
#   'naturally': 3,
#   'hope': 9,
#   'chance': 2,
#   'skip': 1,
#   'prisonplanet': 20,
#   'bunch': 10,
#   'oxford': 9,
#   'elitists': 9,
#   'want': 21,
#   'food': 11,
#   'poor': 11,
#   'fuck': 14,
#   'instead': 14,
#   'dineshdsouza': 7,
#   'thought': 7,
#   'day': 20,
#   'gender': 5,
#   'social': 2,
#   'constructwhich': 1,
#   'head': 7,
#   'maybe': 8,
#   'climatetruthnow': 2,
#   'george': 4,
#   'clooney': 2,
#   'claims': 11,
#   'must': 16,
#   'exist': 3,
#   'liberals': 30,
#   'agree': 11,
#   'exists': 5,
#   'kellyhinestw': 1,
#   'cold': 12,
#   'tulsa': 1,
#   'mich': 1,
#   'cool': 4,
#   'place': 4,
#   'miamibeachbowl': 1,
#   'bikerdave': 1,
#   'question': 11,
#   'al': 36,
#   'gore': 40,
#   'hell': 25,
#   'denier': 9,
#   'dispatch': 1,
#   'c': 10,
#   'fraud': 20,
#   'refuses': 5,
#   'debate': 8,
#   'usfreedomarmy': 9,
#   'understand': 5,
#   'globalism': 2,
#   'amp': 84,
#   'enlist': 13,
#   'gt': 3,
#   'act': 3,
#   'april': 5,
#   'yeah': 5,
#   'freezing': 17,
#   'outside': 21,
#   'generaleeintuit': 1,
#   'dcexaminer': 1,
#   'weathermen': 1,
#   'cant': 18,
#   'tomorrows': 2,
#   'right': 14,
#   'based': 5,
#   'data': 49,
#   'predict': 1,
#   'brentbozell': 2,
#   'rewrite': 1,
#   'history': 7,
#   'fit': 2,
#   'agenda': 16,
#   'journalist': 1,
#   'propagandist': 2,
#   'hrkbenowen': 5,
#   'horror': 3,
#   'chelsea': 2,
#   'clinton': 4,
#   'blames': 11,
#   'diabetes': 2,
#   'gets': 8,
#   'factchecked': 2,
#   'hard': 6,
#   'york': 4,
#   'times': 8,
#   'slammed': 1,
#   'cancellations': 1,
#   'punishment': 2,
#   'heresy': 1,
#   'nuclear': 9,
#   'weapons': 6,
#   'hands': 5,
#   'realjameswoods': 5,
#   'penises': 1,
#   'discuss': 1,
#   'spectator': 1,
#   'comment': 1,
#   'inconvenient': 4,
#   'truth': 14,
#   'eladhutch': 2,
#   'colors': 1,
#   'rainbow': 1,
#   'abortion': 5,
#   'choice': 1,
#   'liberallogic': 2,
#   'theeconomist': 1,
#   'wmo': 2,
#   'dont': 42,
#   'nature': 4,
#   'work': 2,
#   'wow': 6,
#   'yesco': 1,
#   'print': 1,
#   'seanspicier': 7,
#   'presidents': 2,
#   'regs': 2,
#   'california': 6,
#   'fall': 4,
#   'pacific': 1,
#   'weekend': 2,
#   'plans': 4,
#   'reagantman': 1,
#   'media': 11,
#   'falsely': 2,
#   'spins': 1,
#   'trumps': 8,
#   'nyt': 3,
#   'comments': 2,
#   'cited': 1,
#   'climategate': 2,
#   'restated': 1,
#   'skepticism': 3,
#   'nickdsmith': 1,
#   'fanatics': 5,
#   'frightened': 1,
#   'lord': 2,
#   'lawson': 1,
#   'tonight': 2,
#   'whens': 1,
#   'coming': 6,
#   'hmm': 1,
#   'qanda': 3,
#   'asking': 2,
#   'liberal': 21,
#   'anything': 7,
#   'energy': 9,
#   'policy': 6,
#   'coal': 3,
#   'cnn': 16,
#   'damned': 1,
#   'ice': 26,
#   'egypt': 1,
#   'first': 11,
#   'yearsthats': 1,
#   'ya': 2,
#   'cernovich': 5,
#   'experts': 7,
#   'said': 19,
#   'hillary': 9,
#   'win': 5,
#   'claim': 9,
#   'lol': 19,
#   'go': 18,
#   'morons': 9,
#   'know': 32,
#   'nothing': 20,
#   'los': 6,
#   'premierbradwall': 1,
#   'think': 29,
#   'justintrudeau': 2,
#   'buying': 6,
#   'gullibility': 1,
#   'canadians': 1,
#   'regarding': 1,
#   'eldobleem': 1,
#   'defend': 1,
#   'inventors': 1,
#   'runok': 1,
#   'lets': 6,
#   'focus': 4,
#   'pic': 2,
#   'independent': 2,
#   'rapes': 1,
#   'women': 6,
#   'wtf': 2,
#   'insane': 2,
#   'criminals': 1,
#   'today': 9,
#   'serious': 4,
#   'mental': 2,
#   'finally': 7,
#   'designed': 10,
#   'crooks': 3,
#   'crap': 9,
#   'anger': 2,
#   'conservative': 1,
#   'huamerican': 1,
#   'jobs': 9,
#   'insult': 1,
#   'crusade': 1,
#   'niatrump': 1,
#   'climatechange': 8,
#   'trillion': 7,
#   'earth': 22,
#   'tho': 2,
#   'age': 5,
#   'fatties': 1,
#   'johnkerry': 2,
#   'bullshit': 9,
#   'cofounder': 2,
#   'greenpeace': 2,
#   'even': 17,
#   'wrong': 7,
#   'suns': 1,
#   'activity': 4,
#   'samdastyari': 1,
#   'paulinehansonoz': 2,
#   'imagine': 2,
#   'hot': 13,
#   'otherwise': 2,
#   'gopchairwoman': 1,
#   'gop': 4,
#   'potus': 11,
#   'decision': 2,
#   'wasnt': 6,
#   'economics': 1,
#   'loss': 3,
#   'americans': 3,
#   'alyssamilano': 2,
#   'funding': 5,
#   'scam': 51,
#   'roncoleman': 1,
#   'didnt': 6,
#   'read': 13,
#   'assume': 1,
#   'warmingclimate': 2,
#   'antiscience': 3,
#   'become': 6,
#   'religion': 9,
#   'climatedepot': 7,
#   'repoabout': 3,
#   'antarctica': 4,
#   'horrible': 3,
#   'theblaze': 9,
#   'whistleblower': 6,
#   'admits': 10,
#   'scientists': 35,
#   'manipulated': 24,
#   'seem': 6,
#   'worse': 11,
#   'help': 6,
#   'cattharmony': 1,
#   'id': 4,
#   'rather': 7,
#   'marchforbabies': 1,
#   'nice': 3,
#   'paabout': 1,
#   'arms': 1,
#   'race': 3,
#   'middle': 1,
#   'east': 1,
#   'wont': 10,
#   'around': 9,
#   'really': 15,
#   'experience': 1,
#   'wr': 1,
#   'seanhannity': 4,
#   'probably': 4,
#   'shell': 1,
#   'voting': 1,
#   'candidate': 2,
#   'vagina': 1,
#   'radical': 9,
#   'low': 1,
#   'tiny': 1,
#   'state': 5,
#   'rallying': 1,
#   'issued': 1,
#   'healthcare': 2,
#   'industry': 2,
#   'sensanders': 7,
#   'normal': 3,
#   'planets': 4,
#   'process': 2,
#   'fooled': 2,
#   'lies': 8,
#   'thelanarchist': 1,
#   'geoengineering': 4,
#   'programs': 4,
#   'jets': 2,
#   'spraying': 1,
#   'arosols': 1,
#   'iluvspringtime': 1,
#   'send': 4,
#   'lots': 2,
#   'moneygrants': 1,
#   'research': 9,
#   'watch': 9,
#   'quickly': 1,
#   'fad': 1,
#   'disapp': 1,
#   'years': 43,
#   'minutes': 1,
#   'proof': 12,
#   'mtco': 1,
#   'debt': 3,
#   'morningjoe': 1,
#   'joenbc': 1,
#   'causing': 8,
#   'min': 2,
#   'wage': 1,
#   'cost': 4,
#   'libs': 9,
#   'clueless': 1,
#   'bring': 3,
#   'industrial': 1,
#   'back': 12,
#   'america': 14,
#   'federal': 6,
#   'whistle': 5,
#   'blower': 5,
#   'charges': 3,
#   'fox': 3,
#   'alarmist': 5,
#   'warn': 1,
#   'potent': 1,
#   'hurricanes': 5,
#   'anyone': 10,
#   'lecturing': 4,
#   'behind': 10,
#   'simultaneously': 1,
#   'thinks': 5,
#   'genders': 3,
#   'heritage': 2,
#   'president': 10,
#   'resist': 2,
#   'pressure': 2,
#   'foreign': 3,
#   'leaders': 27,
#   'cave': 1,
#   'joefreedomlove': 1,
#   'blog': 2,
#   'fights': 1,
#   'nowthisnews': 2,
#   'pure': 2,
#   'fantasy': 1,
#   'noaa': 12,
#   'caught': 5,
#   'altering': 1,
#   'temps': 2,
#   'surrender': 1,
#   'vestige': 1,
#   'interests': 1,
#   'past': 6,
#   'happened': 9,
#   'centuries': 1,
#   'rambogooner': 1,
#   'saying': 5,
#   'look': 14,
#   'sun': 7,
#   'thats': 14,
#   'lie': 10,
#   'thefoundingson': 1,
#   'temperature': 14,
#   'worsewhos': 1,
#   'surprised': 1,
#   'meurlweb': 2,
#   'georgialogcabin': 1,
#   'noaas': 1,
#   'manipulation': 3,
#   'economy': 4,
#   'national': 5,
#   'religious': 3,
#   'fundamentalism': 1,
#   'cult': 5,
#   'sprinkling': 1,
#   'markacollett': 1,
#   'biggest': 15,
#   'threat': 16,
#   'environment': 3,
#   'overpopulation': 1,
#   'fuelled': 1,
#   'aid': 2,
#   'thi': 1,
#   'davidicke': 2,
#   'founder': 3,
#   'channel': 7,
#   'blasts': 1,
#   'total': 5,
#   'run': 2,
#   'abc': 3,
#   'ass': 4,
#   'hat': 1,
#   'occurrence': 1,
#   'thousands': 3,
#   'jonozalay': 1,
#   'heres': 1,
#   'arctic': 8,
#   'proving': 3,
#   'changenot': 1,
#   'falling': 4,
#   'ithillary': 1,
#   'sex': 1,
#   'trafficking': 1,
#   'pizza': 1,
#   'parlor': 1,
#   'junkscience': 11,
#   'decide': 2,
#   'attribute': 2,
#   'events': 3,
#   'tengop': 4,
#   'dead': 3,
#   'london': 4,
#   'oh': 13,
#   'wait': 10,
#   'nope': 4,
#   'islamic': 4,
#   'terrorism': 8,
#   'againlondonattacks': 2,
#   'agency': 1,
#   'says': 19,
#   'common': 6,
#   'true': 5,
#   'aviwoolf': 1,
#   'leader': 2,
#   'free': 4,
#   'world': 34,
#   'syrian': 2,
#   'civil': 4,
#   'war': 7,
#   'cukoo': 1,
#   'land': 2,
#   'period': 1,
#   'donaldson': 1,
#   'standupforscience': 1,
#   'fact': 12,
#   'weve': 4,
#   'changing': 7,
#   'minds': 1,
#   'since': 15,
#   'foxnews': 12,
#   'ericbolling': 1,
#   'profitable': 3,
#   'hysteria': 7,
#   'business': 6,
#   'cashinin': 1,
#   'hairtrigga': 1,
#   'donlemon': 1,
#   'cnntonight': 1,
#   'big': 14,
#   'money': 36,
#   'never': 18,
#   'rampant': 1,
#   'pollution': 3,
#   'ok': 5,
#   'avid': 1,
#   'outdoorsman': 1,
#   'chucknellis': 1,
#   'revealed': 4,
#   'pope': 5,
#   'argentine': 1,
#   'jesuit': 1,
#   'liberation': 1,
#   'theology': 1,
#   'socialist': 2,
#   'firstclimate': 1,
#   'slaughter': 1,
#   'eugenevtooms': 1,
#   'rextilllerson': 2,
#   'cooling': 12,
#   'snowflake': 3,
#   'craigrbrittain': 2,
#   'acknowledging': 1,
#   'reports': 1,
#   'denying': 2,
#   'clima': 1,
#   'jimgilman': 1,
#   'joelquatro': 1,
#   'mistercarter': 1,
#   'uptownlinda': 1,
#   'washingtonpost': 4,
#   'admit': 1,
#   'yes': 12,
#   'sitting': 1,
#   'waiting': 1,
#   'delayed': 1,
#   'flight': 1,
#   'watching': 3,
#   'hrs': 1,
#   'theyve': 2,
#   'covered': 4,
#   'russia': 4,
#   'scientisttrump': 1,
#   'socalled': 6,
#   'differentiate': 1,
#   'occurring': 3,
#   'forever': 2,
#   'cha': 1,
#   'disavowtrump': 1,
#   'russwhitworth': 1,
#   'ill': 5,
#   'retweet': 2,
#   'shamelessly': 1,
#   'scandal': 1,
#   'fiddled': 1,
#   'climatescam': 3,
#   'greenscam': 1,
#   'teaparty': 1,
#   'tcot': 4,
#   'pjnet': 2,
#   'produces': 2,
#   'swings': 4,
#   'antarctic': 4,
#   'combat': 5,
#   'fing': 1,
#   'laugh': 2,
#   'efbiltg': 1,
#   'buterastrology': 1,
#   'holocaust': 1,
#   'eyes': 1,
#   'wake': 5,
#   'iturlweb': 1,
#   'hankgreen': 1,
#   'blamed': 4,
#   'indus': 1,
#   'valley': 1,
#   'civ': 1,
#   'agonot': 1,
#   'humans': 10,
#   'pray': 2,
#   'ivanka': 1,
#   'stopping': 3,
#   'pushing': 4,
#   'father': 2,
#   'meet': 4,
#   'face': 2,
#   'christamos': 1,
#   'steph': 1,
#   'mad': 1,
#   'buy': 2,
#   'anymore': 2,
#   'newday': 1,
#   'chriscuomo': 1,
#   'ten': 2,
#   'trying': 8,
#   'push': 5,
#   'implement': 1,
#   'carbo': 1,
#   'tombxm': 1,
#   'kick': 1,
#   'musclemilk': 1,
#   'vetsandplayers': 1,
#   'like': 41,
#   'called': 14,
#   'un': 15,
#   'meanwhile': 3,
#   'ignores': 3,
#   'november': 2,
#   'th': 7,
#   'played': 3,
#   'round': 2,
#   'golf': 1,
#   'love': 4,
#   'loudobbs': 3,
#   'app': 1,
#   'trumptrain': 1,
#   'dobbs': 1,
#   'bigstick': 1,
#   'breaking': 3,
#   'goburch': 1,
#   'aint': 4,
#   'believing': 5,
#   'bunk': 1,
#   'massive': 3,
#   'sorry': 5,
#   'popscience': 1,
#   'celebrities': 2,
#   'ever': 22,
#   'referred': 1,
#   'thoughts': 2,
#   'arent': 7,
#   'worth': 2,
#   'listening': 3,
#   'bbcnews': 1,
#   'bbctrust': 1,
#   'metoffice': 1,
#   'guardianeco': 1,
#   'profraud': 1,
#   'duped': 19,
#   'mailonline': 6,
#   'bad': 15,
#   'normally': 1,
#   'intelligent': 1,
#   'believes': 4,
#   'ending': 2,
#   'fault': 1,
#   'promised': 1,
#   'junk': 4,
#   'hes': 7,
#   'talking': 6,
#   'voted': 3,
#   'kwilli': 5,
#   'attention': 2,
#   'macron': 1,
#   'offers': 1,
#   'refugee': 1,
#   'status': 1,
#   'please': 7,
#   'move': 1,
#   'leave': 2,
#   'usa': 5,
#   'asap': 1,
#   'tan': 10,
#   'apple': 1,
#   'could': 6,
#   'political': 9,
#   'blitz': 1,
#   'ios': 1,
#   'users': 1,
#   'mythinnoculations': 1,
#   'autismgeorge': 1,
#   'bush': 1,
#   'genius': 1,
#   'kcjw': 2,
#   'dr': 4,
#   'roger': 1,
#   'pielke': 1,
#   'jr': 1,
#   'link': 2,
#   'extreme': 2,
#   'feedly': 2,
#   'abrahamengel': 1,
#   'julessu': 1,
#   'railboy': 1,
#   'inches': 3,
#   'cheyenne': 1,
#   'wyo': 2,
#   'laramie': 1,
#   'weekalgore': 1,
#   'unavailable': 1,
#   'rick': 4,
#   'perry': 4,
#   'urges': 1,
#   'conversation': 1,
#   'unsettled': 1,
#   'antitrumpmvmt': 1,
#   'appears': 1,
#   'grow': 1,
#   'hktkplanet': 1,
#   'origuk': 1,
#   'scitht': 1,
#   'ranwthr': 1,
#   'invent': 1,
#   'warmingccfake': 1,
#   'hve': 1,
#   'admitted': 2,
#   'liedampfak': 1,
#   'rickstuaconcussion': 1,
#   'changeit': 1,
#   'realstop': 1,
#   'doctorsif': 1,
#   'sciencecelebs': 1,
#   'next': 9,
#   'libtards': 2,
#   'animal': 1,
#   'extinctions': 1,
#   'unicornsarereal': 1,
#   'cnnpolitics': 2,
#   'use': 8,
#   'bs': 6,
#   'leahrboss': 6,
#   'lefts': 3,
#   'meltdown': 5,
#   'whywemustimpeachtrumpinwords': 1,
#   'fukn': 1,
#   'traps': 1,
#   'spew': 1,
#   'air': 4,
#   'courlweb': 1,
#   'adjusting': 1,
#   'match': 2,
#   'theory': 10,
#   'charliekirk': 4,
#   'however': 3,
#   'notice': 3,
#   'changed': 10,
#   'graphs': 1,
#   'produce': 2,
#   'grade': 2,
#   'math': 1,
#   'ciphers': 1,
#   'makada': 4,
#   'warned': 2,
#   'storm': 5,
#   'late': 1,
#   'mikehudema': 1,
#   'three': 2,
#   'towns': 1,
#   'coastlines': 1,
#   'eroding': 1,
#   'needs': 3,
#   'repeat': 1,
#   'rd': 2,
#   'g': 2,
#   'trumpnewyorker': 1,
#   'noncompetitiv': 1,
#   'licialopez': 1,
#   'believe': 46,
#   'least': 5,
#   'well': 11,
#   'though': 2,
#   'election': 7,
#   'lost': 9,
#   'biglybeaglehaus': 1,
#   'burkeanbeer': 1,
#   'kurteichenwald': 1,
#   'cspanwj': 1,
#   'presidenttrump': 2,
#   'jessiejaneduff': 2,
#   'mccarthy': 3,
#   'drove': 1,
#   'obamasclimate': 1,
#   ...}}

# %%
all_words = set()
for pp in type_labels:
    for word in beliver[pp]:
        all_words.add(word)

# %%
beliver['all'] = {}
for pp in type_labels:    
    for word in all_words:
        if word in beliver[pp].keys():
            if word in beliver['all']:
                beliver['all'][word] += beliver[pp][word]
            else:
                beliver['all'][word] = beliver[pp][word]

# %%
beliver
# Out:
# {1: {'polyscimajor': 1,
#   'epa': 271,
#   'chief': 66,
#   'doesnt': 785,
#   'think': 236,
#   'carbon': 98,
#   'dioxide': 35,
#   'main': 25,
#   'cause': 108,
#   'global': 1593,
#   'warming': 1430,
#   'wait': 25,
#   'urlweb': 4014,
#   'via': 199,
#   'mashable': 19,
#   'like': 310,
#   'lack': 15,
#   'evidence': 74,
#   'anthropogenic': 10,
#   'todayinmaker': 1,
#   'wired': 14,
#   'pivotal': 3,
#   'year': 84,
#   'war': 60,
#   'climate': 7340,
#   'change': 7077,
#   'soynoviodetodas': 1,
#   'racist': 31,
#   'sexist': 12,
#   'denying': 120,
#   'bigot': 6,
#   'leading': 60,
#   'polls': 4,
#   'electionnight': 8,
#   'worth': 12,
#   'read': 70,
#   'whether': 34,
#   'dont': 386,
#   'believe': 1004,
#   'thenation': 2,
#   'mike': 8,
#   'pence': 10,
#   'smoking': 5,
#   'causes': 40,
#   'lung': 1,
#   'cancer': 3,
#   'makeandmendlife': 1,
#   'six': 11,
#   'big': 88,
#   'things': 78,
#   'today': 107,
#   'fight': 286,
#   'activist': 4,
#   'h': 29,
#   'aceofspadeshq': 1,
#   'yo': 11,
#   'nephew': 1,
#   'inconsolable': 1,
#   'wants': 70,
#   'die': 394,
#   'old': 48,
#   'age': 33,
#   'perish': 1,
#   'fiery': 1,
#   'hellscape': 1,
#   'paigetweedy': 1,
#   'offense': 3,
#   'stephenschlegel': 307,
#   'shes': 627,
#   'thinking': 338,
#   'going': 590,
#   'husband': 312,
#   'hope': 72,
#   'people': 454,
#   'vocal': 1,
#   'also': 117,
#   'powering': 1,
#   'homes': 4,
#   'renewable': 24,
#   'energy': 113,
#   'goodenergy': 2,
#   'alifaith': 1,
#   'oh': 29,
#   'godtrumps': 1,
#   'government': 66,
#   'removes': 4,
#   'page': 22,
#   'website': 41,
#   'hours': 3,
#   'ahead': 9,
#   'climatemarchurlweb': 1,
#   'glblctzn': 6,
#   'wan': 27,
#   'na': 66,
#   'live': 35,
#   'forever': 1,
#   'nothing': 55,
#   'taylorswift': 1,
#   'zaynmalik': 1,
#   'jackholmes': 1,
#   'issues': 49,
#   'scrubbed': 1,
#   'civil': 13,
#   'rights': 82,
#   'lgbt': 25,
#   'healthcare': 23,
#   'patagonia': 6,
#   'elected': 70,
#   'leaders': 46,
#   'fail': 13,
#   'approach': 18,
#   'environment': 108,
#   'amp': 659,
#   'serious': 47,
#   'worthy': 5,
#   'urgency': 10,
#   'action': 201,
#   'wi': 13,
#   'sensanders': 248,
#   'presidentelect': 193,
#   'millions': 154,
#   'say': 246,
#   'mr': 151,
#   'ccities': 21,
#   'c': 57,
#   'mayors': 6,
#   'representing': 3,
#   'citizens': 16,
#   'urged': 1,
#   'g': 22,
#   'saveourplanet': 1,
#   'worldwildlife': 10,
#   'impacts': 73,
#   'wildlife': 12,
#   'cop': 83,
#   'earthtomarrakech': 9,
#   'urlwebscientists': 1,
#   'wiped': 5,
#   'entire': 31,
#   'underwater': 15,
#   'ecosystem': 8,
#   'againclimate': 1,
#   'tammygrubb': 1,
#   'obama': 44,
#   'raises': 3,
#   'better': 49,
#   'vote': 81,
#   'candidates': 5,
#   'science': 236,
#   'obamaunc': 1,
#   'hate': 21,
#   'mental': 4,
#   'health': 75,
#   'pretty': 17,
#   'low': 8,
#   'menu': 2,
#   'hits': 9,
#   'food': 47,
#   'production': 16,
#   'hey': 38,
#   'michaels': 1,
#   'vetted': 1,
#   'approved': 2,
#   'marketbased': 2,
#   'strategies': 6,
#   'tackling': 35,
#   'supported': 7,
#   'majority': 29,
#   'cdns': 1,
#   'cdnpoli': 5,
#   'startalkradio': 1,
#   'first': 126,
#   'public': 41,
#   'understands': 13,
#   'congress': 18,
#   'johnholdren': 1,
#   'corybooker': 3,
#   'neiltyson': 8,
#   'explain': 29,
#   'htt': 129,
#   'honey': 5,
#   'guide': 2,
#   'paris': 58,
#   'pact': 6,
#   'us': 445,
#   'role': 39,
#   'demforce': 1,
#   'theresistance': 7,
#   'uniteblue': 2,
#   'ignores': 8,
#   'basic': 7,
#   'bgr': 1,
#   'china': 105,
#   'practically': 1,
#   'says': 124,
#   'trump': 889,
#   'lied': 9,
#   'berniesanders': 124,
#   'imvotingbecause': 62,
#   'future': 154,
#   'planet': 186,
#   'stake': 70,
#   'hillary': 85,
#   'clinton': 81,
#   'combat': 133,
#   'donald': 194,
#   'thinks': 219,
#   'deborahehatoxic': 1,
#   'soils': 11,
#   'aquifers': 1,
#   'vast': 4,
#   'amts': 1,
#   'wasted': 6,
#   'waste': 31,
#   'water': 90,
#   'runaway': 5,
#   'paof': 37,
#   'gas': 21,
#   'fracking': 14,
#   'bettybowers': 1,
#   'america': 111,
#   'unproven': 1,
#   'sure': 29,
#   'guy': 41,
#   'called': 52,
#   'noah': 2,
#   'fit': 3,
#   'worlds': 50,
#   'animals': 25,
#   'hi': 7,
#   'foramerica': 1,
#   'protested': 1,
#   'suppoof': 5,
#   'womansmarch': 1,
#   'pato': 3,
#   'help': 126,
#   'https': 275,
#   'thedailybeast': 4,
#   'trumps': 191,
#   'denial': 124,
#   'could': 135,
#   'cost': 26,
#   'trillion': 5,
#   'anyone': 30,
#   'supports': 17,
#   'view': 25,
#   'non': 1,
#   'polluter': 6,
#   'cronie': 1,
#   'please': 77,
#   'step': 24,
#   'forward': 23,
#   'resist': 17,
#   'impeach': 3,
#   'hes': 78,
#   'president': 207,
#   'united': 45,
#   'states': 68,
#   'fuck': 29,
#   'kelkulus': 11,
#   'irony': 13,
#   'florida': 60,
#   'state': 48,
#   'danger': 26,
#   'washed': 13,
#   'away': 30,
#   'due': 112,
#   'rising': 44,
#   'sea': 68,
#   'levels': 40,
#   'denies': 85,
#   'greenpeaceeasia': 1,
#   'pollution': 46,
#   'india': 20,
#   'reached': 6,
#   'stratosphere': 1,
#   'speed': 6,
#   'unep': 18,
#   'citiesclimfin': 1,
#   'lays': 2,
#   'cities': 68,
#   'subnational': 1,
#   'bodies': 2,
#   'finance': 1,
#   'solutions': 41,
#   'hoax': 318,
#   'though': 16,
#   'two': 21,
#   'cents': 2,
#   'political': 50,
#   'leadership': 29,
#   'era': 5,
#   'motherjones': 11,
#   'races': 4,
#   'watch': 152,
#   'care': 103,
#   'profpcdoherty': 1,
#   'need': 235,
#   'economists': 1,
#   'incorporate': 2,
#   'reality': 48,
#   'listen': 40,
#   'ushrn': 1,
#   'human': 89,
#   'facing': 21,
#   'disastrous': 3,
#   'ahamiltonspirit': 1,
#   'question': 25,
#   'manmade': 45,
#   'doubts': 5,
#   'havent': 9,
#   'seen': 14,
#   'inconvenient': 10,
#   'truth': 30,
#   'alphageekstr': 1,
#   'process': 4,
#   'occurs': 1,
#   'naturally': 2,
#   'extreme': 35,
#   'well': 92,
#   'eventually': 4,
#   'severe': 9,
#   'droughts': 10,
#   'roschneider': 1,
#   'neoliberalism': 8,
#   'conned': 7,
#   'fighting': 102,
#   'individuals': 10,
#   'martin': 10,
#   'lukacs': 4,
#   'davidsirota': 19,
#   'must': 164,
#   'rick': 18,
#   'perry': 21,
#   'ordered': 3,
#   'texas': 14,
#   'legislature': 1,
#   'kill': 46,
#   'bill': 29,
#   'requiring': 2,
#   'agencies': 6,
#   'prepare': 13,
#   'thats': 132,
#   'frightening': 38,
#   'country': 108,
#   'world': 446,
#   'hot': 30,
#   'verge': 9,
#   'google': 12,
#   'earths': 12,
#   'timelapse': 7,
#   'update': 4,
#   'illustrates': 3,
#   'years': 133,
#   'sethmacfarlane': 66,
#   'hrc': 62,
#   'proposes': 57,
#   'installing': 56,
#   'half': 74,
#   'billion': 82,
#   'solar': 73,
#   'panels': 60,
#   'end': 121,
#   'term': 70,
#   'beforetheflood': 145,
#   'everyone': 53,
#   'understand': 47,
#   'real': 502,
#   'leodicaprio': 122,
#   'shake': 1,
#   'ever': 58,
#   'earthjustice': 3,
#   'noaa': 15,
#   'repo': 2,
#   'nd': 13,
#   'hottest': 21,
#   'history': 26,
#   'one': 172,
#   'reason': 28,
#   'deniers': 179,
#   'admin': 25,
#   'gt': 12,
#   'conservatives': 29,
#   'love': 25,
#   'huh': 6,
#   'believing': 17,
#   'fertilization': 1,
#   'egg': 2,
#   'automatic': 1,
#   'life': 22,
#   'come': 42,
#   'check': 32,
#   'events': 14,
#   'srhpl': 1,
#   'million': 21,
#   'gone': 17,
#   'towards': 17,
#   'alleviating': 1,
#   'poverty': 22,
#   'reducing': 11,
#   'improving': 3,
#   'call': 47,
#   'mad': 11,
#   'ronaldklain': 1,
#   'decides': 2,
#   'briancdeese': 1,
#   'team': 24,
#   'washingtonpost': 27,
#   'warn': 5,
#   'epidemics': 1,
#   'savingoceans': 2,
#   'potentially': 2,
#   'hufuture': 1,
#   'fishermen': 3,
#   'jobs': 52,
#   'yet': 55,
#   'another': 64,
#   'advisor': 7,
#   'clueless': 5,
#   'climateprogress': 6,
#   'director': 8,
#   'denier': 186,
#   'coal': 54,
#   'lobbies': 1,
#   'deputy': 3,
#   'irisrimon': 1,
#   'chinese': 157,
#   'broke': 12,
#   'massive': 15,
#   'iceberg': 9,
#   'antarctica': 10,
#   'ndenicolamd': 1,
#   'doctors': 5,
#   'agree': 52,
#   'making': 56,
#   'sick': 12,
#   'earthday': 12,
#   'marchforscience': 8,
#   'healthandclimate': 1,
#   'tristinc': 2,
#   'made': 69,
#   'vice': 9,
#   'gay': 25,
#   'curable': 2,
#   'disease': 7,
#   'looking': 30,
#   'officially': 10,
#   'believes': 90,
#   'sorry': 23,
#   'everybody': 11,
#   'else': 18,
#   'realdonaldtrump': 163,
#   'potus': 43,
#   'fucking': 46,
#   'idiot': 13,
#   'im': 178,
#   'geologist': 1,
#   'studied': 4,
#   'college': 11,
#   'coauthored': 1,
#   'papers': 2,
#   'natgeochannel': 122,
#   'right': 195,
#   'travels': 76,
#   'tackle': 126,
#   'peta': 6,
#   'meat': 27,
#   'deforestation': 21,
#   'extinction': 20,
#   'worldveganday': 5,
#   'lexiprez': 2,
#   'literally': 51,
#   'denierrip': 1,
#   'kloppholic': 3,
#   'imagine': 22,
#   'trying': 29,
#   'convince': 11,
#   'isnt': 197,
#   'instead': 40,
#   'conspiracy': 23,
#   'wake': 16,
#   'docrock': 1,
#   'saying': 47,
#   'every': 94,
#   'major': 72,
#   'scientific': 56,
#   'organization': 5,
#   'follow': 15,
#   'projectarcc': 2,
#   'want': 134,
#   'hear': 25,
#   'av': 1,
#   'digital': 5,
#   'archivists': 1,
#   'activism': 1,
#   'avhack': 1,
#   'look': 89,
#   'polar': 34,
#   'bears': 25,
#   'extinct': 11,
#   'land': 10,
#   'antivaccersclimate': 1,
#   'deniersaca': 1,
#   'killers': 1,
#   'stop': 164,
#   'using': 18,
#   'stupidity': 4,
#   'try': 24,
#   'kil': 1,
#   'see': 130,
#   'way': 92,
#   'aveclimate': 2,
#   'apply': 6,
#   'method': 3,
#   'samjamesvelde': 2,
#   'degrees': 84,
#   'early': 9,
#   'november': 53,
#   'los': 4,
#   'angeles': 2,
#   'know': 190,
#   'according': 12,
#   'artclimate': 1,
#   'larsenc': 1,
#   'climatechangeaurlweb': 1,
#   'youths': 3,
#   'almost': 29,
#   'kenyas': 1,
#   'pop': 3,
#   'best': 59,
#   'line': 17,
#   'defense': 27,
#   'securityrobertmburia': 1,
#   'richardmunang': 7,
#   'geographerjay': 1,
#   'nasa': 54,
#   'research': 62,
#   'estate': 3,
#   'markets': 3,
#   'stato': 4,
#   'slump': 1,
#   'jeffdsachs': 2,
#   'cnn': 60,
#   'panelists': 1,
#   'erupt': 1,
#   'video': 22,
#   'time': 141,
#   'lies': 9,
#   'koch': 5,
#   'brothers': 3,
#   'heritage': 3,
#   'worried': 33,
#   'effect': 24,
#   'methane': 10,
#   'greater': 5,
#   'thought': 23,
#   'physorgcom': 2,
#   'astrokatie': 27,
#   'governments': 8,
#   'several': 4,
#   'powers': 2,
#   'failing': 11,
#   'act': 71,
#   'without': 45,
#   'kamalaharris': 38,
#   'stand': 36,
#   'jerrybrowngov': 12,
#   'california': 32,
#   'back': 76,
#   'steveengland': 1,
#   'u': 81,
#   'considered': 4,
#   'piece': 15,
#   'column': 6,
#   'steve': 6,
#   'inform': 2,
#   'ppl': 36,
#   'impact': 62,
#   'species': 32,
#   'habitats': 2,
#   'benwikler': 1,
#   'worry': 41,
#   'natural': 42,
#   'rendering': 2,
#   'earth': 150,
#   'uninhabitable': 4,
#   'alanresnicks': 1,
#   'horsemen': 1,
#   'apocalypse': 3,
#   'famine': 9,
#   'death': 12,
#   'pestilence': 1,
#   'hawaiidelilah': 2,
#   'went': 11,
#   'ivanka': 9,
#   'reporter': 1,
#   'insights': 3,
#   'scientists': 170,
#   'women': 63,
#   'expertis': 1,
#   'wqs': 1,
#   'pakistan': 10,
#   'th': 44,
#   'vulnerable': 24,
#   'terms': 13,
#   'whats': 30,
#   'experienced': 6,
#   'prime': 4,
#   'minister': 9,
#   'ajb': 1,
#   'knock': 1,
#   'brexit': 7,
#   'bury': 4,
#   'issuesbut': 1,
#   'really': 133,
#   'w': 53,
#   'drop': 5,
#   'dead': 19,
#   'nobel': 2,
#   'scientist': 49,
#   'ignorance': 17,
#   'shocking': 8,
#   'lastweektonight': 16,
#   'silly': 16,
#   'issue': 112,
#   'give': 73,
#   'resources': 56,
#   'council': 17,
#   'deanofcomedy': 4,
#   'followed': 2,
#   'closely': 3,
#   'wall': 19,
#   'street': 5,
#   'executives': 3,
#   'sdg': 3,
#   'take': 147,
#   'urgent': 20,
#   'join': 75,
#   'movement': 11,
#   'bradleym': 1,
#   'juddlegum': 3,
#   'kid': 4,
#   'changekid': 1,
#   'fact': 70,
#   'matte': 1,
#   'calls': 34,
#   'bad': 58,
#   'billmckibben': 22,
#   'exxonmobil': 9,
#   'long': 23,
#   'peddling': 2,
#   'misinformation': 6,
#   'elizkolbein': 1,
#   'newyorker': 2,
#   'exxonknew': 9,
#   'mrdenmore': 4,
#   'apafrom': 4,
#   'taking': 53,
#   'brink': 1,
#   'recession': 1,
#   'doubling': 2,
#   'deficit': 1,
#   'pariah': 3,
#   'refugees': 14,
#   'easiest': 4,
#   'ways': 41,
#   'daily': 19,
#   'eating': 15,
#   'beef': 7,
#   'heres': 94,
#   'effects': 93,
#   'marcuschown': 1,
#   'white': 65,
#   'house': 50,
#   'deal': 56,
#   'catastrophe': 13,
#   'threatens': 14,
#   'argue': 13,
#   'new': 283,
#   'turnscoat': 1,
#   'cant': 113,
#   'number': 18,
#   'priority': 10,
#   'mobilizeclimate': 2,
#   'treating': 5,
#   'far': 28,
#   'doomsday': 2,
#   'nowurlweb': 1,
#   'jacobwhitesides': 4,
#   'christmas': 16,
#   'chejackson': 1,
#   'anything': 34,
#   'columbus': 1,
#   'rex': 14,
#   'tillerson': 17,
#   'refuses': 11,
#   'admit': 11,
#   'decades': 27,
#   'ago': 27,
#   'huffpostpol': 14,
#   'wakmax': 1,
#   'talk': 87,
#   'alicebell': 2,
#   'itll': 5,
#   'make': 160,
#   'feel': 18,
#   'go': 94,
#   'duycks': 1,
#   'tomorrow': 12,
#   'event': 9,
#   'childrenrights': 1,
#   'context': 8,
#   'key': 31,
#   'message': 15,
#   'protect': 45,
#   'empower': 3,
#   'boost': 4,
#   'funding': 30,
#   'developing': 4,
#   'countries': 54,
#   'adapt': 14,
#   'paulhbeckwith': 2,
#   'folks': 10,
#   'storyabout': 1,
#   'evil': 3,
#   'twinof': 1,
#   'changethe': 2,
#   'oceans': 20,
#   'acidurlweb': 1,
#   'adriangeolopez': 1,
#   'still': 165,
#   'especially': 15,
#   'pulling': 3,
#   'p': 24,
#   'fitness': 1,
#   'late': 20,
#   'reverse': 18,
#   'warmingampquot': 1,
#   'scholaurship': 1,
#   'motherfucker': 1,
#   'arizonapatriot': 1,
#   'joelpollak': 1,
#   'gabyendingstory': 1,
#   'least': 23,
#   'christianextremist': 1,
#   'evolution': 28,
#   'hoaxes': 3,
#   'natgeophotos': 3,
#   'although': 4,
#   'scary': 18,
#   'topic': 9,
#   'ice': 85,
#   'insanely': 1,
#   'unimaginably': 1,
#   'beautifulurlweb': 1,
#   'everyones': 4,
#   'something': 49,
#   'progressive': 7,
#   'env': 3,
#   'exxon': 38,
#   'hero': 2,
#   'kicked': 1,
#   'saving': 5,
#   'selected': 1,
#   'money': 41,
#   'include': 5,
#   'job': 16,
#   'losses': 3,
#   'business': 26,
#   'interruptions': 1,
#   'worsening': 9,
#   'working': 38,
#   'un': 55,
#   'cnvey': 9,
#   'taylorandbrown': 1,
#   'thing': 96,
#   'bothers': 2,
#   'defund': 2,
#   'illuminateboys': 1,
#   'politicians': 39,
#   'fake': 47,
#   'jamespeshaw': 2,
#   'nzgreens': 2,
#   'gets': 26,
#   'zealand': 4,
#   'clean': 52,
#   'shadbase': 2,
#   'conversationedu': 2,
#   'turtles': 1,
#   'around': 62,
#   'pace': 4,
#   'existential': 10,
#   'challenge': 25,
#   'lawlib': 1,
#   'board': 11,
#   'bouncing': 3,
#   'ideas': 15,
#   'interested': 10,
#   'lisalsong': 1,
#   'horrifying': 6,
#   'outcomes': 1,
#   'stevevsninjas': 1,
#   'f': 18,
#   'liethats': 1,
#   'data': 56,
#   'point': 45,
#   'met': 8,
#   'concluded': 4,
#   'men': 11,
#   'speak': 15,
#   'englis': 1,
#   'sierraclubwi': 1,
#   'pollutingpruitt': 7,
#   'subject': 6,
#   'continued': 5,
#   'debate': 56,
#   'climatefacts': 3,
#   'yayitsrob': 4,
#   'twostep': 1,
#   'kinda': 3,
#   'moderate': 3,
#   'extremely': 7,
#   'radical': 4,
#   'race': 15,
#   'curb': 17,
#   'outpace': 1,
#   'governmentsparisagreement': 1,
#   'globalcovenant': 1,
#   'citiesclimateurlweb': 1,
#   'jellybeatles': 1,
#   'climatehome': 2,
#   'week': 22,
#   'save': 58,
#   'talks': 11,
#   'aleszubajak': 1,
#   'chile': 1,
#   'space': 9,
#   'threatening': 8,
#   'multiple': 2,
#   'shapes': 1,
#   'michaelawat': 2,
#   'much': 64,
#   'department': 11,
#   'office': 13,
#   'bans': 6,
#   'use': 42,
#   'phrase': 6,
#   'classicgrrl': 1,
#   'nuclear': 51,
#   'annihilation': 1,
#   'slowly': 4,
#   'wondering': 15,
#   'climatechange': 114,
#   'billnye': 9,
#   'francehillary': 1,
#   'agent': 3,
#   'ignoring': 27,
#   'benefits': 6,
#   'helps': 11,
#   'weak': 5,
#   'named': 3,
#   'lead': 47,
#   'agency': 8,
#   'fights': 9,
#   'proud': 12,
#   'represent': 8,
#   'finding': 6,
#   'creative': 2,
#   'changeurlweb': 19,
#   'palmerreponodapl': 1,
#   'golden': 2,
#   'gate': 2,
#   'park': 15,
#   'joins': 4,
#   'badlands': 4,
#   'national': 69,
#   'defying': 5,
#   'tweeting': 11,
#   'creationists': 2,
#   'never': 38,
#   'listened': 2,
#   'nye': 14,
#   'fusion': 31,
#   'become': 32,
#   'leader': 76,
#   'watching': 18,
#   'scott': 89,
#   'pruitt': 116,
#   'nonsense': 5,
#   'raising': 31,
#   'bp': 2,
#   'fool': 5,
#   'parisagreement': 52,
#   'watched': 6,
#   'get': 130,
#   'worse': 40,
#   'ralphnortham': 1,
#   'biggest': 66,
#   'opponent': 1,
#   'changeits': 3,
#   'followernodad': 21,
#   'parent': 16,
#   'id': 24,
#   'childrenscientist': 15,
#   'stave': 17,
#   'children': 33,
#   'stay': 28,
#   'voxdotcom': 21,
#   'election': 44,
#   'marks': 11,
#   'limiting': 15,
#   'moron': 12,
#   'lol': 26,
#   'cineversitytv': 1,
#   'ff': 4,
#   'corrupt': 10,
#   'co': 94,
#   'fossil': 45,
#   'fuels': 19,
#   'scoopit': 1,
#   'iansomerhalder': 24,
#   'speaking': 22,
#   'changetonight': 11,
#   'killer': 13,
#   'episode': 14,
#   'yearsofliving': 23,
#   'concept': 47,
#   'created': 72,
#   'order': 62,
#   'manufacturing': 46,
#   'noncompetiti': 44,
#   'per': 7,
#   'cent': 1,
#   'sad': 32,
#   'head': 86,
#   'suggests': 3,
#   'primary': 37,
#   'contributor': 46,
#   'engadget': 1,
#   'cmon': 2,
#   'nhla': 1,
#   'efforts': 32,
#   'markmagana': 1,
#   'nhlamember': 1,
#   'greenlatino': 1,
#   'latinopriorities': 1,
#   'ddlovato': 33,
#   'ivotedbecause': 33,
#   'equality': 47,
#   'comprehensive': 33,
#   'immigration': 40,
#   'reform': 50,
#   'prochoice': 33,
#   'magnitude': 4,
#   'looks': 64,
#   'meteorite': 1,
#   'strike': 2,
#   'gradual': 1,
#   'renewables': 17,
#   'crucia': 1,
#   'brentsullivan': 1,
#   'climatehawk': 36,
#   'shell': 10,
#   'deny': 107,
#   'put': 42,
#   'profit': 11,
#   'joshgad': 5,
#   'mourning': 5,
#   'stage': 8,
#   'putting': 21,
#   'kids': 52,
#   'standup': 3,
#   'globalgoals': 5,
#   'directly': 13,
#   'linked': 12,
#   'crucial': 14,
#   'achieve': 3,
#   'senfeinstein': 3,
#   'breaking': 9,
#   'senate': 11,
#   'appropriations': 1,
#   'committee': 14,
#   'voted': 52,
#   'restore': 4,
#   'vital': 12,
#   'panela': 1,
#   'victo': 1,
#   'epascottpruitt': 26,
#   'drives': 14,
#   'lets': 79,
#   'send': 15,
#   'copy': 10,
#   'dummies': 8,
#   'twelve': 1,
#   'bloody': 1,
#   'shit': 30,
#   'sleep': 3,
#   'raining': 8,
#   'brought': 12,
#   'michaelpielocik': 1,
#   ...},
#  2: {'rawstory': 5,
#   'researchers': 28,
#   'say': 66,
#   'three': 6,
#   'years': 60,
#   'act': 17,
#   'climate': 3345,
#   'change': 3206,
#   'late': 8,
#   'urlweb': 3921,
#   'tveitdal': 10,
#   'percent': 9,
#   'chance': 6,
#   'avoiding': 4,
#   'dangerous': 20,
#   'global': 508,
#   'warming': 436,
#   'study': 98,
#   'finds': 32,
#   'fossil': 8,
#   'fuel': 5,
#   'giant': 7,
#   'exxonmobil': 12,
#   'misled': 9,
#   'public': 20,
#   'harvard': 12,
#   'academics': 2,
#   'conclude': 2,
#   'bangladesh': 5,
#   'confronting': 1,
#   'head': 76,
#   'latimes': 22,
#   'atmospheric': 2,
#   'rivers': 3,
#   'fueled': 4,
#   'could': 133,
#   'decimate': 2,
#   'wild': 5,
#   'oysters': 5,
#   'san': 7,
#   'francisco': 5,
#   'bay': 8,
#   'independent': 52,
#   'trumps': 238,
#   'team': 32,
#   'removed': 5,
#   'data': 31,
#   'white': 55,
#   'house': 69,
#   'website': 64,
#   'may': 93,
#   'breaking': 22,
#   'law': 15,
#   'targets': 8,
#   'nations': 17,
#   'playing': 1,
#   'long': 2,
#   'game': 7,
#   'fighting': 24,
#   'via': 299,
#   'conversationedu': 3,
#   'washingtonpost': 45,
#   'alaskan': 3,
#   'tundra': 2,
#   'filling': 1,
#   'atmosphere': 7,
#   'carbon': 79,
#   'dioxide': 56,
#   'worsening': 1,
#   'thetorontosun': 1,
#   'sunlorrie': 2,
#   'indian': 12,
#   'environmentalist': 3,
#   'calls': 53,
#   'dicaprio': 13,
#   'documentary': 5,
#   'starbuck': 1,
#   'world': 114,
#   'food': 20,
#   'supplies': 4,
#   'risk': 29,
#   'threatens': 13,
#   'international': 21,
#   'trade': 28,
#   'warn': 19,
#   'experts': 44,
#   'foxnews': 14,
#   'macron': 13,
#   'charm': 1,
#   'changed': 3,
#   'mind': 10,
#   'republicans': 22,
#   'real': 39,
#   'time': 47,
#   'fight': 159,
#   'ninaburleighurlweb': 1,
#   'kylegriffin': 9,
#   'nyt': 5,
#   'reviewed': 1,
#   'draft': 3,
#   'rpt': 1,
#   'fed': 1,
#   'scientists': 178,
#   'directly': 3,
#   'contradicting': 2,
#   'admins': 2,
#   'claims': 19,
#   'https': 80,
#   'bbcbreaking': 6,
#   'uk': 39,
#   'government': 55,
#   'signs': 36,
#   'paris': 109,
#   'agreement': 81,
#   'worlds': 39,
#   'first': 26,
#   'comprehensive': 5,
#   'treaty': 11,
#   'tackling': 23,
#   'us': 293,
#   'environmental': 30,
#   'agency': 36,
#   'chief': 100,
#   'says': 234,
#   'humans': 25,
#   'contribute': 2,
#   'thinkprogress': 17,
#   'rex': 57,
#   'tillersons': 5,
#   'emailsurlweb': 1,
#   'ghg': 1,
#   'resevoirs': 2,
#   'methane': 6,
#   'play': 5,
#   'substantial': 1,
#   'role': 36,
#   'greenharvard': 2,
#   'universities': 2,
#   'uniquely': 1,
#   'important': 5,
#   'battle': 26,
#   'popsci': 9,
#   'ten': 1,
#   'ugliest': 1,
#   'animals': 3,
#   'threatened': 12,
#   'syfys': 1,
#   'incorporated': 1,
#   'imagines': 1,
#   'future': 16,
#   'ravaged': 1,
#   'cnn': 80,
#   'nytnational': 2,
#   'budget': 28,
#   'proposal': 7,
#   'spending': 9,
#   'money': 17,
#   'anymore': 5,
#   'air': 15,
#   'pollution': 14,
#   'deaths': 4,
#   'expected': 11,
#   'rise': 20,
#   'due': 59,
#   'labour': 3,
#   'budgeting': 1,
#   'punch': 1,
#   'climatechange': 69,
#   'foxandfriends': 2,
#   'new': 191,
#   'catholic': 1,
#   'priests': 3,
#   'preach': 2,
#   'congregations': 1,
#   'reposays': 6,
#   'foxnation': 1,
#   'sasjabeslik': 2,
#   'meet': 25,
#   'chinas': 20,
#   'ecological': 5,
#   'migrants': 2,
#   'people': 28,
#   'displaced': 4,
#   'china': 143,
#   'warns': 39,
#   'trump': 824,
#   'abandoning': 10,
#   'deal': 47,
#   'ft': 11,
#   'science': 94,
#   'rescue': 5,
#   'chocolate': 1,
#   'europe': 15,
#   'safetypindaily': 15,
#   'federal': 40,
#   'department': 48,
#   'censoring': 7,
#   'use': 28,
#   'term': 10,
#   'emails': 25,
#   'reveal': 9,
#   'olliemilman': 2,
#   'conservative': 6,
#   'columnist': 3,
#   'siege': 2,
#   'ny': 17,
#   'times': 24,
#   'debut': 2,
#   'fox': 9,
#   'news': 127,
#   'indyusa': 4,
#   'director': 6,
#   'said': 18,
#   'combating': 4,
#   'waste': 16,
#   'trudeau': 9,
#   'must': 21,
#   'put': 8,
#   'emphasis': 1,
#   'defence': 3,
#   'wants': 29,
#   'onside': 1,
#   'nationalpost': 3,
#   'thehill': 82,
#   'rahm': 7,
#   'emanuel': 11,
#   'posts': 9,
#   'webpage': 12,
#   'deleted': 21,
#   'administration': 45,
#   'energydesk': 4,
#   'historic': 5,
#   'coal': 31,
#   'fall': 4,
#   'profound': 1,
#   'impact': 43,
#   'efforts': 49,
#   'tackle': 29,
#   'literateliberal': 1,
#   'leading': 16,
#   'deniers': 9,
#   'told': 10,
#   'want': 24,
#   'motherjones': 13,
#   'pablorodas': 14,
#   'p': 14,
#   'west': 6,
#   'coast': 6,
#   'states': 31,
#   'even': 13,
#   'ecointernet': 23,
#   'secretary': 47,
#   'state': 48,
#   'tillerson': 71,
#   'arctic': 55,
#   'action': 57,
#   'antinuclear': 1,
#   'stephen': 8,
#   'hawking': 5,
#   'message': 14,
#   'dont': 30,
#   'ignore': 21,
#   'telesurenglish': 1,
#   'one': 30,
#   'jamaicas': 1,
#   'iconic': 2,
#   'beaches': 3,
#   'vanishing': 2,
#   'thanks': 14,
#   'nzaegel': 1,
#   'effects': 47,
#   'wreak': 1,
#   'havoc': 1,
#   'mental': 13,
#   'health': 34,
#   'doctors': 9,
#   'upi': 1,
#   'brace': 4,
#   'bitterly': 4,
#   'cold': 6,
#   'winter': 16,
#   'shifts': 9,
#   'polar': 22,
#   'vortex': 11,
#   'business': 47,
#   'tells': 41,
#   'isnt': 33,
#   'hoax': 45,
#   'invented': 15,
#   'climatekeith': 1,
#   'saskatchewan': 1,
#   'ag': 18,
#   'provincial': 2,
#   'govt': 13,
#   'plan': 88,
#   'policies': 30,
#   'target': 8,
#   'address': 18,
#   'skpol': 1,
#   'exxon': 81,
#   'shareholders': 6,
#   'moved': 2,
#   'force': 11,
#   'company': 10,
#   'disclose': 6,
#   'poses': 3,
#   'natureorg': 5,
#   'leaders': 58,
#   'reaffirm': 5,
#   'commitment': 9,
#   'parisagreement': 8,
#   'john': 26,
#   'roughan': 1,
#   'miss': 1,
#   'sceptical': 1,
#   'voice': 5,
#   'zealand': 6,
#   'herald': 10,
#   'environment': 76,
#   'huffingtonpost': 17,
#   'chinese': 20,
#   'cmdangelo': 3,
#   'businessinsider': 9,
#   'apple': 6,
#   'borrowing': 1,
#   'billion': 17,
#   'bradydennis': 2,
#   'cdc': 15,
#   'abruptly': 5,
#   'cancels': 11,
#   'longplanned': 4,
#   'conference': 23,
#   'river': 12,
#   'canada': 14,
#   'turned': 4,
#   'piracy': 2,
#   'thedailyclimate': 2,
#   'frogs': 1,
#   'heading': 1,
#   'uphill': 1,
#   'escape': 1,
#   'india': 25,
#   'timesofindia': 1,
#   'campaigner': 7,
#   'dies': 6,
#   'snorkeling': 6,
#   'greatbarrierreef': 14,
#   'climatechangrr': 10,
#   'sends': 6,
#   'much': 19,
#   'smaller': 5,
#   'talks': 27,
#   'bonn': 1,
#   'home': 20,
#   'http': 18,
#   'washtimes': 3,
#   'whistleblower': 5,
#   'alleges': 1,
#   'noaa': 11,
#   'manipulated': 6,
#   'hide': 1,
#   'pause': 6,
#   'reportedly': 2,
#   'used': 51,
#   'alias': 43,
#   'read': 11,
#   'xom': 2,
#   'guardianeco': 25,
#   'stopping': 6,
#   'way': 29,
#   'save': 23,
#   'great': 28,
#   'barrier': 22,
#   'reef': 18,
#   'wsj': 16,
#   'rebuke': 6,
#   'policy': 51,
#   'ge': 8,
#   'ceo': 20,
#   'immelt': 2,
#   'arnold': 8,
#   'schwarzenegger': 10,
#   'teams': 4,
#   'end': 10,
#   'lead': 28,
#   'make': 38,
#   'guardian': 64,
#   'ht': 7,
#   'weneedhillary': 1,
#   'cbs': 8,
#   'evening': 1,
#   'donald': 166,
#   'skeptic': 22,
#   'charge': 4,
#   'protecting': 3,
#   'drbobbullard': 1,
#   'theres': 16,
#   'b': 15,
#   'fear': 29,
#   'consequence': 9,
#   'victory': 15,
#   'googlegirl': 1,
#   'sues': 4,
#   'inaction': 13,
#   'obamas': 41,
#   'legacy': 5,
#   'weakened': 1,
#   'investment': 8,
#   'dirty': 2,
#   'sabrush': 1,
#   'epa': 237,
#   'believe': 21,
#   'primary': 57,
#   'contributor': 50,
#   'picks': 6,
#   'sceptic': 4,
#   'scott': 112,
#   'pruitt': 96,
#   'cop': 19,
#   'gma': 1,
#   'undergoing': 1,
#   'rapid': 12,
#   'ice': 41,
#   'melt': 19,
#   'speed': 2,
#   'vicenews': 6,
#   'rumored': 1,
#   'pick': 18,
#   'everyone': 4,
#   'love': 3,
#   'ajplus': 15,
#   'top': 32,
#   'met': 1,
#   'g': 52,
#   'summit': 26,
#   'today': 14,
#   'countries': 27,
#   'affirmed': 1,
#   'theyd': 1,
#   'except': 1,
#   'antarctica': 14,
#   'starting': 1,
#   'turn': 9,
#   'green': 27,
#   'u': 2,
#   'opens': 2,
#   'water': 25,
#   'research': 54,
#   'facility': 1,
#   'urged': 14,
#   'bbcnews': 2,
#   'geographyteacher': 1,
#   'nytimes': 48,
#   'cooks': 2,
#   'decades': 7,
#   'ahead': 29,
#   'suffer': 5,
#   'equally': 1,
#   'pope': 15,
#   'challenges': 6,
#   'un': 66,
#   'sdogbon': 1,
#   'mgwvjaiye': 1,
#   'changes': 26,
#   'course': 12,
#   'california': 52,
#   'stubbornly': 1,
#   'presses': 1,
#   'forward': 6,
#   'drills': 4,
#   'tibet': 1,
#   'glaciers': 7,
#   'morocco': 6,
#   'record': 30,
#   'humancaused': 15,
#   'rerouted': 6,
#   'entire': 12,
#   'doubts': 12,
#   'dioxides': 2,
#   'bbc': 17,
#   'scrambling': 1,
#   'protect': 13,
#   'energized': 1,
#   'concerns': 5,
#   'appolitics': 7,
#   'national': 43,
#   'park': 25,
#   'service': 4,
#   'defies': 3,
#   'social': 9,
#   'media': 8,
#   'ban': 14,
#   'tweets': 19,
#   'japanese': 1,
#   'interned': 1,
#   'wwii': 1,
#   'danger': 6,
#   'zone': 3,
#   'anothergreen': 1,
#   'kurdish': 1,
#   'response': 5,
#   'communicate': 6,
#   'officials': 12,
#   'risks': 36,
#   'forces': 6,
#   'drop': 16,
#   'mention': 13,
#   'joint': 7,
#   'statement': 10,
#   'defense': 22,
#   'continues': 12,
#   'cleanenergy': 3,
#   'little': 9,
#   'quebec': 1,
#   'municipalities': 1,
#   'discuss': 36,
#   'montreal': 3,
#   'march': 19,
#   'environmentguru': 1,
#   'stance': 18,
#   'softeninghis': 1,
#   'tone': 1,
#   'whether': 12,
#   'kill': 5,
#   'punxsutawneyphil': 1,
#   'wwfaustralia': 1,
#   'nsw': 2,
#   'landclearing': 1,
#   'laws': 6,
#   'loss': 11,
#   'possingham': 1,
#   'radionational': 1,
#   'kids': 34,
#   'taking': 20,
#   'feds': 9,
#   'possibly': 9,
#   'couover': 9,
#   'scientist': 37,
#   'spreads': 1,
#   'word': 2,
#   'biking': 1,
#   'across': 14,
#   'america': 22,
#   'wtop': 2,
#   'ecolocyl': 1,
#   'epenvironment': 1,
#   'ceta': 1,
#   'contraries': 1,
#   'direction': 1,
#   'commitments': 5,
#   'limit': 10,
#   'temperature': 4,
#   'c': 15,
#   'cetat': 1,
#   'creating': 7,
#   'void': 3,
#   'persuade': 3,
#   'help': 42,
#   'fill': 3,
#   'la': 3,
#   'featuremexicos': 1,
#   'maya': 2,
#   'point': 6,
#   'slow': 13,
#   'species': 19,
#   'googleaction': 1,
#   'harmful': 3,
#   'unnecessary': 1,
#   'car': 1,
#   'reports': 15,
#   'heatwaves': 3,
#   'hurricanes': 6,
#   'floods': 18,
#   'famine': 4,
#   'seven': 3,
#   'hotspots': 4,
#   'guardiannews': 7,
#   'minhazmerchant': 1,
#   'ministers': 3,
#   'italy': 5,
#   'pledge': 5,
#   'per': 5,
#   'accord': 12,
#   'without': 20,
#   'democracynow': 2,
#   'chomsky': 2,
#   'every': 10,
#   'republican': 13,
#   'candidate': 8,
#   'either': 2,
#   'denied': 3,
#   'happening': 12,
#   'shouldnt': 1,
#   'pinklphants': 1,
#   'mayor': 11,
#   'chicago': 10,
#   'posted': 1,
#   'epas': 22,
#   'city': 14,
#   'winenewz': 1,
#   'wine': 5,
#   'industry': 7,
#   'trouble': 2,
#   'really': 23,
#   'doesnt': 23,
#   'face': 21,
#   'aggyk': 1,
#   'five': 7,
#   'pacific': 12,
#   'islands': 7,
#   'lost': 12,
#   'rising': 6,
#   'seas': 5,
#   'hits': 7,
#   'nasa': 17,
#   'defiantly': 4,
#   'communicating': 3,
#   'despite': 45,
#   'nasaclimate': 2,
#   'lift': 2,
#   'em': 1,
#   'yall': 1,
#   'fusion': 3,
#   'peru': 5,
#   'suffering': 2,
#   'worst': 14,
#   'recent': 8,
#   'historyand': 2,
#   'blame': 20,
#   'environmentke': 1,
#   'kenya': 1,
#   'ratified': 2,
#   'judiwakhungu': 1,
#   'mygovke': 1,
#   'nemakenya': 1,
#   'keforestservice': 1,
#   'professors': 2,
#   'sign': 25,
#   'open': 9,
#   'letter': 9,
#   'urging': 8,
#   'aireguru': 1,
#   'knocks': 2,
#   'extends': 3,
#   'effosan': 1,
#   'ap': 20,
#   'gov': 26,
#   'causes': 24,
#   'uproar': 10,
#   'contradicts': 14,
#   'washington': 34,
#   'post': 30,
#   'huffpostpol': 18,
#   'wildlife': 8,
#   'far': 6,
#   'worse': 19,
#   'thought': 11,
#   'australia': 21,
#   'left': 11,
#   'behind': 9,
#   'momentum': 5,
#   'appointees': 1,
#   'fake': 7,
#   'big': 11,
#   'pattern': 4,
#   'cloud': 3,
#   'cover': 4,
#   'masked': 3,
#   'deceptively': 2,
#   'simple': 4,
#   'number': 4,
#   'enters': 5,
#   'articles': 5,
#   'last': 14,
#   'hrs': 2,
#   'memo': 5,
#   'alarms': 5,
#   'energy': 100,
#   'staff': 16,
#   'cnbc': 9,
#   'pennsylvania': 1,
#   'fracking': 2,
#   'clash': 2,
#   'attorney': 10,
#   'general': 15,
#   'japan': 3,
#   'pruitts': 25,
#   'office': 28,
#   'deluged': 16,
#   'angry': 16,
#   'callers': 16,
#   'questions': 24,
#   'ajenglish': 8,
#   'worldpenguinday': 2,
#   'penguin': 2,
#   'colony': 2,
#   'meeting': 22,
#   'urges': 34,
#   'highest': 3,
#   'political': 9,
#   'afp': 3,
#   'reindeer': 10,
#   'disappearing': 7,
#   'alarming': 3,
#   'rate': 2,
#   'alaska': 7,
#   'obama': 78,
#   'admin': 10,
#   'sending': 3,
#   'million': 18,
#   'fund': 23,
#   'tongotongoz': 1,
#   'lastnightinsweden': 1,
#   'mass': 5,
#   'immigration': 2,
#   'north': 5,
#   'wef': 12,
#   'cities': 29,
#   'outpacing': 2,
#   'race': 14,
#   'curb': 32,
#   'nbc': 1,
#   'dismissed': 2,
#   'manmade': 9,
#   'many': 9,
#   'young': 6,
#   'poverty': 5,
#   'terrorism': 6,
#   'thebaxterbean': 1,
#   'executive': 42,
#   'order': 64,
#   'dismantling': 4,
#   'president': 100,
#   'combat': 29,
#   'barack': 7,
#   'create': 3,
#   'refugee': 2,
#   'crisis': 8,
#   'unprecedented': 4,
#   'human': 29,
#   'history': 8,
#   'clintonkowach': 1,
#   'ethiopias': 2,
#   'coffee': 5,
#   'bibleprophecy': 1,
#   'truth': 9,
#   'knowledge': 4,
#   'energyboom': 1,
#   'election': 10,
#   'jeopardize': 1,
#   'climatecentral': 24,
#   'cabinet': 6,
#   'nominees': 3,
#   'position': 12,
#   'petraau': 2,
#   'denies': 22,
#   'ordered': 4,
#   'hand': 12,
#   'secret': 5,
#   'prosecutors': 3,
#   'smartnews': 3,
#   'spring': 8,
#   'came': 3,
#   'early': 9,
#   'culprit': 3,
#   'mmcphoto': 1,
#   'recordbreaking': 34,
#   'pushes': 25,
#   'uncharted': 27,
#   'territory': 25,
#   'shellknew': 1,
#   'film': 15,
#   'emerges': 1,
#   'showing': 4,
#   'oil': 25,
#   'firm': 1,
#   'shell': 8,
#   'warning': 16,
#   'amazngebooks': 2,
#   'author': 2,
#   'radio': 8,
#   'host': 4,
#   'suggests': 12,
#   'weve': 4,
#   'already': 18,
#   'war': 13,
#   'malcolm': 3,
#   'roberts': 2,
#   'sbs': 1,
#   'cause': 30,
#   'conflicts': 2,
#   'sahel': 1,
#   'faces': 12,
#   'droughts': 6,
#   'storms': 9,
#   'accelerates': 4,
#   'bill': 19,
#   'gates': 9,
#   'investors': 17,
#   'worth': 8,
#   'launching': 5,
#   'innovation': 6,
#   'stanford': 4,
#   'link': 25,
#   'extreme': 28,
#   'weather': 36,
#   'germany': 10,
#   'together': 4,
#   'presidentelect': 16,
#   'nobody': 12,
#   'knows': 12,
#   'cnni': 9,
#   'implications': 1,
#   'ctvnews': 1,
#   'capitalize': 1,
#   'takes': 18,
#   'step': 6,
#   'back': 65,
#   'cdnpoli': 3,
#   'chairman': 5,
#   'committee': 16,
#   'beneficial': 1,
#   'phannam': 1,
#   'disaster': 17,
#   'alley': 2,
#   'cyclonedebbie': 1,
#   'shows': 26,
#   'test': 4,
#   'australias': 8,
#   'military': 12,
#   'smh': 3,
#   'whysharksmatter': 1,
#   'feedly': 2,
#   'actually': 9,
#   'required': 3,
#   'lawurlweb': 2,
#   'roll': 11,
#   'reviews': 12,
#   'source': 9,
#   'reuters': 68,
#   'companies': 16,
#   'involved': 2,
#   'sector': 4,
#   'problem': 10,
#   'cant': 13,
#   'words': 4,
#   'google': 12,
#   'fresh': 2,
#   'doubt': 6,
#   'dramatically': 15,
#   'approach': 18,
#   'duped': 1,
#   'bloomberg': 25,
#   'grilse': 1,
#   'considering': 2,
#   'ways': 6,
#   'fasttrack': 1,
#   'withdrawal': 3,
#   'administrator': 7,
#   'speech': 9,
#   'delegate': 3,
#   'cdcs': 5,
#   'canceled': 7,
#   'al': 36,
#   'gore': 30,
#   'facethenation': 1,
#   'berniesanders': 2,
#   'icymi': 4,
#   'underlying': 1,
#   'assumptions': 1,
#   'keeping': 4,
#   'finding': 1,
#   'common': 3,
#   'ground': 3,
#   'climatehawk': 30,
#   'biden': 5,
#   'abcnews': 5,
#   'glo': 1,
#   'sweeping': 10,
#   'rollback': 6,
#   'obamaera': 10,
#   'rules': 13,
#   'deptartment': 1,
#   'rejects': 8,
#   'attempt': 3,
#   'single': 1,
#   'working': 5,
#   'year': 19,
#   'become': 10,
#   'refugees': 4,
#   'ocean': 23,
#   'levels': 17,
#   'butterfly': 1,
#   'protector': 1,
#   'informed': 1,
#   'gets': 6,
#   'obe': 1,
#   'try': 3,
#   'care': 11,
#   'jeopardizing': 1,
#   'pentagons': 1,
#   'retired': 2,
#   'markfhand': 1,
#   'closes': 3,
#   'abroad': 1,
#   'ignorance': 1,
#   'diplomacy': 3,
#   'undo': 17,
#   'protections': 4,
#   'thebetterindia': 1,
#   'yearold': 6,
#   'indias': 2,
#   'seat': 1,
#   'bank': 10,
#   'todays': 1,
#   'storieshttps': 1,
#   'bradreason': 1,
#   'revises': 1,
#   'remove': 7,
#   'moments': 2,
#   'michaelemann': 3,
#   'age': 5,
#   'libel': 1,
#   'suit': 2,
#   'heads': 3,
#   'trial': 10,
#   'chelseaeharvey': 1,
#   'fiction': 3,
#   'fact': 1,
#   'announces': 4,
#   'goal': 4,
#   'increase': 10,
#   'meetings': 2,
#   'dallasnews': 2,
#   'restrict': 1,
#   'investor': 4,
#   'activism': 2,
#   'like': 18,
#   'resolution': 1,
#   'jeffmosier': 1,
#   'chile': 1,
#   'see': 16,
#   'greatest': 1,
#   'external': 2,
#   'threat': 37,
#   'nprparallels': 1,
#   'rusty': 1,
#   'patched': 1,
#   'bumblebee': 1,
#   'added': 1,
#   'endangered': 5,
#   'list': 4,
#   'gt': 2,
#   'habitat': 6,
#   'losspesticides': 1,
#   'amp': 35,
#   'rt': 2,
#   'jasonkoebler': 1,
#   'references': 13,
#   'inauguration': 11,
#   'popular': 4,
#   'belief': 7,
#   'paginanuova': 1,
#   'tv': 5,
#   'algae': 8,
#   'altusepa': 4,
#   'documents': 12,
#   'healthurlweb': 1,
#   'billmckibben': 1,
#   'massive': 6,
#   'blooms': 3,
#   'arabian': 6,
#   'sea': 32,
#   'tied': 6,
#   'changein': 1,
#   'oxygenchoked': 1,
#   'waters': 2,
#   'beneath': 1,
#   'fish': 3,
#   'die': 4,
#   'johnvidal': 1,
#   'launches': 3,
#   'triple': 2,
#   'initiative': 3,
#   'challenge': 16,
#   'conservatives': 7,
#   'elected': 3,
#   'abraham': 5,
#   'builds': 1,
#   'wetland': 2,
#   'resilience': 5,
#   'reinforce': 1,
#   'indigenous': 17,
#   'spreading': 6,
#   'case': 10,
#   'acting': 5,
#   'demforce': 1,
#   'cbcnews': 12,
#   'win': 9,
#   'environmentalists': 8,
#   ...},
#  0: {'calum': 1,
#   'tweets': 5,
#   'abt': 5,
#   'reunitingish': 1,
#   'w': 15,
#   'castsees': 1,
#   'replies': 1,
#   'begging': 1,
#   'come': 27,
#   'countriescalum': 1,
#   'goes': 4,
#   'back': 21,
#   'rting': 1,
#   'climate': 1439,
#   'change': 1375,
#   'also': 24,
#   'met': 7,
#   'guy': 11,
#   'let': 6,
#   'us': 101,
#   'truth': 7,
#   'gay': 6,
#   'people': 65,
#   'existing': 1,
#   'urlweb': 830,
#   'jnpftw': 1,
#   'scientists': 24,
#   'denounce': 3,
#   'choice': 4,
#   'dealt': 1,
#   'simple': 5,
#   'issues': 11,
#   'like': 96,
#   'energy': 23,
#   'policy': 15,
#   'complex': 5,
#   'mal': 2,
#   'vs': 4,
#   'tones': 2,
#   'qanda': 4,
#   'andrewsharp': 1,
#   'win': 5,
#   'probability': 1,
#   'bullshit': 5,
#   'man': 30,
#   'saw': 5,
#   'nba': 1,
#   'finals': 1,
#   'thats': 36,
#   'knew': 1,
#   'global': 1036,
#   'warming': 967,
#   'isnt': 58,
#   'real': 94,
#   'chris': 1,
#   'initially': 1,
#   'talked': 8,
#   'changeme': 1,
#   'thinked': 1,
#   'three': 2,
#   'seconds': 2,
#   'europea': 2,
#   'approve': 1,
#   'executive': 4,
#   'order': 6,
#   'realdonaldtrump': 29,
#   'due': 21,
#   'sign': 7,
#   'environmenturlweb': 1,
#   'glennf': 1,
#   'calling': 2,
#   'great': 36,
#   'space': 6,
#   'cylinder': 1,
#   'save': 7,
#   'fuckofflaine': 1,
#   'jjxrry': 1,
#   'spacex': 1,
#   'quebanjesus': 1,
#   'antarctica': 5,
#   'big': 17,
#   'lmao': 5,
#   'nigga': 5,
#   'use': 12,
#   'air': 19,
#   'conditioner': 1,
#   'hope': 7,
#   'china': 26,
#   'tells': 4,
#   'trump': 147,
#   'hoax': 30,
#   'invented': 3,
#   'via': 24,
#   'business': 6,
#   'lol': 22,
#   'schooling': 2,
#   'uscgpacificnw': 1,
#   'nsf': 1,
#   'icebreaking': 1,
#   'ships': 1,
#   'primary': 5,
#   'cause': 56,
#   'arctic': 7,
#   'freeze': 4,
#   'amp': 100,
#   'stay': 5,
#   'away': 11,
#   'doesnt': 53,
#   'exist': 19,
#   'club': 44,
#   'penguin': 84,
#   'shutting': 20,
#   'cernovich': 4,
#   'ldnenvironment': 1,
#   'weve': 4,
#   'shoterm': 1,
#   'opps': 1,
#   'working': 5,
#   'send': 5,
#   'cv': 1,
#   'qs': 1,
#   'environmentlondongovuk': 1,
#   'h': 8,
#   'markbaileymp': 1,
#   'fed': 1,
#   'energyenvt': 1,
#   'minister': 2,
#   'joshfrydenberg': 2,
#   'refused': 1,
#   'allow': 7,
#   'term': 5,
#   'coag': 1,
#   'council': 3,
#   'communique': 1,
#   'despit': 1,
#   'jadorelacouture': 1,
#   'fact': 12,
#   'leonardo': 30,
#   'dicaprio': 20,
#   'discuss': 10,
#   'smithsonianenv': 1,
#   'sercs': 1,
#   'roy': 1,
#   'rich': 2,
#   'colleagues': 1,
#   'create': 3,
#   'buzz': 2,
#   'germany': 1,
#   'simulation': 1,
#   'senior': 3,
#   'quality': 3,
#   'specialist': 1,
#   'airquality': 1,
#   'climatechange': 15,
#   'greenhousegas': 1,
#   'cnn': 18,
#   'protest': 3,
#   'stupid': 7,
#   'mthgd': 1,
#   'shut': 21,
#   'prisonplanet': 2,
#   'wow': 11,
#   'finally': 5,
#   'evil': 3,
#   'wake': 1,
#   'good': 39,
#   'drishtiias': 1,
#   'audio': 2,
#   'article': 14,
#   'environment': 11,
#   'trumps': 24,
#   'decision': 4,
#   'form': 6,
#   'paris': 18,
#   'agreementhttps': 1,
#   'politicalshopiewagn': 1,
#   'dems': 2,
#   'causing': 21,
#   'stfu': 1,
#   'reader': 1,
#   'questions': 8,
#   'science': 29,
#   'theories': 3,
#   'zachheltzel': 1,
#   'believe': 87,
#   'generally': 1,
#   'refuse': 1,
#   'say': 33,
#   'trans': 2,
#   'loud': 1,
#   'youre': 28,
#   'better': 9,
#   'vp': 3,
#   'nasajohnson': 1,
#   'ask': 21,
#   'explain': 16,
#   'jinjjarevil': 1,
#   'way': 20,
#   'seokjin': 1,
#   'blinks': 1,
#   'adorable': 1,
#   'stopstrees': 1,
#   'grow': 1,
#   'crime': 21,
#   'rate': 4,
#   'decreases': 1,
#   'benhulac': 1,
#   'asked': 28,
#   'charges': 1,
#   'exxonmobil': 1,
#   'withheld': 1,
#   'information': 4,
#   'tillerson': 5,
#   'declines': 1,
#   'answer': 9,
#   'twice': 1,
#   'secretaryofst': 1,
#   'rjsalmond': 1,
#   'already': 10,
#   'denial': 10,
#   'either': 10,
#   'would': 43,
#   'loss': 6,
#   'well': 25,
#   'quiz': 2,
#   'cultural': 2,
#   'heritageclimate': 1,
#   'disclaimer': 1,
#   'dont': 73,
#   'agree': 6,
#   'answers': 5,
#   'still': 35,
#   'interesting': 20,
#   'look': 24,
#   'whos': 5,
#   'town': 3,
#   'thank': 13,
#   'enjoying': 4,
#   'quick': 6,
#   'trip': 2,
#   'brown': 2,
#   'county': 1,
#   'state': 5,
#   'park': 4,
#   'degree': 4,
#   'november': 13,
#   'day': 27,
#   'puffnpuffin': 1,
#   'stevemartintogo': 1,
#   'billnye': 5,
#   'bumfonline': 1,
#   'could': 25,
#   'someone': 15,
#   'link': 7,
#   'journal': 3,
#   'reviewed': 3,
#   'one': 49,
#   'guess': 12,
#   'mei': 1,
#   'mains': 1,
#   'jackposobiec': 3,
#   'soon': 10,
#   'altright': 1,
#   'blamed': 6,
#   'gingivitis': 1,
#   'senatormroberts': 2,
#   'much': 31,
#   'finkel': 1,
#   'blueprint': 1,
#   'stop': 32,
#   'none': 4,
#   'deindustrialise': 1,
#   'economy': 9,
#   'fo': 1,
#   'prisionplaneta': 1,
#   'scottadamssays': 5,
#   'studies': 4,
#   'choose': 2,
#   'show': 14,
#   'ones': 3,
#   'htt': 14,
#   'inspiration': 20,
#   'told': 25,
#   'em': 8,
#   'think': 82,
#   'solved': 6,
#   'problem': 13,
#   'kids': 9,
#   'fix': 12,
#   'sit': 3,
#   'wait': 12,
#   'dadlife': 1,
#   'tell': 30,
#   'story': 10,
#   'contest': 1,
#   'petraau': 1,
#   'countries': 6,
#   'subtweeted': 2,
#   'lianamaeby': 1,
#   'plus': 2,
#   'side': 7,
#   'anymore': 6,
#   'robydalvik': 1,
#   'kalem': 1,
#   'ini': 2,
#   'karena': 5,
#   'faktor': 1,
#   'laut': 1,
#   'naik': 2,
#   'conversation': 4,
#   'go': 13,
#   'morning': 5,
#   'arthur': 3,
#   'cold': 26,
#   'yes': 23,
#   'obviously': 5,
#   'fake': 14,
#   'agreed': 2,
#   'thi': 1,
#   'caused': 22,
#   'cabbage': 1,
#   'farts': 3,
#   'simonwest': 1,
#   'brilliant': 1,
#   'cartoon': 2,
#   'sums': 2,
#   'cancel': 16,
#   'barackobama': 1,
#   'policies': 10,
#   'itisreal': 1,
#   'adam': 1,
#   'adamcurry': 1,
#   'maakte': 1,
#   'al': 16,
#   'keer': 1,
#   'zijn': 2,
#   'agenda': 8,
#   'leuk': 1,
#   'info': 3,
#   'erry': 1,
#   'reason': 11,
#   'fight': 21,
#   'ccol': 1,
#   'putting': 3,
#   'ac': 1,
#   'outside': 12,
#   'ineedtakeatwit': 1,
#   'zwash': 1,
#   'foxnews': 9,
#   'thejuanwilliams': 1,
#   'lolololololol': 1,
#   'oceans': 1,
#   'rising': 5,
#   'even': 33,
#   'without': 7,
#   'stand': 3,
#   'successes': 2,
#   'hayleiip': 1,
#   'im': 81,
#   'qualified': 1,
#   'pulled': 2,
#   'pic': 5,
#   'environmental': 5,
#   'ni': 2,
#   'wingsscotland': 2,
#   'belfast': 1,
#   'alone': 2,
#   'probably': 13,
#   'accelerates': 2,
#   'year': 19,
#   'night': 7,
#   'dicapriofdn': 1,
#   'u': 29,
#   'preach': 1,
#   'yacht': 1,
#   'hypocrite': 6,
#   'gesemdicapt': 1,
#   'fuck': 21,
#   'anyone': 9,
#   'lives': 7,
#   'earth': 17,
#   'laughing': 1,
#   'mattis': 3,
#   'says': 45,
#   'proves': 3,
#   'elections': 1,
#   'henningakesson': 1,
#   'interested': 4,
#   'glaciers': 4,
#   'yr': 4,
#   'researcher': 2,
#   'position': 6,
#   'regional': 1,
#   'modeling': 3,
#   'bjerknesbccr': 1,
#   'uib': 1,
#   'right': 36,
#   'significant': 2,
#   'weather': 37,
#   'event': 6,
#   'blindly': 1,
#   'blame': 20,
#   'tahjshaunx': 1,
#   'funnymaine': 1,
#   'black': 8,
#   'men': 5,
#   'hitlers': 1,
#   'main': 8,
#   'target': 1,
#   'holocaust': 1,
#   'women': 9,
#   'amcp': 3,
#   'papers': 3,
#   'cridfxj': 1,
#   'agreement': 15,
#   'isolated': 1,
#   'completely': 1,
#   'elliehighwood': 1,
#   'ok': 8,
#   'crochet': 1,
#   'addict': 1,
#   'blanket': 1,
#   'stripes': 1,
#   'coloured': 1,
#   'according': 5,
#   'last': 13,
#   'years': 26,
#   'cudder': 1,
#   'everyone': 19,
#   'pointedit': 1,
#   'triggers': 1,
#   'rise': 9,
#   'giant': 4,
#   'orchids': 1,
#   'battle': 3,
#   'carniverous': 1,
#   'plants': 1,
#   'devour': 1,
#   'dwindling': 1,
#   'humans': 11,
#   'thefilm': 1,
#   'bringing': 5,
#   'tornadoes': 2,
#   'floods': 2,
#   'god': 11,
#   'america': 9,
#   'plaguing': 1,
#   'farrakhan': 1,
#   'quote': 2,
#   'nuclear': 23,
#   'war': 10,
#   'might': 15,
#   'plunge': 1,
#   'winter': 23,
#   'wont': 14,
#   'worry': 7,
#   'notlinkolafan': 1,
#   'rowanjones': 1,
#   'need': 37,
#   'pay': 7,
#   'kimkardashian': 1,
#   'heaps': 1,
#   'cash': 3,
#   'promote': 1,
#   'solutions': 3,
#   'lets': 8,
#   'boredeaths': 1,
#   'mtthwdvs': 1,
#   'learn': 1,
#   'difference': 5,
#   'shellenbergermd': 1,
#   'new': 44,
#   'leodicaprio': 7,
#   'web': 1,
#   'site': 2,
#   'attacks': 1,
#   'power': 8,
#   'plant': 5,
#   'closures': 1,
#   'increase': 3,
#   'co': 12,
#   'emissions': 7,
#   'ht': 5,
#   'grandma': 1,
#   'said': 44,
#   'aveeuropathend': 1,
#   'pbp': 1,
#   'cling': 1,
#   'idea': 8,
#   'anything': 13,
#   'civil': 4,
#   'rights': 13,
#   'website': 7,
#   'plesscatherine': 1,
#   'team': 10,
#   'energyclimate': 1,
#   'check': 6,
#   'mcggovt': 1,
#   'mariamartmcg': 1,
#   'cocodupepe': 1,
#   'marlapeyre': 1,
#   'eliseffant': 1,
#   'https': 36,
#   'pollrepoto': 1,
#   'address': 5,
#   'isdoing': 1,
#   'enough': 9,
#   'needs': 10,
#   'quinnipiac': 2,
#   'rv': 1,
#   'ezralevant': 5,
#   'sheilagunnreids': 2,
#   'videos': 2,
#   'un': 22,
#   'conference': 20,
#   'marrakech': 2,
#   'weathernetwork': 1,
#   'snow': 19,
#   'joke': 6,
#   'claims': 5,
#   'yet': 9,
#   'another': 9,
#   'casualty': 1,
#   'saveoursnowmen': 1,
#   'thenextweb': 2,
#   'national': 15,
#   'geographics': 6,
#   'documentary': 23,
#   'youtube': 11,
#   'ultravlolence': 20,
#   'interviewer': 21,
#   'warmingmelania': 20,
#   'hello': 23,
#   'hes': 78,
#   'kind': 24,
#   'strong': 21,
#   'c': 28,
#   'nuritben': 1,
#   'world': 39,
#   'ranges': 1,
#   'different': 3,
#   'eural': 1,
#   'india': 3,
#   'africa': 3,
#   'jedrlee': 8,
#   'hey': 17,
#   'girl': 9,
#   'changebecause': 8,
#   'going': 35,
#   'ignore': 10,
#   'denying': 7,
#   'celebrate': 2,
#   'overcome': 1,
#   'obamacare': 4,
#   'million': 4,
#   'becketadams': 3,
#   'journo': 1,
#   'twitter': 10,
#   'seems': 3,
#   'angrier': 1,
#   'bret': 4,
#   'stephens': 4,
#   'oped': 3,
#   'week': 11,
#   'nyt': 13,
#   'publish': 1,
#   'drshow': 1,
#   'amyaharder': 3,
#   'chriscmooney': 1,
#   'surveyfunk': 1,
#   'project': 3,
#   'kfb': 1,
#   'maybe': 22,
#   'messing': 2,
#   'sleep': 2,
#   'cycle': 1,
#   'cuntpanda': 1,
#   'globetoppers': 1,
#   'rickagain': 1,
#   'mercnews': 1,
#   'cartoons': 1,
#   'donald': 19,
#   'kejayurbane': 1,
#   'humid': 2,
#   'hot': 43,
#   'thotkejay': 1,
#   'urbane': 1,
#   'mood': 2,
#   'piece': 3,
#   'yay': 1,
#   'thing': 40,
#   'concerns': 1,
#   'please': 16,
#   'boys': 6,
#   'deny': 9,
#   'get': 45,
#   'bi': 2,
#   'gabrielgrims': 1,
#   'habitat': 1,
#   'driving': 1,
#   'species': 4,
#   'extinction': 4,
#   'crisis': 4,
#   'realpeerreview': 1,
#   'resurgence': 1,
#   'dragonsurlweb': 1,
#   'catalyticrxn': 1,
#   'trend': 4,
#   'toward': 2,
#   'increased': 3,
#   'acceptance': 3,
#   'humancaused': 4,
#   'flat': 2,
#   'scienceelecti': 1,
#   'catbeltane': 2,
#   'cool': 10,
#   'presidential': 2,
#   'debates': 7,
#   'featured': 2,
#   'whatsoever': 2,
#   'repstevensmith': 3,
#   'host': 3,
#   'vote': 8,
#   'hillary': 12,
#   'believes': 15,
#   'make': 30,
#   'actually': 20,
#   'warfare': 1,
#   'hoosierworld': 1,
#   'entertainers': 1,
#   'theyre': 19,
#   'meeting': 7,
#   'lib': 1,
#   'presidents': 1,
#   'work': 13,
#   'dare': 2,
#   'talk': 33,
#   'urban': 3,
#   'classylikekoi': 1,
#   'justinkanew': 1,
#   'keep': 15,
#   'heard': 12,
#   'something': 14,
#   'weeks': 6,
#   'ago': 9,
#   'infothey': 1,
#   'taking': 6,
#   'kid': 3,
#   'named': 3,
#   'naomi': 1,
#   'started': 13,
#   'damn': 13,
#   'mike': 3,
#   'drop': 3,
#   'little': 9,
#   'yo': 5,
#   'question': 9,
#   'amitav': 1,
#   'ghosh': 1,
#   'talks': 8,
#   'book': 8,
#   'standard': 1,
#   'news': 23,
#   'central': 4,
#   'graysekelly': 1,
#   'polar': 14,
#   'bears': 8,
#   'natural': 5,
#   'enemies': 2,
#   'dies': 3,
#   'starvation': 1,
#   'sonofliberty': 1,
#   'poll': 4,
#   'made': 16,
#   'scientific': 4,
#   'djmikerawk': 1,
#   'fireworks': 1,
#   'contribute': 3,
#   'asking': 3,
#   'potus': 5,
#   'ing': 1,
#   'monitoringmodeling': 1,
#   'metrowaterworks': 1,
#   'talking': 18,
#   'programs': 5,
#   'ralucaellis': 1,
#   'thefranklin': 1,
#   'electromegnatic': 1,
#   'inthe': 1,
#   'airpuja': 1,
#   'diya': 2,
#   'ko': 4,
#   'boojate': 1,
#   'hiweather': 1,
#   'technologysehipnotize': 1,
#   'yourmind': 1,
#   'willemjoustra': 1,
#   'waar': 1,
#   'blijft': 1,
#   'die': 16,
#   'fvckrvcism': 1,
#   'presidentelect': 5,
#   'thinks': 13,
#   'nanasranch': 1,
#   'hell': 14,
#   'freezes': 2,
#   'suhshu': 1,
#   'mcm': 5,
#   'myth': 7,
#   'ship': 2,
#   'sailed': 1,
#   'two': 11,
#   'declining': 1,
#   'romans': 1,
#   'caught': 4,
#   'hebrew': 1,
#   'character': 3,
#   'weekend': 2,
#   'bloke': 1,
#   'inspired': 1,
#   'warmingfwm': 1,
#   'pkollar': 1,
#   'rangers': 1,
#   'update': 1,
#   'fighting': 9,
#   'monster': 2,
#   'called': 20,
#   'polluticorn': 1,
#   'unicorn': 1,
#   'pollutes': 1,
#   'stuff': 7,
#   'pr': 1,
#   'alicemolero': 1,
#   'mean': 15,
#   'cooling': 4,
#   'heating': 1,
#   'define': 1,
#   'enzoboschi': 1,
#   'le': 4,
#   'piante': 1,
#   'assorbono': 1,
#   'pi': 2,
#   'non': 4,
#   'hanno': 1,
#   'bisogno': 1,
#   'di': 10,
#   'acqua': 1,
#   'sono': 2,
#   'diventate': 1,
#   'efficienti': 1,
#   'contro': 2,
#   'il': 5,
#   'nature': 1,
#   'tan': 4,
#   'sweeping': 1,
#   'american': 9,
#   'politics': 11,
#   'intolerant': 1,
#   'bullying': 1,
#   'censorshiploving': 1,
#   'groupsbrought': 1,
#   'regards': 2,
#   'lovely': 2,
#   'today': 29,
#   'read': 20,
#   'swrightwestozs': 1,
#   'latest': 6,
#   'insurance': 2,
#   'lending': 1,
#   'featuring': 1,
#   'apra': 1,
#   'speech': 8,
#   'centrepolicydev': 1,
#   'thecosby': 1,
#   'gon': 19,
#   'na': 30,
#   'post': 8,
#   'ig': 2,
#   'snap': 3,
#   'location': 1,
#   'views': 11,
#   'blm': 1,
#   'type': 1,
#   'wha': 2,
#   'skeptical': 1,
#   'environmentalist': 1,
#   'takes': 10,
#   'controversial': 2,
#   'doc': 10,
#   'e': 7,
#   'acha': 1,
#   'que': 1,
#   'nada': 1,
#   'est': 2,
#   'acontecendo': 1,
#   'bbanimals': 1,
#   'effects': 9,
#   'associate': 1,
#   'lots': 3,
#   'poorlowerclass': 1,
#   'rocket': 2,
#   'beautiful': 5,
#   'outin': 1,
#   'february': 6,
#   'lolbut': 1,
#   'justsaying': 1,
#   'ctvtoront': 1,
#   'calis': 1,
#   'endless': 2,
#   'drought': 7,
#   'howstorms': 1,
#   'making': 11,
#   'dent': 1,
#   'californias': 1,
#   'feet': 1,
#   'opositive': 1,
#   'aashi': 1,
#   'iamwithmodiji': 1,
#   'lkoprem': 1,
#   'tum': 2,
#   'muskurae': 1,
#   'sheetal': 1,
#   'hawae': 1,
#   'chal': 1,
#   'gai': 1,
#   'sansar': 1,
#   'kaha': 1,
#   'hai': 1,
#   'stance': 3,
#   'hasnt': 3,
#   'moderated': 1,
#   'forecasterenten': 1,
#   'funny': 7,
#   'becomes': 1,
#   'president': 18,
#   'probablywonthappenbutwhoreallyknows': 1,
#   'aerialwav': 1,
#   'turns': 6,
#   'pin': 1,
#   'hopes': 1,
#   'given': 3,
#   'fires': 2,
#   'australia': 5,
#   'summer': 6,
#   'must': 21,
#   'cnazmul': 1,
#   'starting': 3,
#   'synthesizing': 1,
#   'reports': 3,
#   'community': 2,
#   'projects': 2,
#   'pksf': 1,
#   'saleemulhuq': 1,
#   'gobeshona': 1,
#   'icccad': 1,
#   'theres': 11,
#   'many': 12,
#   'liberal': 8,
#   'snowflakes': 3,
#   'scienceisntreal': 1,
#   'tomi': 1,
#   'lahren': 1,
#   'uspgglobal': 1,
#   'annual': 2,
#   'bray': 1,
#   'service': 1,
#   'founder': 1,
#   'focus': 6,
#   'wed': 1,
#   'feb': 1,
#   'london': 2,
#   'sinow': 1,
#   'sipetethamel': 1,
#   'sea': 10,
#   'came': 4,
#   'earlier': 6,
#   'thought': 17,
#   'wichita': 1,
#   'atlantic': 2,
#   'coast': 3,
#   'spended': 1,
#   'da': 4,
#   'servicing': 1,
#   'snowblowers': 1,
#   'shosleeves': 2,
#   'bright': 2,
#   'whoabrorelax': 1,
#   'hence': 1,
#   'findings': 1,
#   'dad': 4,
#   'really': 34,
#   'cwant': 1,
#   'destroy': 2,
#   'sirwilfreddeath': 1,
#   'alicewoolley': 1,
#   'bonnegreer': 1,
#   'bbc': 7,
#   'gives': 4,
#   'false': 4,
#   'equivalence': 1,
#   'arguments': 3,
#   'eff': 1,
#   'guys': 11,
#   'r': 11,
#   'advocating': 1,
#   'special': 7,
#   'role': 6,
#   'banksusing': 1,
#   'range': 2,
#   'instruments': 3,
#   'changerelated': 1,
#   'discl': 1,
#   'chemists': 1,
#   'find': 15,
#   'spoiling': 1,
#   'series': 6,
#   'causes': 15,
#   'allenwest': 1,
# ...
#   'moveon': 2,
#   'rorybergin': 1,
#   'juliaoftoronto': 1,
#   'carrot': 1,
#   'ie': 4,
#   'trumpdisaster': 1,
#   'resothat': 1,
#   'tristanalbers': 1,
#   'accepting': 3,
#   'love': 54,
#   'educatnstrong': 1,
#   'tracedominguez': 1,
#   'sencorygardner': 2,
#   'nofascistusa': 1,
#   'action': 278,
#   'eu': 25,
#   'continuous': 3,
#   'tracker': 25,
#   'touches': 2,
#   'zachjgreen': 1,
#   'terms': 17,
#   'oscar': 1,
#   'gores': 15,
#   'siricerasi': 1,
#   'hoa': 3,
#   'stayinformedcc': 1,
#   'woman': 14,
#   'cluddite': 1,
#   'lastweektonight': 16,
#   'profoundly': 2,
#   'richardwjones': 1,
#   'history': 46,
#   'orange': 7,
#   'restaurant': 1,
#   'bequeathed': 1,
#   'dr': 26,
#   'thisdirectly': 1,
#   'roads': 2,
#   'bffoundation': 1,
#   'warminga': 1,
#   'tf': 2,
#   'hating': 2,
#   'aquamarching': 1,
#   'itnow': 1,
#   'nominee': 9,
#   'repmeehan': 1,
#   'kristennwiig': 1,
#   'dnaples': 1,
#   'ezlusztig': 2,
#   'tobacco': 6,
#   'metofficesci': 2,
#   'zer': 1,
#   'cjwade': 2,
#   'melti': 1,
#   'maggieeeng': 1,
#   'nic': 1,
#   'transforming': 3,
#   'harbinger': 1,
#   'phantompower': 1,
#   'imrankhanpti': 2,
#   'moths': 1,
#   'coproducer': 1,
#   'galkamax': 1,
#   'changeat': 1,
#   'secy': 2,
#   'coverd': 1,
#   'ndenicolamd': 1,
#   'brentsullivan': 1,
#   'racingxtinction': 1,
#   'projectarcc': 2,
#   'flynns': 1,
#   'parisclimatedeal': 3,
#   'weak': 7,
#   'vortex': 12,
#   'jp': 1,
#   'supporting': 12,
#   'tonyschwartz': 2,
#   'aemarling': 1,
#   'wai': 1,
#   'growth': 27,
#   'breitbais': 1,
#   'unstoppablehere': 2,
#   'zaibatsunews': 3,
#   'februarys': 6,
#   'hansen': 4,
#   'cycleoakville': 1,
#   'presidentin': 1,
#   'guyendorekaiser': 1,
#   'princesspayyton': 1,
#   'spectacular': 1,
#   'joshbloch': 1,
#   'migrating': 2,
#   'regulatory': 1,
#   'libbyreale': 1,
#   'yayprogress': 1,
#   'sasjabeslik': 3,
#   'continued': 7,
#   'antarctica': 33,
#   'ladyliberty': 1,
#   'suck': 7,
#   'workshopnicknuttgens': 1,
#   'dismantle': 4,
#   'jackbenedwards': 1,
#   'decolonising': 1,
#   'simonreeve': 2,
#   'sudden': 8,
#   'aidancomiskey': 1,
#   'susannecraig': 1,
#   'alifaith': 1,
#   'changedenying': 9,
#   'nuzzel': 1,
#   'alexteachey': 1,
#   'properties': 2,
#   'addresed': 1,
#   'cr': 4,
#   'hanatruly': 1,
#   'tragic': 4,
#   'adamparkhomenko': 1,
#   'expands': 2,
#   'asia': 13,
#   'jasonbordoff': 2,
#   'katesrock': 1,
#   'trilliontonne': 1,
#   'london': 12,
#   'rips': 3,
#   'trafficking': 2,
#   'lt': 4,
#   'addresss': 1,
#   'doubters': 6,
#   'ampavoid': 1,
#   'ikebarinholtz': 1,
#   'shapes': 1,
#   'rip': 7,
#   'pove': 1,
#   'bugs': 2,
#   'adp': 1,
#   'responsibility': 5,
#   'theresistan': 1,
#   'balboa': 1,
#   'oregonian': 2,
#   'mosshander': 1,
#   'jenniferwishon': 1,
#   'peopleyr': 1,
#   'proven': 16,
#   'teaching': 15,
#   'stern': 8,
#   'parasite': 2,
#   'fired': 14,
#   'outlines': 2,
#   'anarchists': 1,
#   'die': 418,
#   'sequester': 1,
#   'nonpartisan': 1,
#   'interpretation': 2,
#   'juniper': 1,
#   'greeted': 2,
#   'adherents': 2,
#   'palegoon': 2,
#   'happ': 1,
#   'climatecrisis': 1,
#   'juliabrueg': 1,
#   'whenever': 2,
#   'realbradgarrett': 1,
#   'citieshome': 1,
#   'youve': 15,
#   'curious': 8,
#   'brexitbritain': 1,
#   'abandoning': 18,
#   'guyshrubsole': 1,
#   'evacide': 1,
#   'field': 3,
#   'surrounds': 1,
#   'fionaskywalker': 1,
#   'lhfang': 2,
#   'certainsm': 1,
#   'covfefe': 4,
#   'thecaseyrusu': 1,
#   'publicity': 1,
#   'altfactistan': 1,
#   'lone': 2,
#   'antaisce': 1,
#   'gccthinkacttank': 2,
#   'basic': 10,
#   'chemical': 2,
#   'graph': 4,
#   'vegas': 2,
#   'iamacli': 1,
#   'looking': 42,
#   'pestilence': 1,
#   'islamaphobia': 3,
#   'chain': 4,
#   'leaks': 1,
#   'abcnews': 7,
#   'demonic': 1,
#   'forestry': 2,
#   'sleepme': 1,
#   'alaskan': 5,
#   'morningjoe': 2,
#   'umm': 2,
#   'nonbelievers': 1,
#   'snow': 103,
#   'wwfscotland': 1,
#   'scottierock': 1,
#   'ragcha': 1,
#   'fazalcheema': 1,
#   'ikea': 1,
#   'sideeffects': 1,
#   'sebastian': 1,
#   'trumpsepa': 2,
#   'dairyisscary': 1,
#   'anyways': 1,
#   'pesky': 2,
#   'diet': 11,
#   'prog': 2,
#   'unchecked': 11,
#   'balance': 4,
#   'faith': 6,
#   'also': 149,
#   'markmackinnon': 1,
#   'bodyofbreen': 1,
#   'openly': 5,
#   'ones': 14,
#   'kitharingstons': 1,
#   'rnc': 1,
#   'rises': 3,
#   'arises': 1,
#   'foll': 2,
#   'grants': 1,
#   'birdiessandershttps': 2,
#   'whysharksmatter': 2,
#   'luddites': 1,
#   'senior': 13,
#   'brookewmckeever': 1,
#   'treaty': 15,
#   'actions': 36,
#   'caitrionambalfe': 3,
#   'proportionally': 1,
#   'usembassydublin': 1,
#   'finally': 19,
#   'peacefully': 1,
#   'fools': 7,
#   'anger': 5,
#   'youssefkawkgi': 1,
#   'joe': 6,
#   'newrepublic': 2,
#   'writes': 11,
#   'interior': 21,
#   'org': 5,
#   'shareholder': 3,
#   'consistently': 2,
#   'conservationorg': 6,
#   'susanwojcicki': 1,
#   'schimmbo': 1,
#   'rangers': 3,
#   'decomposition': 1,
#   'startunnels': 1,
#   'sfitz': 1,
#   'senbobcasey': 2,
#   'courage': 2,
#   'thedemocrats': 6,
#   'stored': 2,
#   'pine': 3,
#   'baw': 2,
#   'reflect': 4,
#   'dunningrandall': 1,
#   'jew': 1,
#   'biking': 2,
#   'therealnews': 1,
#   'nash': 1,
#   'fo': 3,
#   'changescience': 1,
#   'cineversitytv': 1,
#   'yeseniatwigs': 1,
#   'intimate': 3,
#   'supponorthern': 1,
#   'mikegrunwald': 1,
#   'changes': 69,
#   'authoritarian': 2,
#   'reversing': 13,
#   'income': 11,
#   'taxes': 25,
#   'ruined': 1,
#   'frontlinepbs': 2,
#   'peopleurlweb': 1,
#   'mt': 5,
#   'ranks': 3,
#   'misssadiev': 1,
#   'whore': 1,
#   'founder': 6,
#   'jackharries': 1,
#   'paourselves': 1,
#   'moron': 13,
#   'signed': 22,
#   'betsydevosed': 1,
#   'greenbeltnagger': 1,
#   'minimal': 2,
#   'malcolmturnbull': 1,
#   'mays': 6,
#   'mouths': 2,
#   'folded': 1,
#   'eyebrows': 1,
#   'harvardchansph': 3,
#   'boigu': 1,
#   'rolandsmartin': 1,
#   'richarddixon': 1,
#   'tomilahren': 5,
#   'crime': 30,
#   'atticusgf': 1,
#   'chaos': 4,
#   'minutes': 15,
#   'theforumnorwich': 1,
#   'palau': 3,
#   'julia': 5,
#   'architects': 3,
#   'rescue': 6,
#   'letting': 4,
#   'aldairmaruz': 1,
#   'fox': 25,
#   'retreat': 11,
#   'wldbabe': 1,
#   'narrowly': 1,
#   'stand': 44,
#   'godsquad': 1,
#   'women': 83,
#   'folks': 14,
#   'amreading': 6,
#   'shazbkhanzdageo': 1,
#   'laughed': 2,
#   'coal': 94,
#   'tednordh': 1,
#   'nut': 2,
#   'abdulszn': 1,
#   'goelectric': 1,
#   'nineyearold': 2,
#   'even': 166,
#   'yearcombined': 2,
#   'delotaylor': 1,
#   'funds': 9,
#   'purged': 3,
#   'barely': 9,
#   'stepstoreverseclimatechange': 5,
#   'connects': 1,
#   'edglasgow': 1,
#   'akkoca': 1,
#   'automation': 2,
#   'soynoviodetodas': 1,
#   'climatecouncil': 2,
#   'dlomax': 1,
#   'unitydays': 1,
#   'ttrif': 1,
#   'weeks': 13,
#   'encroachment': 1,
#   'naming': 2,
#   'pharoahlives': 1,
#   'sabal': 1,
#   'detachment': 1,
#   'dem': 8,
#   'hot': 91,
#   'lowkey': 4,
#   'nwankpaa': 1,
#   'earthdaywithdna': 1,
#   'bobwieckowskica': 1,
#   'timesmore': 1,
#   'sturgeons': 1,
#   'basin': 2,
#   'mj': 1,
#   'rightsopposing': 1,
#   'ltg': 1,
#   'meteorology': 2,
#   'hayhoe': 1,
#   'obvs': 2,
#   'aliens': 6,
#   'hack': 7,
#   'monster': 5,
#   'century': 17,
#   'value': 11,
#   'dicapriolegend': 1,
#   'outdoorsy': 1,
#   'powering': 1,
#   'west': 18,
#   'although': 6,
#   'minority': 1,
#   'globalisation': 3,
#   'reign': 2,
#   'fangirlshirts': 1,
#   'mbalter': 1,
#   'gayriot': 3,
#   'suppoagscottpruitt': 1,
#   'contemptthe': 1,
#   'nomination': 3,
#   'walters': 1,
#   'nicolairoan': 1,
#   'instead': 61,
#   'flightsbut': 1,
#   'happyjulieis': 1,
#   'natgeothese': 1,
#   'savetheepa': 5,
#   'realsaibai': 1,
#   'breitbartlook': 1,
#   'tell': 135,
#   'hanson': 2,
#   'sends': 9,
#   'pick': 50,
#   'bears': 44,
#   'imaniraeleen': 1,
#   'diverse': 1,
#   'cried': 2,
#   'fell': 5,
#   'brooklynseipel': 1,
#   'otherwise': 12,
#   'poojaxlays': 1,
#   'habitats': 4,
#   'pennykilkenny': 1,
#   'timeyes': 1,
#   'zeddrebel': 1,
#   'nuttall': 3,
#   'sabrinahaqqie': 1,
#   'ditch': 7,
#   'katyperrys': 1,
#   'gentrification': 1,
#   'unitewomenorg': 1,
#   'trumpor': 1,
#   'shrinking': 6,
#   'alicemolero': 2,
#   'putting': 28,
#   'hn': 1,
#   'ajenews': 2,
#   'industrial': 3,
#   'four': 15,
#   'jilloutman': 1,
#   'povs': 1,
#   'uc': 4,
#   'lisad': 1,
#   'smh': 21,
#   'highlight': 11,
#   'tx': 2,
#   'ton': 2,
#   'republic': 2,
#   'energyenviro': 4,
#   'wato': 1,
#   'mxschell': 1,
#   'boosters': 1,
#   'pointless': 3,
#   'blacktencommand': 1,
#   'moodtrble': 1,
#   'ministers': 5,
#   'potusclimate': 1,
#   'black': 20,
#   'ominous': 1,
#   'recruiting': 3,
#   'fuentesursula': 1,
#   'passedread': 1,
#   'occupation': 2,
#   'egypt': 5,
#   'ideas': 23,
#   'sinc': 2,
#   'dorofcalif': 1,
#   'bellend': 1,
#   'paulwesley': 1,
#   'rachaelswindon': 4,
#   'plan': 139,
#   'crlndays': 1,
#   'speechboy': 1,
#   'gandhi': 1,
#   'underestimating': 2,
#   'aligned': 2,
#   'ecehh': 1,
#   'tweetsoutloud': 1,
#   'landscape': 3,
#   'germanys': 1,
#   'scottforflorida': 1,
#   'boingboing': 3,
#   'assad': 1,
#   'inspectnafforestationpollution': 1,
#   'assessing': 4,
#   'champions': 1,
#   'georgiiama': 1,
#   'attorney': 13,
#   'house': 142,
#   'conspiracy': 29,
#   'koenders': 1,
#   'gets': 44,
#   'raise': 23,
#   'feralandfancy': 1,
#   'goingglocal': 1,
#   'unrelated': 2,
#   'conscious': 3,
#   'denialists': 3,
#   'alepotenza': 2,
#   'looney': 3,
#   'steinberg': 1,
#   'power': 53,
#   'found': 25,
#   'defended': 3,
#   'hcombs': 1,
#   'cherihonkala': 1,
#   'overcome': 4,
#   'sfgate': 4,
#   'hurts': 7,
#   'biennalearte': 1,
#   'wealth': 12,
#   'polluti': 2,
#   'nowthisnews': 25,
#   'stacrying': 2,
#   'adaption': 1,
#   'supergirl': 1,
#   'gofundme': 1,
#   'requires': 5,
#   'mythjournalist': 1,
#   'antiterrorism': 1,
#   'extraction': 2,
#   'participate': 1,
#   'uniofoxford': 2,
#   'cigar': 1,
#   'almedalen': 1,
#   'glenont': 6,
#   'exacerbating': 2,
#   'lamerica': 1,
#   'brendaekwurzel': 1,
#   'profracking': 1,
#   'abc': 34,
#   'founding': 2,
#   'bathtaps': 1,
#   'repbarbaralee': 5,
#   'introd': 1,
#   'woodmackenzie': 1,
#   'worthy': 5,
#   'heterosexual': 1,
#   'notourjustice': 1,
#   'dizzycatdesign': 1,
#   'equalityvoted': 1,
#   'pollutants': 1,
#   'judeinlondon': 1,
#   'shagcat': 1,
#   'proterrorist': 1,
#   'sacrifices': 1,
#   'climatechan': 2,
#   'effects': 149,
#   'elected': 74,
#   'sports': 4,
#   'genders': 4,
#   'becaus': 1,
#   'kingd': 1,
#   'realits': 2,
#   'gotten': 3,
#   'levelurlweb': 3,
#   'chances': 1,
#   'changethank': 1,
#   'documentaries': 1,
#   'weapon': 6,
#   'conspira': 1,
#   'nowwatching': 1,
#   'preserve': 5,
#   'idea': 28,
#   'matthewacherry': 1,
#   'tabloids': 1,
#   'enjoyment': 1,
#   'fantasy': 2,
#   'actng': 1,
#   'kloppholic': 3,
#   'privatizing': 1,
#   'glitterglo': 1,
#   'pgsittenfeld': 1,
#   'vehicle': 5,
#   'mpapl': 1,
#   'kmiotekc': 1,
#   'episode': 16,
#   'researching': 8,
#   'clings': 1,
#   'great': 173,
#   'predicting': 5,
#   'arguably': 4,
#   'despairs': 1,
#   'radiative': 1,
#   'minor': 3,
#   'western': 5,
#   'drandrewthaler': 1,
#   'advecoltd': 1,
#   'kat': 3,
#   'vicenews': 8,
#   'bryton': 1,
#   'sicily': 2,
#   'excited': 8,
#   'thinktank': 4,
#   'defeat': 9,
#   'demonstrate': 2,
#   'scenarios': 2,
#   'instabilityno': 1,
#   'ipa': 1,
#   'evs': 1,
#   'patagonia': 6,
#   'ppmhtt': 1,
#   'leadershipurlweb': 1,
#   'consecutive': 2,
#   'coat': 3,
#   'kardashians': 2,
#   'epapollution': 1,
#   'macskagoly': 1,
#   'conclusions': 4,
#   'nprgoatsandsoda': 1,
#   'obamafoundation': 1,
#   'okomaorg': 1,
#   'alone': 14,
#   'happen': 24,
#   'foxes': 1,
#   'marty': 1,
#   'temperature': 30,
#   'luxurytravel': 1,
#   'nationalists': 1,
#   'charity': 2,
#   'smacity': 1,
#   'realnews': 1,
#   'billshortenmp': 3,
#   'lyme': 2,
#   'willful': 4,
#   'educate': 6,
#   'relied': 1,
#   'studentactivism': 1,
#   'failing': 18,
#   'fji': 1,
#   'poverty': 34,
#   'ppicnotes': 1,
#   'antide': 1,
#   'lodizzle': 1,
#   'sands': 2,
#   'qz': 7,
#   'hes': 172,
#   'dups': 2,
#   'jaynethom': 1,
#   'taezar': 1,
#   'combating': 41,
#   'bullet': 3,
#   'view': 36,
#   'phils': 1,
#   'compost': 1,
#   'yemen': 3,
#   'wastesampcattle': 1,
#   'penguin': 90,
#   'waragainstwomen': 1,
#   'selves': 1,
#   'gasflaring': 1,
#   'perpetuated': 5,
#   'book': 30,
#   'ableg': 3,
#   'fiesta': 1,
#   'defiance': 4,
#   'silence': 4,
#   'columbus': 1,
#   'krikke': 1,
#   'reachwest': 1,
#   'letters': 2,
#   'pouring': 1,
#   'decay': 1,
#   'xx': 2,
#   'nrdcaf': 1,
#   'wonread': 1,
#   'coralbleaching': 1,
#   'scenes': 2,
#   'defendtruth': 1,
#   'welfare': 2,
#   'repeated': 1,
#   'camera': 8,
#   'regret': 1,
#   'furthering': 3,
#   'download': 3,
#   'anothers': 1,
#   'searching': 1,
#   'rebeccawinthrop': 1,
#   'bomau': 1,
#   'characters': 2,
#   'catalonia': 2,
#   'trumpu': 1,
#   'ticks': 3,
#   'nat': 3,
#   'blackspence': 1,
#   'frye': 1,
#   'deptofdefense': 2,
#   'hammonds': 1,
#   'rescuers': 1,
#   'hottest': 26,
#   'rodent': 3,
#   'lecture': 8,
#   'nhsdestroying': 1,
#   'makethatchange': 1,
#   'el': 9,
#   'refuting': 11,
#   'midwest': 2,
#   'effoto': 12,
#   'carriejames': 1,
#   'reliving': 1,
#   'potuss': 1,
#   'enhance': 2,
#   'hastily': 1,
#   'drshepherd': 2,
#   'insecurity': 5,
#   'hand': 21,
#   'stato': 4,
#   'switching': 3,
#   'folder': 1,
#   'makeup': 1,
#   'conversation': 21,
#   'theyve': 6,
#   'flattered': 2,
#   'illustrate': 4,
#   'weekendwe': 1,
#   'doylejacq': 1,
#   'spouted': 1,
#   'line': 24,
#   'warmingwhen': 1,
#   'eriksolheim': 9,
#   'echoed': 1,
#   'miketqub': 1,
#   'page': 62,
#   'video': 62,
#   'anylaurie': 1,
#   'storm': 17,
#   'bettybowers': 1,
#   'brokenearthday': 1,
#   'waffle': 1,
#   'muslim': 7,
#   'pathways': 1,
#   'addresses': 3,
#   'preachy': 1,
#   'plot': 8,
#   'islahmufti': 1,
#   'incredulouswhat': 1,
#   'dorobc': 1,
#   'exists': 41,
#   'realjameswoods': 6,
#   'nationalfarmers': 1,
#   'hacked': 7,
#   'metal': 1,
#   'teamossoff': 1,
#   'mikegalsworthy': 1,
#   'goals': 21,
#   'chunk': 1,
#   'vanished': 1,
#   'predominant': 1,
#   'executive': 53,
#   'obamafarewell': 2,
#   'drug': 2,
#   'catastrophically': 1,
#   'pointthen': 1,
#   'turnbull': 19,
#   'bloomberg': 28,
#   'datacityworld': 1,
#   'copernicusunoff': 1,
#   'apt': 2,
#   'impactexistential': 1,
#   'ontario': 5,
#   'avhack': 1,
#   'honoured': 2,
#   'alter': 9,
#   'lmk': 1,
#   'achieving': 4,
#   'degradation': 3,
#   'thenarayan': 1,
#   'abortions': 3,
#   'miel': 4,
#   'msnbc': 12,
#   'part': 1,
#   'beat': 15,
#   'wit': 5,
#   'composting': 3,
#   'minded': 4,
#   'chrisamccoy': 1,
#   'samjamesvelde': 2,
#   'quickly': 8,
#   'tree': 15,
#   'carbonjam': 1,
#   'summit': 37,
#   'headass': 1,
#   'seiresearch': 1,
#   'avedangerous': 1,
#   'madispaghetti': 1,
#   'twcuddleston': 1,
#   'toll': 11,
#   'polli': 1,
#   'growing': 25,
#   'popular': 18,
#   'alefive': 1,
#   'beli': 2,
#   'pirate': 1,
#   'rainforestcx': 1,
#   'titanic': 4,
#   'assuming': 6,
#   'slate': 39,
#   'havingamptimes': 1,
#   'suing': 34,
#   'annehidalgo': 3,
#   'garyraybetz': 1,
#   'cclsaltlake': 2,
#   'curing': 1,
#   'agchatoz': 1,
#   'karenldukes': 1,
#   'scottwiener': 1,
#   'dismiss': 5,
#   'phrase': 23,
#   'possession': 1,
#   'igggie': 1,
#   'kamalaharris': 42,
#   'ar': 1,
#   'scoped': 1,
#   'salon': 16,
#   'sengarypeters': 1,
#   'worldveganday': 5,
#   'montana': 1,
#   'bucks': 3,
#   'doubting': 1,
#   'scientistsclimate': 1,
#   'designtaxi': 1,
#   'solnit': 1,
#   'pepcanadell': 1,
#   'dwallacewellss': 1,
#   'undrstnd': 1,
#   'smerconish': 1,
#   'climatevoter': 2,
#   'whod': 1,
#   'gorsuchs': 2,
#   'marks': 12,
#   'sem': 1,
#   'adoftheday': 2,
#   'dmitrii': 1,
#   'changelarissa': 1,
#   'reminding': 2,
#   'vicbudget': 1,
#   'conduct': 1,
#   'poof': 1,
#   'bogus': 4,
#   'figure': 10,
#   'johnshopkinsehe': 1,
#   'gregjenner': 1,
#   'tackle': 159,
#   'martychavez': 1,
#   'elonmusk': 7,
#   'soak': 1,
#   'changedestroyed': 1,
#   'processes': 5,
#   'quadratic': 1,
#   'rejection': 2,
#   'warsforoil': 1,
#   'dwtkns': 1,
#   'pariah': 3,
#   'beach': 6,
#   'pabloriddla': 1,
#   'children': 45,
#   'hey': 66,
#   'carmeljudeobsc': 1,
#   'students': 10,
#   'annemariayritys': 1,
#   'dearclarissa': 1,
#   'btwn': 1,
#   'ddentner': 1,
#   'near': 10,
#   'hale': 1,
#   'patrickjegan': 1,
#   'rachelbkr': 1,
#   'vascopyjama': 1,
#   'uppermiddle': 1,
#   'predetermined': 2,
#   'billgates': 2,
#   'jgirvin': 1,
#   'parallel': 1,
#   'posttruth': 1,
#   'epas': 38,
#   'greenbrexit': 2,
#   'influence': 12,
#   'marrakech': 4,
#   'lesbian': 5,
#   'sitting': 8,
#   'whispering': 1,
#   'dprint': 1,
#   'put': 59,
#   'nasaclimate': 3,
#   'conclusion': 6,
#   'luxembourg': 1,
#   'mondaymood': 1,
#   'hypothetical': 5,
#   'inherent': 2,
#   'marmot': 2,
#   'vastleft': 1,
#   'senangusking': 1,
#   'putapriceonit': 1,
#   'jonnyecology': 1,
#   'gove': 7,
#   'friends': 36,
#   'orwell': 1,
#   'chubbahbubbah': 1,
#   'ashleylynch': 2,
#   'analysis': 14,
#   'anthropocene': 1,
#   'weve': 30,
#   'external': 7,
#   'carson': 1,
#   'finnskata': 1,
#   'technically': 1,
#   'agree': 76,
#   'arabia': 3,
#   'damnit': 1,
#   'worry': 58,
#   'sachasaeen': 1,
#   'aides': 6,
#   'alejand': 1,
#   'devils': 1,
#   'kathrynbruscobk': 1,
#   'counts': 2,
#   'knowledgereluctancy': 1,
#   'opengov': 1,
#   ...}}

# %%
df_token = pd.DataFrame(beliver, columns = [1, 2, 0, -1, 'all'])

# %%
beliver.keys()
# Out:
# dict_keys([1, 2, 0, -1, 'all'])

# %%
df_token = df_token.fillna(0)

# %%
total_words = sum([v for v in beliver['all'].values()])
total_words
# Out:
# 181649

# %%
_ = plt.hist([v for v in beliver['all'].values() if v < 10],bins=10)
plt.ylabel("number of words")
plt.xlabel("word frequency")
# Out:
# Text(0.5, 0, 'word frequency')

# %%
def get_number_of_words(value):
    return len([v for v in beliver['all'].values() if v == value])

# %%
get_number_of_words(2)
# Out:
# 2902

# %%
def get_rare_words(value, start , stop):
    
    rare_words = [k for k, v in beliver['all'].items() if v==value] 
    print(rare_words[start:stop], len(rare_words))
    return rare_words

# %%
rare_words = get_rare_words(9, 100, 200)
# Out:
# ['smoking', 'funder', 'held', 'marchforscience', 'californias', 'envoy', 'solved', 'earlier', 'considered', 'bret', 'saved', 'natureorg', 'ptsd', 'antiabortion', 'guns', 'round', 'happeningand', 'turnbullmalcolm', 'bostonglobe', 'min', 'coffee', 'oped', 'prime', 'sometimes', 'mostly', 'outpace', 'bleaching', 'weatherchannel', 'davos', 'eventually', 'alarm', 'carney', 'differ', 'announces', 'lines', 'freeze', 'awful', 'beliefs', 'count', 'ecosystems', 'removing', 'necessary', 'plays', 'standing', 'european', 'drink', 'climatechangeisreal', 'innovative', 'arms', 'antarcticas', 'humanmade', 'certain', 'heads', 'exxonknew', 'womenclimate', 'required', 'trend', 'honest', 'author', 'michigan', 'warmth', 'streaming', 'accurate', 'tied', 'invest', 'works', 'honor', 'kid', 'newyorker', 'alliance', 'oppose', 'responds', 'seven', 'mcspocky', 'hunt', 'female', 'destroyed', 'unfccc', 'nuts', 'cbs', 'belugasolar', 'mailonline', 'feds', 'worldnews', 'reveals', 'garage', 'cernovich', 'tuckercarlson', 'usfreedomarmy', 'elitists'] 190

# %%
rare_words
# Out:
# ['confront',
#  'chair',
#  'everyday',
#  'nominee',
#  'changedenying',
#  'funds',
#  'barely',
#  'sends',
#  'defeat',
#  'el',
#  'eriksolheim',
#  'alter',
#  'smaller',
#  'wins',
#  'path',
#  'initiatives',
#  'werent',
#  'temps',
#  'zeroco',
#  'quality',
#  'proposal',
#  'illegal',
#  'burn',
#  'usual',
#  'protesting',
#  'da',
#  'jonriley',
#  'cuz',
#  'findings',
#  'largely',
#  'sa',
#  'disprove',
#  'pic',
#  'usled',
#  'wide',
#  'advocate',
#  'cry',
#  'ah',
#  'debt',
#  'obamacare',
#  'arguing',
#  'contributed',
#  'ed',
#  'assume',
#  'earthtomarrakech',
#  'africas',
#  'lolgop',
#  'willing',
#  'challenged',
#  'tillersons',
#  'mining',
#  'backwards',
#  'canadians',
#  'interests',
#  'expensive',
#  'individual',
#  'crowd',
#  'boston',
#  'ending',
#  'melts',
#  'imaginary',
#  'session',
#  'heatwaves',
#  'writing',
#  'wo',
#  'police',
#  'scottadamssays',
#  'fears',
#  'denialist',
#  'regime',
#  'slowing',
#  'determined',
#  'tomleewalker',
#  'itll',
#  'trailer',
#  'corporations',
#  'vault',
#  'narendramodi',
#  'clearly',
#  'shareholders',
#  'amount',
#  'planetary',
#  'fascinating',
#  'vow',
#  'fit',
#  'climatehome',
#  'badlandsnps',
#  'corals',
#  'began',
#  'sounds',
#  'barackobama',
#  'note',
#  'alexsteffen',
#  'notice',
#  'seeks',
#  'neoliberalism',
#  'immigrants',
#  'sued',
#  'charts',
#  'niggas',
#  'smoking',
#  'funder',
#  'held',
#  'marchforscience',
#  'californias',
#  'envoy',
#  'solved',
#  'earlier',
#  'considered',
#  'bret',
#  'saved',
#  'natureorg',
#  'ptsd',
#  'antiabortion',
#  'guns',
#  'round',
#  'happeningand',
#  'turnbullmalcolm',
#  'bostonglobe',
#  'min',
#  'coffee',
#  'oped',
#  'prime',
#  'sometimes',
#  'mostly',
#  'outpace',
#  'bleaching',
#  'weatherchannel',
#  'davos',
#  'eventually',
#  'alarm',
#  'carney',
#  'differ',
#  'announces',
#  'lines',
#  'freeze',
#  'awful',
#  'beliefs',
#  'count',
#  'ecosystems',
#  'removing',
#  'necessary',
#  'plays',
#  'standing',
#  'european',
#  'drink',
#  'climatechangeisreal',
#  'innovative',
#  'arms',
#  'antarcticas',
#  'humanmade',
#  'certain',
#  'heads',
#  'exxonknew',
#  'womenclimate',
#  'required',
#  'trend',
#  'honest',
#  'author',
#  'michigan',
#  'warmth',
#  'streaming',
#  'accurate',
#  'tied',
#  'invest',
#  'works',
#  'honor',
#  'kid',
#  'newyorker',
#  'alliance',
#  'oppose',
#  'responds',
#  'seven',
#  'mcspocky',
#  'hunt',
#  'female',
#  'destroyed',
#  'unfccc',
#  'nuts',
#  'cbs',
#  'belugasolar',
#  'mailonline',
#  'feds',
#  'worldnews',
#  'reveals',
#  'garage',
#  'cernovich',
#  'tuckercarlson',
#  'usfreedomarmy',
#  'elitists']

# %%
# how many words appear more than 10 times?
# how many words of the total does that account for?
print(len([v for v in beliver['all'].values() if v >= 9]))
occurs_more_than_10_times = sum([v for v in beliver['all'].values() if v >= 9])
print(occurs_more_than_10_times)
# Out:
# 2457
# 143608

# %%
def get_short_words(value, start , stop):
    
    rare_words = [k for k, v in beliver['all'].items() if len(k) <= value] 
    print(rare_words[start:stop], len(rare_words))
    
    return rare_words

# %%
short_words = get_short_words(3, 0, 288)
# Out:
# ['mps', 'hv', 'lo', 'yep', 'wef', 'ie', 'eu', 'hoa', 'dr', 'tf', 'zer', 'nic', 'jp', 'wai', 'cr', 'lt', 'rip', 'adp', 'die', 'umm', 'rnc', 'joe', 'org', 'baw', 'jew', 'fo', 'mt', 'fox', 'nut', 'dem', 'hot', 'mj', 'ltg', 'hn', 'uc', 'smh', 'tx', 'ton', 'abc', 'kat', 'ipa', 'evs', 'fji', 'qz', 'hes', 'xx', 'nat', 'el', 'apt', 'lmk', 'wit', 'ar', 'sem', 'hey', 'put', 'man', 'ol', 'e', 'ev', 'bp', 'rg', 'ga', 'geo', 'fml', 'iss', 'oil', 'hal', 'ac', 'ago', 'lte', 'eo', 'hfa', 'bl', 'rin', 'bom', 'rw', 'sat', 'ss', 'era', 'ucc', 'una', 'cos', 'get', 'b', 'day', 'rex', 'mo', 'mac', 'two', 'guy', 'bah', 'wow', 'uwm', 'law', 'cf', 'mlb', 'tip', 'fos', 'da', 'flu', 'yrs', 'red', 'doe', 'cuz', 'iwd', 'ye', 'bec', 'fd', 'cz', 'tbt', 'ajc', 'sa', 'yal', 'pic', 'iwo', 'vet', 'pls', 'anz', 'mr', 'li', 'agw', 'nih', 'opp', 'pow', 'buy', 'ps', 'lip', 'cry', 'npr', 'lgb', 'jr', 'ri', 'age', 'act', 'ah', 'ccc', 'crb', 'rad', 'vs', 'ris', 'wtf', 'som', 'uk', 'sec', 'max', 'fan', 'bca', 'gn', 'fkn', 'saf', 'imo', 'ill', 'los', 'nia', 'ad', 'nov', 'um', 'tap', 'rea', 'vp', 'sm', 'myc', 'aim', 'ok', 'bio', 'tie', 'met', 'ed', 'goj', 'gif', 'kxl', 'dad', 'nsw', 'doc', 'new', 'nod', 'pun', 'idk', 'wp', 'rn', 'cop', 'pdi', 'pac', 'nd', 'dig', 'mnn', 'etc', 'ajb', 'mar', 'ded', 'cus', 'nu', 'hmm', 'bro', 'add', 'de', 'hid', 'wa', 'lwv', 'adm', 'mug', 'snl', 'ccl', 'tim', 'tru', 'fat', 'rhs', 'gla', 'thx', 'gpa', 'one', 'car', 'set', 'cri', 'fuq', 'fl', 'tv', 'iot', 'wny', 'az', 'aj', 'aw', 'pro', 'fau', 'mit', 'nvm', 'ou', 'plz', 'fus', 'gro', 'kpk', 'dna', 'si', 'al', 'sdg', 'goi', 'wet', 'mor', 'box', 'imp', 'web', 'npc', 'toe', 'ag', 'tci', 'obv', 'bet', 'ban', 'kkk', 'bs', 'et', 'exp', 'ds', 'bit', 'nh', 'mix', 'ofa', 'cou', 'deb', 'ta', 'aca', 'fao', 'ram', 'cia', 'hi', 'fal', 'hiv', 'cnn', 'tfw', 'ht', 'bil', 'lat', 'em', 'nom', 'bsw', 'mpk', 'hbo', 'fra', 'acc', 'ctl', 'pr', 'yr', 'hav', 'gt', 'n', 'csr', 'kil', 'bu'] 1203

# %%
short_words
# Out:
# ['hv',
#  'lo',
#  'ie',
#  'eu',
#  'dr',
#  'tf',
#  'jp',
#  'cr',
#  'lt',
#  'fo',
#  'mt',
#  'mj',
#  'hn',
#  'uc',
#  'tx',
#  'qz',
#  'xx',
#  'el',
#  'ar',
#  'ol',
#  'e',
#  'ev',
#  'bp',
#  'rg',
#  'ga',
#  'ac',
#  'eo',
#  'bl',
#  'rw',
#  'ss',
#  'b',
#  'mo',
#  'cf',
#  'da',
#  'ye',
#  'fd',
#  'cz',
#  'sa',
#  'mr',
#  'li',
#  'ps',
#  'jr',
#  'ri',
#  'ah',
#  'vs',
#  'uk',
#  'gn',
#  'ad',
#  'um',
#  'vp',
#  'sm',
#  'ok',
#  'ed',
#  'wp',
#  'rn',
#  'nd',
#  'nu',
#  'de',
#  'wa',
#  'fl',
#  'tv',
#  'az',
#  'aj',
#  'aw',
#  'ou',
#  'si',
#  'al',
#  'ag',
#  'bs',
#  'et',
#  'ds',
#  'nh',
#  'ta',
#  'hi',
#  'ht',
#  'em',
#  'pr',
#  'yr',
#  'gt',
#  'n',
#  'bu',
#  'pa',
#  'pl',
#  'wo',
#  'tw',
#  'ez',
#  'ep',
#  'bv',
#  'x',
#  'dw',
#  'mm',
#  'ha',
#  'fp',
#  'bc',
#  'p',
#  'ab',
#  'np',
#  'ba',
#  'cc',
#  'pk',
#  'en',
#  'h',
#  'nl',
#  'fu',
#  'br',
#  'gd',
#  'yo',
#  'km',
#  'ng',
#  'rd',
#  'su',
#  'r',
#  'fx',
#  'sh',
#  'ef',
#  'ch',
#  'nz',
#  'ai',
#  'bw',
#  'ca',
#  'fb',
#  'af',
#  'eh',
#  'wh',
#  'ff',
#  'z',
#  'q',
#  'ft',
#  'dg',
#  'ci',
#  'se',
#  'qs',
#  'ki',
#  'go',
#  'te',
#  'nm',
#  'xy',
#  'oh',
#  'cg',
#  'bt',
#  'k',
#  'mp',
#  'gb',
#  'eg',
#  'cl',
#  'w',
#  'g',
#  'va',
#  'tr',
#  'ap',
#  'kn',
#  'us',
#  'gr',
#  'sq',
#  'rt',
#  'sj',
#  'ms',
#  'bn',
#  'ya',
#  'op',
#  'fm',
#  'c',
#  'ho',
#  'gw',
#  'kp',
#  'ex',
#  'sc',
#  'wv',
#  'j',
#  'po',
#  'vi',
#  'lb',
#  'ka',
#  'av',
#  'ji',
#  'di',
#  'ty',
#  'hr',
#  'th',
#  'fr',
#  'mu',
#  'cm',
#  'bb',
#  'uh',
#  'st',
#  'un',
#  'ny',
#  'jv',
#  'ip',
#  'rs',
#  'pe',
#  'pm',
#  'tt',
#  'f',
#  'il',
#  'gu',
#  'ke',
#  'oc',
#  'wi',
#  'eq',
#  'hm',
#  'dc',
#  'au',
#  'uw',
#  'id',
#  'sb',
#  'fa',
#  'nt',
#  'im',
#  'nj',
#  'v',
#  'bo',
#  'vo',
#  'na',
#  'fe',
#  'ne',
#  'pp',
#  'mf',
#  'dt',
#  'mh',
#  'du',
#  'ww',
#  'oi',
#  'ur',
#  'l',
#  'ax',
#  'mn',
#  'nc',
#  'co',
#  'u',
#  'ju',
#  'ow',
#  'la',
#  'lv',
#  'sf',
#  'ut',
#  'ew',
#  'ge',
#  'gs',
#  'xi',
#  'vr',
#  'rv',
#  'pi',
#  'hw',
#  'fg',
#  'nv',
#  'gm',
#  'uq',
#  'je',
#  'ni',
#  'ko',
#  'wt',
#  'tp',
#  'bi',
#  'mi',
#  'tl',
#  'jw',
#  'ea',
#  'mv',
#  'hb',
#  'ii',
#  'ja',
#  'yg',
#  'cv',
#  'iq',
#  'tu',
#  'tn',
#  'pc',
#  'sd',
#  'sw',
#  'le',
#  'jd',
#  'oj',
#  'es',
#  'ig',
#  'ws',
#  'jk',
#  'ay',
#  'fw',
#  'jc',
#  'yk',
#  'wr',
#  'pb',
#  'uv',
#  'os',
#  'xd',
#  'ru',
#  'sr']

# %%
# how many words appear more than 10 times?
# how many words of the total does that account for?
print(len([v for k, v in beliver['all'].items() if len(k) <= 2]))
low_length = sum([v for k, v in beliver['all'].items() if len(k) <=2])
print(low_length)
# Out:
# 288
# 4528

# %% [markdown]
# ### The amount of data left
#
# with removing the rare words and the short length words, looking at the percentage of the data left

# %%
# Looking at the data that appears more than 10 times
(occurs_more_than_10_times - low_length) / total_words
# Out:
# 0.7656524395950431

# %%
df_token['perc_1'] = (df_token[1] / df_token['all']) * 100
df_token['perc_0'] = (df_token[0] / df_token['all']) * 100
df_token['perc_2'] = (df_token[2] / df_token['all']) * 100
df_token['perc_-1'] = (df_token[-1] / df_token['all']) * 100

# %% [markdown]
# # Removing redundant data
#
# there are words that may be considered to be important because of their appearance in every class which is not reall an advantage to our model

# %%
df_token.sort_values('all', ascending = False).head(25)
# Out:
#               1       2       0     -1    all     perc_1     perc_0  \
# climate  7340.0  3345.0  1439.0  792.0  12916  56.828740  11.141220
# change   7077.0  3206.0  1375.0  735.0  12393  57.104817  11.094973
# urlweb   4014.0  3921.0   830.0  509.0   9274  43.282295   8.949752
# global   1593.0   508.0  1036.0  634.0   3771  42.243437  27.472819
# warming  1430.0   436.0   967.0  604.0   3437  41.606052  28.135001
# trump     889.0   824.0   147.0   56.0   1916  46.398747   7.672234
# believe  1004.0    21.0    87.0   46.0   1158  86.701209   7.512953
# us        445.0   293.0   101.0   63.0    902  49.334812  11.197339
# doesnt    785.0    23.0    53.0   23.0    884  88.800905   5.995475
# amp       659.0    35.0   100.0   84.0    878  75.056948  11.389522
# real      502.0    39.0    94.0   60.0    695  72.230216  13.525180
# going     590.0    16.0    35.0   28.0    669  88.191330   5.231689
# shes      627.0     1.0     9.0    1.0    638  98.275862   1.410658
# world     446.0   114.0    39.0   34.0    633  70.458136   6.161137
# people    454.0    28.0    65.0   57.0    604  75.165563  10.761589
# epa       271.0   237.0    28.0   17.0    553  49.005425   5.063291
# via       199.0   299.0    24.0   21.0    543  36.648250   4.419890
# new       283.0   191.0    44.0   23.0    541  52.310536   8.133087
# dont      386.0    30.0    73.0   42.0    531  72.693032  13.747646
# fight     286.0   159.0    21.0    7.0    473  60.465116   4.439746
# like      310.0    18.0    96.0   41.0    465  66.666667  20.645161
# trumps    191.0   238.0    24.0    8.0    461  41.431670   5.206074
# hoax      318.0    45.0    30.0   50.0    443  71.783296   6.772009
# science   236.0    94.0    29.0   77.0    436  54.128440   6.651376
# says      124.0   234.0    45.0   19.0    422  29.383886  10.663507
#
#             perc_2    perc_-1
# climate  25.898111   6.131929
# change   25.869442   5.930767
# urlweb   42.279491   5.488462
# global   13.471228  16.812517
# warming  12.685482  17.573465
# trump    43.006263   2.922756
# believe   1.813472   3.972366
# us       32.483370   6.984479
# doesnt    2.601810   2.601810
# amp       3.986333   9.567198
# real      5.611511   8.633094
# going     2.391629   4.185351
# shes      0.156740   0.156740
# world    18.009479   5.371248
# people    4.635762   9.437086
# epa      42.857143   3.074141
# via      55.064457   3.867403
# new      35.304991   4.251386
# dont      5.649718   7.909605
# fight    33.615222   1.479915
# like      3.870968   8.817204
# trumps   51.626898   1.735358
# hoax     10.158014  11.286682
# science  21.559633  17.660550
# says     55.450237   4.502370

# %%
redundant_tokens = ['climate', 'change', 'urlweb', 'global', 'warming', 'trump', 'us',
    'epa', 'via', 'trumps', 'says']

# %%
unwanted = short_words + rare_words + redundant_tokens
unwanted
# Out:
# ['hv',
#  'lo',
#  'ie',
#  'eu',
#  'dr',
#  'tf',
#  'jp',
#  'cr',
#  'lt',
#  'fo',
#  'mt',
#  'mj',
#  'hn',
#  'uc',
#  'tx',
#  'qz',
#  'xx',
#  'el',
#  'ar',
#  'ol',
#  'e',
#  'ev',
#  'bp',
#  'rg',
#  'ga',
#  'ac',
#  'eo',
#  'bl',
#  'rw',
#  'ss',
#  'b',
#  'mo',
#  'cf',
#  'da',
#  'ye',
#  'fd',
#  'cz',
#  'sa',
#  'mr',
#  'li',
#  'ps',
#  'jr',
#  'ri',
#  'ah',
#  'vs',
#  'uk',
#  'gn',
#  'ad',
#  'um',
#  'vp',
#  'sm',
#  'ok',
#  'ed',
#  'wp',
#  'rn',
#  'nd',
#  'nu',
#  'de',
#  'wa',
#  'fl',
#  'tv',
#  'az',
#  'aj',
#  'aw',
#  'ou',
#  'si',
#  'al',
#  'ag',
#  'bs',
#  'et',
#  'ds',
#  'nh',
#  'ta',
#  'hi',
#  'ht',
#  'em',
#  'pr',
#  'yr',
#  'gt',
#  'n',
#  'bu',
#  'pa',
#  'pl',
#  'wo',
#  'tw',
#  'ez',
#  'ep',
#  'bv',
#  'x',
#  'dw',
#  'mm',
#  'ha',
#  'fp',
#  'bc',
#  'p',
#  'ab',
#  'np',
#  'ba',
#  'cc',
#  'pk',
#  'en',
#  'h',
#  'nl',
#  'fu',
#  'br',
#  'gd',
#  'yo',
#  'km',
#  'ng',
#  'rd',
#  'su',
#  'r',
#  'fx',
#  'sh',
#  'ef',
#  'ch',
#  'nz',
#  'ai',
#  'bw',
#  'ca',
#  'fb',
#  'af',
#  'eh',
#  'wh',
#  'ff',
#  'z',
#  'q',
#  'ft',
#  'dg',
#  'ci',
#  'se',
#  'qs',
#  'ki',
#  'go',
#  'te',
#  'nm',
#  'xy',
#  'oh',
#  'cg',
#  'bt',
#  'k',
#  'mp',
#  'gb',
#  'eg',
#  'cl',
#  'w',
#  'g',
#  'va',
#  'tr',
#  'ap',
#  'kn',
#  'us',
#  'gr',
#  'sq',
#  'rt',
#  'sj',
#  'ms',
#  'bn',
#  'ya',
#  'op',
#  'fm',
#  'c',
#  'ho',
#  'gw',
#  'kp',
#  'ex',
#  'sc',
#  'wv',
#  'j',
#  'po',
#  'vi',
#  'lb',
#  'ka',
#  'av',
#  'ji',
#  'di',
#  'ty',
#  'hr',
#  'th',
#  'fr',
#  'mu',
#  'cm',
#  'bb',
#  'uh',
#  'st',
#  'un',
#  'ny',
#  'jv',
#  'ip',
#  'rs',
#  'pe',
#  'pm',
#  'tt',
#  'f',
#  'il',
#  'gu',
#  'ke',
#  'oc',
#  'wi',
#  'eq',
#  'hm',
#  'dc',
#  'au',
#  'uw',
#  'id',
#  'sb',
#  'fa',
#  'nt',
#  'im',
#  'nj',
#  'v',
#  'bo',
#  'vo',
#  'na',
#  'fe',
#  'ne',
#  'pp',
#  'mf',
#  'dt',
#  'mh',
#  'du',
#  'ww',
#  'oi',
#  'ur',
#  'l',
#  'ax',
#  'mn',
#  'nc',
#  'co',
#  'u',
#  'ju',
#  'ow',
#  'la',
#  'lv',
#  'sf',
#  'ut',
#  'ew',
#  'ge',
#  'gs',
#  'xi',
#  'vr',
#  'rv',
#  'pi',
#  'hw',
#  'fg',
#  'nv',
#  'gm',
#  'uq',
#  'je',
#  'ni',
#  'ko',
#  'wt',
#  'tp',
#  'bi',
#  'mi',
#  'tl',
#  'jw',
#  'ea',
#  'mv',
#  'hb',
#  'ii',
#  'ja',
#  'yg',
#  'cv',
#  'iq',
#  'tu',
#  'tn',
#  'pc',
#  'sd',
#  'sw',
#  'le',
#  'jd',
#  'oj',
#  'es',
#  'ig',
#  'ws',
#  'jk',
#  'ay',
#  'fw',
#  'jc',
#  'yk',
#  'wr',
#  'pb',
#  'uv',
#  'os',
#  'xd',
#  'ru',
#  'sr',
#  ['confront',
#   'chair',
#   'everyday',
#   'nominee',
#   'changedenying',
#   'funds',
#   'barely',
#   'sends',
#   'defeat',
#   'el',
#   'eriksolheim',
#   'alter',
#   'smaller',
#   'wins',
#   'path',
#   'initiatives',
#   'werent',
#   'temps',
#   'zeroco',
#   'quality',
#   'proposal',
#   'illegal',
#   'burn',
#   'usual',
#   'protesting',
#   'da',
#   'jonriley',
#   'cuz',
#   'findings',
#   'largely',
#   'sa',
#   'disprove',
#   'pic',
#   'usled',
#   'wide',
#   'advocate',
#   'cry',
#   'ah',
#   'debt',
#   'obamacare',
#   'arguing',
#   'contributed',
#   'ed',
#   'assume',
#   'earthtomarrakech',
#   'africas',
#   'lolgop',
#   'willing',
#   'challenged',
#   'tillersons',
#   'mining',
#   'backwards',
#   'canadians',
#   'interests',
#   'expensive',
#   'individual',
#   'crowd',
#   'boston',
#   'ending',
#   'melts',
#   'imaginary',
#   'session',
#   'heatwaves',
#   'writing',
#   'wo',
#   'police',
#   'scottadamssays',
#   'fears',
#   'denialist',
#   'regime',
#   'slowing',
#   'determined',
#   'tomleewalker',
#   'itll',
#   'trailer',
#   'corporations',
#   'vault',
#   'narendramodi',
#   'clearly',
#   'shareholders',
#   'amount',
#   'planetary',
#   'fascinating',
#   'vow',
#   'fit',
#   'climatehome',
#   'badlandsnps',
#   'corals',
#   'began',
#   'sounds',
#   'barackobama',
#   'note',
#   'alexsteffen',
#   'notice',
#   'seeks',
#   'neoliberalism',
#   'immigrants',
#   'sued',
#   'charts',
#   'niggas',
#   'smoking',
#   'funder',
#   'held',
#   'marchforscience',
#   'californias',
#   'envoy',
#   'solved',
#   'earlier',
#   'considered',
#   'bret',
#   'saved',
#   'natureorg',
#   'ptsd',
#   'antiabortion',
#   'guns',
#   'round',
#   'happeningand',
#   'turnbullmalcolm',
#   'bostonglobe',
#   'min',
#   'coffee',
#   'oped',
#   'prime',
#   'sometimes',
#   'mostly',
#   'outpace',
#   'bleaching',
#   'weatherchannel',
#   'davos',
#   'eventually',
#   'alarm',
#   'carney',
#   'differ',
#   'announces',
#   'lines',
#   'freeze',
#   'awful',
#   'beliefs',
#   'count',
#   'ecosystems',
#   'removing',
#   'necessary',
#   'plays',
#   'standing',
#   'european',
#   'drink',
#   'climatechangeisreal',
#   'innovative',
#   'arms',
#   'antarcticas',
#   'humanmade',
#   'certain',
#   'heads',
#   'exxonknew',
#   'womenclimate',
#   'required',
#   'trend',
#   'honest',
#   'author',
#   'michigan',
#   'warmth',
#   'streaming',
#   'accurate',
#   'tied',
#   'invest',
#   'works',
#   'honor',
#   'kid',
#   'newyorker',
#   'alliance',
#   'oppose',
#   'responds',
#   'seven',
#   'mcspocky',
#   'hunt',
#   'female',
#   'destroyed',
#   'unfccc',
#   'nuts',
#   'cbs',
#   'belugasolar',
#   'mailonline',
#   'feds',
#   'worldnews',
#   'reveals',
#   'garage',
#   'cernovich',
#   'tuckercarlson',
#   'usfreedomarmy',
#   'elitists'],
#  'confront',
#  'chair',
#  'everyday',
#  'nominee',
#  'changedenying',
#  'funds',
#  'barely',
#  'sends',
#  'defeat',
#  'el',
#  'eriksolheim',
#  'alter',
#  'smaller',
#  'wins',
#  'path',
#  'initiatives',
#  'werent',
#  'temps',
#  'zeroco',
#  'quality',
#  'proposal',
#  'illegal',
#  'burn',
#  'usual',
#  'protesting',
#  'da',
#  'jonriley',
#  'cuz',
#  'findings',
#  'largely',
#  'sa',
#  'disprove',
#  'pic',
#  'usled',
#  'wide',
#  'advocate',
#  'cry',
#  'ah',
#  'debt',
#  'obamacare',
#  'arguing',
#  'contributed',
#  'ed',
#  'assume',
#  'earthtomarrakech',
#  'africas',
#  'lolgop',
#  'willing',
#  'challenged',
#  'tillersons',
#  'mining',
#  'backwards',
#  'canadians',
#  'interests',
#  'expensive',
#  'individual',
#  'crowd',
#  'boston',
#  'ending',
#  'melts',
#  'imaginary',
#  'session',
#  'heatwaves',
#  'writing',
#  'wo',
#  'police',
#  'scottadamssays',
#  'fears',
#  'denialist',
#  'regime',
#  'slowing',
#  'determined',
#  'tomleewalker',
#  'itll',
#  'trailer',
#  'corporations',
#  'vault',
#  'narendramodi',
#  'clearly',
#  'shareholders',
#  'amount',
#  'planetary',
#  'fascinating',
#  'vow',
#  'fit',
#  'climatehome',
#  'badlandsnps',
#  'corals',
#  'began',
#  'sounds',
#  'barackobama',
#  'note',
#  'alexsteffen',
#  'notice',
#  'seeks',
#  'neoliberalism',
#  'immigrants',
#  'sued',
#  'charts',
#  'niggas',
#  'smoking',
#  'funder',
#  'held',
#  'marchforscience',
#  'californias',
#  'envoy',
#  'solved',
#  'earlier',
#  'considered',
#  'bret',
#  'saved',
#  'natureorg',
#  'ptsd',
#  'antiabortion',
#  'guns',
#  'round',
#  'happeningand',
#  'turnbullmalcolm',
#  'bostonglobe',
#  'min',
#  'coffee',
#  'oped',
#  'prime',
#  'sometimes',
#  'mostly',
#  'outpace',
#  'bleaching',
#  'weatherchannel',
#  'davos',
#  'eventually',
#  'alarm',
#  'carney',
#  'differ',
#  'announces',
#  'lines',
#  'freeze',
#  'awful',
#  'beliefs',
#  'count',
#  'ecosystems',
#  'removing',
#  'necessary',
#  'plays',
#  'standing',
#  'european',
#  'drink',
#  'climatechangeisreal',
#  'innovative',
#  'arms',
#  'antarcticas',
#  'humanmade',
#  'certain',
#  'heads',
#  'exxonknew',
#  'womenclimate',
#  'required',
#  'trend',
#  'honest',
#  'author',
#  'michigan',
#  'warmth',
#  'streaming',
#  'accurate',
#  'tied',
#  'invest',
#  'works',
#  'honor',
#  'kid',
#  'newyorker',
#  'alliance',
#  'oppose',
#  'responds',
#  'seven',
#  'mcspocky',
#  'hunt',
#  'female',
#  'destroyed',
#  'unfccc',
#  'nuts',
#  'cbs',
#  'belugasolar',
#  'mailonline',
#  'feds',
#  'worldnews',
#  'reveals',
#  'garage',
#  'cernovich',
#  'tuckercarlson',
#  'usfreedomarmy',
#  'elitists',
#  'climate',
#  'change',
#  'urlweb',
#  'global',
#  'warming',
#  'trump',
#  'us',
#  'epa',
#  'via',
#  'trumps',
#  'says']

# %%
def token_cleaner(df):
    
    #tokenise the tweets and create a column of tokens
    df['clean_tokens'] = [v for v in df['token_no_stop_word'] if v not in unwanted]

    # join the clean_tokens to form a sentence
    clean_tokens = [" ".join(i) for i in df['clean_tokens']]
    df['less_noise'] = clean_tokens
    
    return df

# %%
exp = token_cleaner(processed_df_train)

# %%
exp.head()
# Out:
#    sentiment                                            message  tweetid  \
# 0          1  polyscimajor epa chief doesnt think carbon dio...   625221
# 1          1  its not like we lack evidence of anthropogenic...   126103
# 2          2  rawstory researchers say we have three years t...   698562
# 3          1  todayinmaker wired   was a pivotal year in the...   573736
# 4          1  soynoviodetodas its  and a racist sexist clima...   466954
#
#                                               tokens  \
# 0  [polyscimajor, epa, chief, doesnt, think, carb...
# 1  [its, not, like, we, lack, evidence, of, anthr...
# 2  [rawstory, researchers, say, we, have, three, ...
# 3  [todayinmaker, wired, was, a, pivotal, year, i...
# 4  [soynoviodetodas, its, and, a, racist, sexist,...
#
#                                   token_no_stop_word  \
# 0  [polyscimajor, epa, chief, doesnt, think, carb...
# 1  [like, lack, evidence, anthropogenic, global, ...
# 2  [rawstory, researchers, say, three, years, act...
# 3  [todayinmaker, wired, pivotal, year, war, clim...
# 4  [soynoviodetodas, racist, sexist, climate, cha...
#
#                                                lemma  \
# 0  [polyscimajor, epa, chief, doesnt, think, carb...
# 1  [like, lack, evidence, anthropogenic, global, ...
# 2  [rawstory, researcher, say, three, year, act, ...
# 3  [todayinmaker, wired, pivotal, year, war, clim...
# 4  [soynoviodetodas, racist, sexist, climate, cha...
#
#                                                 stem  \
# 0  [polyscimajor, epa, chief, doesnt, think, carb...
# 1      [like, lack, evid, anthropogen, global, warm]
# 2  [rawstori, research, say, three, year, act, cl...
# 3  [todayinmak, wire, pivot, year, war, climat, c...
# 4  [soynoviodetoda, racist, sexist, climat, chang...
#
#                                      clean_sentences  \
# 0  polyscimajor epa chief doesnt think carbon dio...
# 1    like lack evidence anthropogenic global warming
# 2  rawstory researchers say three years act clima...
# 3  todayinmaker wired pivotal year war climate ch...
# 4  soynoviodetodas racist sexist climate change d...
#
#                                 stem_clean_sentences  polarity  subjectivity  \
# 0  polyscimajor epa chief doesnt think carbon dio...  0.083333      0.166667
# 1             like lack evid anthropogen global warm  0.000000      0.000000
# 2  rawstori research say three year act climat ch... -0.300000      0.600000
# 3  todayinmak wire pivot year war climat chang ur...  0.500000      0.800000
# 4  soynoviodetoda racist sexist climat chang deni...  0.000000      0.000000
#
#                                lemma_clean_sentences  \
# 0  polyscimajor epa chief doesnt think carbon dio...
# 1    like lack evidence anthropogenic global warming
# 2  rawstory researcher say three year act climate...
# 3  todayinmaker wired pivotal year war climate ch...
# 4  soynoviodetodas racist sexist climate change d...
#
#                                         clean_tokens  \
# 0  [polyscimajor, epa, chief, doesnt, think, carb...
# 1  [like, lack, evidence, anthropogenic, global, ...
# 2  [rawstory, researchers, say, three, years, act...
# 3  [todayinmaker, wired, pivotal, year, war, clim...
# 4  [soynoviodetodas, racist, sexist, climate, cha...
#
#                                           less_noise
# 0  polyscimajor epa chief doesnt think carbon dio...
# 1    like lack evidence anthropogenic global warming
# 2  rawstory researchers say three years act clima...
# 3  todayinmaker wired pivotal year war climate ch...
# 4  soynoviodetodas racist sexist climate change d...

# %% [markdown]
# # Train Test split with unbalanced
#
# the train test is a very valuable part of the training and assessing the model perfomance while also avoiding data leakage and overfitting of the model

# %%
# importing necessary libraries
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
 
# X -> features, y -> label
y =  processed_df_train['sentiment']
X =  processed_df_train['clean_sentences']

# dividing X, y into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                random_state = 42)

# extracting features
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(ngram_range = (1, 3))
V_train_X = vectorizer.fit_transform(X_train)
V_test_X = vectorizer.transform(X_test)


# Import the scaler module
from sklearn import preprocessing
scaler = preprocessing.MaxAbsScaler ()

# Scale data
X_train_scaled = scaler.fit_transform(V_train_X)
X_test_scaled = scaler.transform(V_test_X)

# %% [markdown]
# # Building A model with a few algorithms

# %%
# training a linear SVM classifier
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(V_train_X,y_train)
svm_predictions = svm_model_linear.predict(V_test_X)
 
# model accuracy for V_test_X 
accuracy = svm_model_linear.score(V_test_X, y_test)
 
# creating a confusion matrix
cm2 = confusion_matrix(y_test, svm_predictions)

print('Classification Report SVM')
print(classification_report(y_test, svm_predictions))
# Out:
# Classification Report SVM
#               precision    recall  f1-score   support
#
#           -1       0.78      0.40      0.53       336
#            0       0.62      0.39      0.48       547
#            1       0.78      0.85      0.81      2178
#            2       0.70      0.83      0.76       894
#
#     accuracy                           0.74      3955
#    macro avg       0.72      0.61      0.64      3955
# weighted avg       0.74      0.74      0.73      3955

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

nb_classifier = MultinomialNB()
nb_classifier.fit(V_train_X, y_train)

pred = nb_classifier.predict(V_test_X)
metrics.accuracy_score(y_test, pred)

print('Classification Report Naive')
print(classification_report(y_test, svm_predictions))
# Out:
# Classification Report Naive
#               precision    recall  f1-score   support
#
#           -1       0.79      0.41      0.54       336
#            0       0.60      0.40      0.48       547
#            1       0.76      0.87      0.81      2178
#            2       0.75      0.78      0.77       894
#
#     accuracy                           0.75      3955
#    macro avg       0.72      0.62      0.65      3955
# weighted avg       0.74      0.75      0.73      3955

# %%
# training a Naive classifierBayes 
from sklearn.linear_model import LogisticRegression
lm_vt = LogisticRegression(multi_class='ovr').fit(X_train_scaled, y_train)
pred_lr_vt = lm_vt.predict(X_test_scaled)

print('Classification Report Linear logistics')
print(classification_report(y_test, pred_lr_vt))
# Out:
# Classification Report Linear logistics
#               precision    recall  f1-score   support
#
#           -1       0.78      0.41      0.54       336
#            0       0.61      0.39      0.47       547
#            1       0.77      0.88      0.82      2178
#            2       0.75      0.78      0.76       894
#
#     accuracy                           0.75      3955
#    macro avg       0.73      0.61      0.65      3955
# weighted avg       0.74      0.75      0.74      3955

# %% [markdown]
# # Experimenting data with less noise

# %%
# importing necessary libraries
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
 
# X -> features, y -> label
exp_y =  exp['sentiment']
exp_X =  exp['less_noise']

# dividing X, y into train and test data
exp_X_train, exp_X_test, exp_y_train, exp_y_test = train_test_split(exp_X, exp_y, 
                                random_state = 42)

# extracting features
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
exp_V_train_X = vectorizer.fit_transform(exp_X_train)
exp_V_test_X = vectorizer.transform(exp_X_test)


# Import the scaler module
from sklearn import preprocessing
scaler = preprocessing.MaxAbsScaler ()

# Scale data
exp_X_train_scaled = scaler.fit_transform(exp_V_train_X)
exp_X_test_scaled = scaler.transform(exp_V_test_X)

# %%
# training a linear SVM classifier
from sklearn.svm import SVC
exp_svm_model_linear = SVC(kernel = 'linear', C = 1).fit(exp_V_train_X,exp_y_train)
exp_svm_predictions = svm_model_linear.predict(exp_V_test_X)
 
# model accuracy for V_test_X 
accuracy = svm_model_linear.score(exp_V_test_X, exp_y_test)
 
# creating a confusion matrix
cm2 = confusion_matrix(exp_y_test, exp_svm_predictions)

print('Classification Report SVM')
print(classification_report(exp_y_test, exp_svm_predictions))
# Out:
# Classification Report SVM
#               precision    recall  f1-score   support
#
#           -1       0.79      0.41      0.54       336
#            0       0.60      0.40      0.48       547
#            1       0.76      0.87      0.81      2178
#            2       0.75      0.78      0.77       894
#
#     accuracy                           0.75      3955
#    macro avg       0.72      0.62      0.65      3955
# weighted avg       0.74      0.75      0.73      3955

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

nb_classifier = MultinomialNB()
nb_classifier.fit(exp_V_train_X, exp_y_train)

exp_pred = nb_classifier.predict(exp_V_test_X)
metrics.accuracy_score(exp_y_test, exp_pred)

print('Classification Report Naive')
print(classification_report(exp_y_test, exp_svm_predictions))
# Out:
# Classification Report Naive
#               precision    recall  f1-score   support
#
#           -1       0.79      0.41      0.54       336
#            0       0.60      0.40      0.48       547
#            1       0.76      0.87      0.81      2178
#            2       0.75      0.78      0.77       894
#
#     accuracy                           0.75      3955
#    macro avg       0.72      0.62      0.65      3955
# weighted avg       0.74      0.75      0.73      3955

# %%
# training a Naive classifierBayes 
from sklearn.linear_model import LogisticRegression
lm_vt = LogisticRegression(multi_class='ovr').fit(exp_X_train_scaled, exp_y_train)
exp_pred_lr_vt = lm_vt.predict(exp_X_test_scaled)

print('Classification Report Linear logistics')
print(classification_report(exp_y_test, exp_pred_lr_vt))
# Out:
# Classification Report Linear logistics
#               precision    recall  f1-score   support
#
#           -1       0.78      0.41      0.54       336
#            0       0.61      0.39      0.47       547
#            1       0.77      0.88      0.82      2178
#            2       0.75      0.78      0.76       894
#
#     accuracy                           0.75      3955
#    macro avg       0.73      0.61      0.65      3955
# weighted avg       0.74      0.75      0.74      3955

# %% [markdown]
# # Dealing with Imbalanced Data
#
# The tweets have four classes with each class having a value count different from the other, with this imbalance available, we can train the model to be ble to presict more on who are the Pros(1) but lack the predicting ability to predict if one is Anti(-1) this leads to a problem of bias, thus with sampling our data in three follo wing ways:
#
#
#   - Upsampling the classes with less data
#   - downsampling the class with the most data
#   - Using SMOTE
#
# By investigating each type of sampling we can then pick which one is better perfoming from the f1 score, we can then follow that sammpling to make the model perfom better

# %%
processed_df_train.sentiment.value_counts()
# Out:
#  1    8530
#  2    3640
#  0    2353
# -1    1296
# Name: sentiment, dtype: int64

# %% [markdown]
# ## Creating the sampled data for upsampling the data to max class
#
# creating the sampled data to the maximum class and investigate the perfomance of the model, since we used duplicated data we should also expect the model to overfit

# %%
# Pick a class size of roughly half the size of the largest size
class_size = 8530

# Downsample classes with more than 5000 observations
pro_downsampled = resample(clean_df_train[clean_df_train['sentiment']==1],
                          replace=False, # sample without replacement (no need to duplicate observations)
                          n_samples= class_size, # match number in class_size
                          random_state=27) # reproducible results

# Upsample classes with less than 5000 observations
neutral_upsampled = resample(clean_df_train[clean_df_train['sentiment']==0],
                          replace=True, # sample with replacement (we need to duplicate observations)
                          n_samples=class_size, # match number in class_size
                          random_state=27) # reproducible results

# Upsample classes with less than 5000 observations
anti_upsampled = resample(clean_df_train[clean_df_train['sentiment']==-1],
                          replace=True, # sample with replacement (we need to duplicate observations)
                          n_samples=class_size, # match number in class_size
                          random_state=27) # reproducible results

# Upsample classes with less than 5000 observations
news_upsampled = resample(clean_df_train[clean_df_train['sentiment']==2],
                          replace=True, # sample with replacement (we need to duplicate observations)
                          n_samples=class_size, # match number in class_size
                          random_state=27) # reproducible results

# %%
# Combine sampled classes with majority class
up_sampled = pd.concat([pro_downsampled, neutral_upsampled, anti_upsampled, news_upsampled])

# Check new class counts
up_sampled['sentiment'].value_counts()
# Out:
#  1    8530
#  0    8530
# -1    8530
#  2    8530
# Name: sentiment, dtype: int64

# %%
up_sampled.shape
# Out:
# (34120, 3)

# %%
up_sampled.head()
# Out:
#        sentiment                                            message  tweetid  \
# 11729          1  ubcforestry funding from genomebc will supposa...   977844
# 8308           1  yadimoiina gag orders sure hes definitely gree...   441956
# 7159           1  pattonoswalt not ominous at all he also wants ...   978938
# 5644           1  melissajpeltier in case you forgot about that ...   587737
# 6732           1  sethmacfarlane hrc proposes installing half a ...   804767
#
#                                                   tokens  \
# 11729  [ubcforestry, funding, from, genomebc, will, s...
# 8308   [yadimoiina, gag, orders, sure, hes, definitel...
# 7159   [pattonoswalt, not, ominous, at, all, he, also...
# 5644   [melissajpeltier, in, case, you, forgot, about...
# 6732   [sethmacfarlane, hrc, proposes, installing, ha...
#
#                                       token_no_stop_word  \
# 11729  [ubcforestry, funding, genomebc, supposallynai...
# 8308   [yadimoiina, gag, orders, sure, hes, definitel...
# 7159   [pattonoswalt, ominous, also, wants, names, an...
# 5644   [melissajpeltier, case, forgot, chinese, hoax,...
# 6732   [sethmacfarlane, hrc, proposes, installing, ha...
#
#                                                    lemma  \
# 11729  [ubcforestry, funding, genomebc, supposallynai...
# 8308   [yadimoiina, gag, order, sure, he, definitely,...
# 7159   [pattonoswalt, ominous, also, want, name, anyo...
# 5644   [melissajpeltier, case, forgot, chinese, hoax,...
# 6732   [sethmacfarlane, hrc, proposes, installing, ha...
#
#                                                     stem  \
# 11729  [ubcforestri, fund, genomebc, supposallynaitke...
# 8308   [yadimoiina, gag, order, sure, hes, definit, g...
# 7159   [pattonoswalt, omin, also, want, name, anyon, ...
# 5644   [melissajpelti, case, forgot, chines, hoax, gl...
# 6732   [sethmacfarlan, hrc, propos, instal, half, bil...
#
#                                          clean_sentences  \
# 11729  ubcforestry funding genomebc supposallynaitken...
# 8308   yadimoiina gag orders sure hes definitely gree...
# 7159   pattonoswalt ominous also wants names anyone w...
# 5644   melissajpeltier case forgot chinese hoax globa...
# 6732   sethmacfarlane hrc proposes installing half bi...
#
#                                     stem_clean_sentences  polarity  \
# 11729  ubcforestri fund genomebc supposallynaitken te...  0.000000
# 8308   yadimoiina gag order sure hes definit green do...  0.150000
# 7159   pattonoswalt omin also want name anyon work cl...  0.200000
# 5644   melissajpelti case forgot chines hoax global w...  0.000000
# 6732   sethmacfarlan hrc propos instal half billion s...  0.041667
#
#        subjectivity                              lemma_clean_sentences  \
# 11729      0.000000  ubcforestry funding genomebc supposallynaitken...
# 8308       0.594444  yadimoiina gag order sure he definitely green ...
# 7159       0.100000  pattonoswalt ominous also want name anyone wor...
# 5644       0.000000  melissajpeltier case forgot chinese hoax globa...
# 6732       0.250000  sethmacfarlane hrc proposes installing half bi...
#
#                                             clean_tokens  \
# 11729  [ubcforestry, funding, genomebc, supposallynai...
# 8308   [yadimoiina, gag, orders, sure, hes, definitel...
# 7159   [pattonoswalt, ominous, also, wants, names, an...
# 5644   [melissajpeltier, case, forgot, chinese, hoax,...
# 6732   [sethmacfarlane, hrc, proposes, installing, ha...
#
#                                               less_noise
# 11729  ubcforestry funding genomebc supposallynaitken...
# 8308   yadimoiina gag orders sure hes definitely gree...
# 7159   pattonoswalt ominous also wants names anyone w...
# 5644   melissajpeltier case forgot chinese hoax globa...
# 6732   sethmacfarlane hrc proposes installing half bi...

# %% [markdown]
# ## let us have a look at the new distribution of data after upsampling

# %%
labels = ['Pro', 'News', 'Neutral', 'Anti'] 

# Get all possible labels
plt.bar(labels,df_train['sentiment'].value_counts() ,color='green')
plt.bar(labels,up_sampled['sentiment'].value_counts() ,color='orange')
plt.xticks(labels, ['Pro', 'News', 'Neutral', 'Anti'] )
plt.ylabel("# of observations")
plt.legend(['original','resampled'])
plt.show()

# %% [markdown]
# # Train Test split with balanced upsampled data

# %%
# importing necessary libraries
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
 
# X -> features, y -> label
up_y =  up_sampled['sentiment']
up_X =  up_sampled['clean_sentences']

# dividing X, y into train and test data
up_X_train, up_X_test, up_y_train, up_y_test = train_test_split(up_X, up_y, 
                                random_state = 42)

# extracting features
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
up_V_train_X = vectorizer.fit_transform(up_X_train)
up_V_test_X = vectorizer.transform(up_X_test)


# Import the scaler module
from sklearn import preprocessing
scaler = preprocessing.MaxAbsScaler ()

# Scale data
up_X_train_scaled = scaler.fit_transform(up_V_train_X)
up_X_test_scaled = scaler.transform(up_V_test_X)

# %% [markdown]
# # modelling

# %%
# training a linear SVM classifier
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(up_V_train_X,up_y_train)
up_svm_predictions = svm_model_linear.predict(up_V_test_X)
 
# model accuracy for V_test_X 
accuracy = svm_model_linear.score(up_V_test_X, up_y_test)
 
# creating a confusion matrix
cm2 = confusion_matrix(up_y_test, up_svm_predictions)

print('Classification Report SVM')
print(classification_report(up_y_test, up_svm_predictions))
# Out:
# Classification Report SVM
#               precision    recall  f1-score   support
#
#           -1       0.94      0.99      0.96      2070
#            0       0.88      0.93      0.90      2134
#            1       0.89      0.75      0.82      2147
#            2       0.89      0.95      0.92      2179
#
#     accuracy                           0.90      8530
#    macro avg       0.90      0.90      0.90      8530
# weighted avg       0.90      0.90      0.90      8530

# %%
# training a Linear Logistics 
from sklearn.linear_model import LogisticRegression
lm_vt = LogisticRegression(multi_class='ovr').fit(up_V_train_X, up_y_train)
up_pred_lr_vt = lm_vt.predict(up_V_test_X)

# printing the classification report
print('Classification Report Linear logistics')
print(classification_report(up_y_test, up_pred_lr_vt))
# Out:
# Classification Report Linear logistics
#               precision    recall  f1-score   support
#
#           -1       0.91      0.96      0.94      2070
#            0       0.84      0.87      0.86      2134
#            1       0.86      0.69      0.77      2147
#            2       0.84      0.93      0.89      2179
#
#     accuracy                           0.86      8530
#    macro avg       0.86      0.86      0.86      8530
# weighted avg       0.86      0.86      0.86      8530

# %%
# Training the scaled data for the Linear Logistics

slm_vt = LogisticRegression(multi_class='ovr').fit(up_X_train_scaled, up_y_train)
up_spred_lr_vt = slm_vt.predict(up_X_test_scaled)
print('Classification Report Linear logistics')
print(classification_report(up_y_test,up_spred_lr_vt))
# Out:
# Classification Report Linear logistics
#               precision    recall  f1-score   support
#
#           -1       0.94      0.99      0.97      2070
#            0       0.88      0.95      0.92      2134
#            1       0.93      0.75      0.83      2147
#            2       0.90      0.96      0.93      2179
#
#     accuracy                           0.91      8530
#    macro avg       0.91      0.91      0.91      8530
# weighted avg       0.91      0.91      0.91      8530

# %% [markdown]
# # Hyperparameter tuning
#
# Getting the best hyperparameters for the upsampled data

# %%
# Import Grid search for hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# number of folds to be tested on
nfolds = 5

# the values of c to check for
Cs = [0.001, 0.01, 0.1, 1, 10]

# the values of gamma
gammas = [0.001, 0.01, 0.1, 1]

# Creating the parameters dictionary
param_grid = {
    'C'     : Cs,
    'gamma' : gammas
    }

# Applying the grid search and comparing based on the f1 score
grid_SVM = GridSearchCV(SVC(kernel = 'linear'), param_grid, scoring='f1', cv=nfolds)
grid_SVM.fit(V_train_X, y_train)

# Getting the best parameters of grid search
grid_SVM.best_params_

# %% [markdown]
# # Beast feature selection

# %%
# Import the feature selector module
from sklearn import feature_selection
from sklearn.feature_selection import f_classif

# Set up selector, choosing score function and number of features to retain
selector_kbest = feature_selection.SelectKBest(score_func=f_classif, k=20)


# Transform (i.e.: run selection on) the training data
X_train_kbest = selector_kbest.fit_transform(V_train_X, y_train)

# Fit model to the transformed data
SVM_k_best = SVC(kernel='linear', degree=0.001, C=0.001).fit(X_train_kbest, y_train)


# Before generating predictions, we'll need to transform the test data the same way we did the train data
X_test_kbest = selector_kbest.transform(V_test_X)

# Generate predictions from var thresh model
pred_lm_kbest = SVM_k_best.predict(X_test_kbest)


#rbf_pred = rbf.predict(V_test_X)
print('Classification Report poly_pred ')
print(classification_report(y_test, pred_lm_kbest))

# %% [markdown]
# ## Creating the Data for donwsampling to min class
#
# Creating a data frame with down sampled data to min data available in the classes, which is class Anti(-1) with the count of 1296

# %%
# Pick a class size of roughly half the size of the largest size
min_class_size = 1296

# Downsample classes with more than 5000 observations
pro_down_sampled = resample(processed_df_train[processed_df_train['sentiment']==1],
                          replace=False, # sample without replacement (no need to duplicate observations)
                          n_samples= min_class_size, # match number in class_size
                          random_state=27) # reproducible results

# Upsample classes with less than 5000 observations
neutral_down_sampled = resample(processed_df_train[processed_df_train['sentiment']==0],
                          replace=True, # sample with replacement (we need to duplicate observations)
                          n_samples= min_class_size, # match number in class_size
                          random_state=27) # reproducible results

# Upsample classes with less than 5000 observations
anti_down_sampled = resample(processed_df_train[processed_df_train['sentiment']==-1],
                          replace=True, # sample with replacement (we need to duplicate observations)
                          n_samples= min_class_size, # match number in class_size
                          random_state=27) # reproducible results

# Upsample classes with less than 5000 observations
news_down_sampled = resample(processed_df_train[processed_df_train['sentiment']==2],
                          replace=True, # sample with replacement (we need to duplicate observations)
                          n_samples= min_class_size, # match number in class_size
                          random_state=27) # reproducible results

# %%
# Combine sampled classes with majority class
down_sampled = pd.concat([pro_down_sampled, neutral_down_sampled, anti_down_sampled, news_down_sampled])

# Check new class counts
down_sampled['sentiment'].value_counts()
# Out:
#  1    1296
#  0    1296
# -1    1296
#  2    1296
# Name: sentiment, dtype: int64

# %%
down_sampled.shape
# Out:
# (5184, 11)

# %%
down_sampled.head()
# Out:
#        sentiment                                            message  tweetid  \
# 11729          1  ubcforestry funding from genomebc will supposa...   977844
# 8308           1  yadimoiina gag orders sure hes definitely gree...   441956
# 7159           1  pattonoswalt not ominous at all he also wants ...   978938
# 5644           1  melissajpeltier in case you forgot about that ...   587737
# 6732           1  sethmacfarlane hrc proposes installing half a ...   804767
#
#                                                   tokens  \
# 11729  [ubcforestry, funding, from, genomebc, will, s...
# 8308   [yadimoiina, gag, orders, sure, hes, definitel...
# 7159   [pattonoswalt, not, ominous, at, all, he, also...
# 5644   [melissajpeltier, in, case, you, forgot, about...
# 6732   [sethmacfarlane, hrc, proposes, installing, ha...
#
#                                       token_no_stop_word  \
# 11729  [ubcforestry, funding, genomebc, supposallynai...
# 8308   [yadimoiina, gag, orders, sure, hes, definitel...
# 7159   [pattonoswalt, ominous, also, wants, names, an...
# 5644   [melissajpeltier, case, forgot, chinese, hoax,...
# 6732   [sethmacfarlane, hrc, proposes, installing, ha...
#
#                                                    lemma  \
# 11729  [ubcforestry, funding, genomebc, supposallynai...
# 8308   [yadimoiina, gag, order, sure, he, definitely,...
# 7159   [pattonoswalt, ominous, also, want, name, anyo...
# 5644   [melissajpeltier, case, forgot, chinese, hoax,...
# 6732   [sethmacfarlane, hrc, proposes, installing, ha...
#
#                                                     stem  \
# 11729  [ubcforestri, fund, genomebc, supposallynaitke...
# 8308   [yadimoiina, gag, order, sure, hes, definit, g...
# 7159   [pattonoswalt, omin, also, want, name, anyon, ...
# 5644   [melissajpelti, case, forgot, chines, hoax, gl...
# 6732   [sethmacfarlan, hrc, propos, instal, half, bil...
#
#                                          clean_sentences  \
# 11729  ubcforestry funding genomebc supposallynaitken...
# 8308   yadimoiina gag orders sure hes definitely gree...
# 7159   pattonoswalt ominous also wants names anyone w...
# 5644   melissajpeltier case forgot chinese hoax globa...
# 6732   sethmacfarlane hrc proposes installing half bi...
#
#                                     stem_clean_sentences  polarity  \
# 11729  ubcforestri fund genomebc supposallynaitken te...  0.000000
# 8308   yadimoiina gag order sure hes definit green do...  0.150000
# 7159   pattonoswalt omin also want name anyon work cl...  0.200000
# 5644   melissajpelti case forgot chines hoax global w...  0.000000
# 6732   sethmacfarlan hrc propos instal half billion s...  0.041667
#
#        subjectivity                              lemma_clean_sentences  \
# 11729      0.000000  ubcforestry funding genomebc supposallynaitken...
# 8308       0.594444  yadimoiina gag order sure he definitely green ...
# 7159       0.100000  pattonoswalt ominous also want name anyone wor...
# 5644       0.000000  melissajpeltier case forgot chinese hoax globa...
# 6732       0.250000  sethmacfarlane hrc proposes installing half bi...
#
#                                             clean_tokens  \
# 11729  [ubcforestry, funding, genomebc, supposallynai...
# 8308   [yadimoiina, gag, orders, sure, hes, definitel...
# 7159   [pattonoswalt, ominous, also, wants, names, an...
# 5644   [melissajpeltier, case, forgot, chinese, hoax,...
# 6732   [sethmacfarlane, hrc, proposes, installing, ha...
#
#                                               less_noise
# 11729  ubcforestry funding genomebc supposallynaitken...
# 8308   yadimoiina gag orders sure hes definitely gree...
# 7159   pattonoswalt ominous also wants names anyone w...
# 5644   melissajpeltier case forgot chinese hoax globa...
# 6732   sethmacfarlane hrc proposes installing half bi...

# %%
df_train.sentiment.value_counts()
# Out:
#  1    8530
#  2    3640
#  0    2353
# -1    1296
# Name: sentiment, dtype: int64

# %% [markdown]
# ## let us have a look at the new distribution of data after downsampling

# %%
labels = ['Pro', 'News', 'Neutral', 'Anti'] 

# Get all possible labels
plt.bar(labels,df_train['sentiment'].value_counts() ,color='green')
plt.bar(labels,down_sampled['sentiment'].value_counts() ,color='orange')
plt.xticks(labels, ['Pro', 'News', 'Neutral', 'Anti'] )
plt.ylabel("# of observations")
plt.legend(['original','resampled'])
plt.show()

# %% [markdown]
# # Train Test split with balanced downsampled data
#
# spliting and transforming the down sampled data and scaling it at the same town for those algorithms that need scaled data

# %%
# importing necessary libraries
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
 
# X -> features, y -> label
down_y =  down_sampled['sentiment']
down_X =  down_sampled['clean_sentences']

# dividing X, y into train and test data
down_X_train, down_X_test, down_y_train, down_y_test = train_test_split(down_X, down_y, 
                                random_state = 42)

# extracting features
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
down_V_train_X = vectorizer.fit_transform(down_X_train)
down_V_test_X = vectorizer.transform(down_X_test)


# Import the scaler module
from sklearn import preprocessing
scaler = preprocessing.MaxAbsScaler ()
# Scale data
down_X_train_scaled = scaler.fit_transform(down_V_train_X)
down_X_test_scaled = scaler.transform(down_V_test_X)

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt


pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
])

X = scaler.fit_transform(pipeline.fit_transform(down_X_train).todense())

pca = PCA(n_components=2).fit(X)
data2D = pca.transform(X)
plt.scatter(data2D[:,0], data2D[:,1], c = down_y_train)

# 
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2).fit(X)
centers2D = pca.transform(kmeans.cluster_centers_)

plt.scatter(centers2D[:,0], centers2D[:,1], 
            marker='x', s=200, linewidths=3, c='b')
plt.show()              #not required if using ipython notebook

# %% [markdown]
# # modelling the down scaled data

# %%
# training a linear SVM classifier
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(down_V_train_X,down_y_train)
down_svm_predictions = svm_model_linear.predict(down_V_test_X)
 
# model accuracy for V_test_X 
accuracy = svm_model_linear.score(down_V_test_X, down_y_test)
 
# creating a confusion matrix
cm2 = confusion_matrix(down_y_test, down_svm_predictions)

print('Classification Report SVM')
print(classification_report(down_y_test, down_svm_predictions))
# Out:
# Classification Report SVM
#               precision    recall  f1-score   support
#
#           -1       0.84      0.78      0.81       294
#            0       0.63      0.70      0.67       306
#            1       0.70      0.58      0.63       352
#            2       0.77      0.87      0.81       344
#
#     accuracy                           0.73      1296
#    macro avg       0.73      0.73      0.73      1296
# weighted avg       0.73      0.73      0.73      1296

# %%
# training a Linear Logistics 
from sklearn.linear_model import LogisticRegression
lm_vt = LogisticRegression(multi_class='ovr').fit(down_V_train_X, down_y_train)
down_pred_lr_vt = lm_vt.predict(down_V_test_X)

# printing the classification report
print('Classification Report Linear logistics')
print(classification_report(down_y_test, down_pred_lr_vt))
# Out:
# Classification Report Linear logistics
#               precision    recall  f1-score   support
#
#           -1       0.77      0.77      0.77       294
#            0       0.65      0.66      0.66       306
#            1       0.70      0.53      0.60       352
#            2       0.72      0.88      0.79       344
#
#     accuracy                           0.71      1296
#    macro avg       0.71      0.71      0.71      1296
# weighted avg       0.71      0.71      0.70      1296

# %%
# Training the scaled data for the Linear Logistics

slm_vt = LogisticRegression(multi_class='ovr').fit(down_X_train_scaled, down_y_train)
down_spred_lr_vt = slm_vt.predict(down_X_test_scaled)
print('Classification Report Linear logistics')
print(classification_report(down_y_test,down_spred_lr_vt))
# Out:
# Classification Report Linear logistics
#               precision    recall  f1-score   support
#
#           -1       0.83      0.81      0.82       294
#            0       0.65      0.73      0.69       306
#            1       0.74      0.56      0.64       352
#            2       0.76      0.87      0.81       344
#
#     accuracy                           0.74      1296
#    macro avg       0.74      0.74      0.74      1296
# weighted avg       0.74      0.74      0.74      1296

# %% [markdown]
# # Hyperparameter tuning
#
# Getting the best hyperparameters for the downsampled data

# %%
# Import Grid search for hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# number of folds to be tested on
nfolds = 2

# the values of c to check for
Cs = [0.001, 0.01, 0.1, 1, 10]

# the values of gamma
gammas = [0.001, 0.01, 0.1, 1]

# Creating the parameters dictionary
param_grid = {
    'C'     : Cs,
    'gamma' : gammas
    }

# Applying the grid search and comparing based on the f1 score
grid_SVM = GridSearchCV(SVC(kernel='poly'), param_grid, scoring='f1', cv=nfolds)
grid_SVM.fit(V_train_X, y_train)

# Getting the best parameters of grid search
grid_SVM.best_params_

# %% [markdown]
# # Best feature selection

# %%
# Import the feature selector module
from sklearn import feature_selection
from sklearn.feature_selection import f_classif

# Set up selector, choosing score function and number of features to retain
selector_kbest = feature_selection.SelectKBest(score_func=f_classif, k=20)


# Transform (i.e.: run selection on) the training data
X_train_kbest = selector_kbest.fit_transform(V_train_X, y_train)

# Fit model to the transformed data
SVM_k_best = SVC(kernel='linear', degree=0.001, C=0.001).fit(X_train_kbest, y_train)


# Before generating predictions, we'll need to transform the test data the same way we did the train data
X_test_kbest = selector_kbest.transform(V_test_X)

# Generate predictions from var thresh model
pred_lm_kbest = SVM_k_best.predict(X_test_kbest)


#rbf_pred = rbf.predict(V_test_X)
print('Classification Report poly_pred ')
print(classification_report(y_test, pred_lm_kbest))

# %% [markdown]
# # Creating sample data with SMOTE

# %%
# importing necessary libraries
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
 
# X -> features, y -> label
y =  sampled['sentiment']
X =  sampled['clean_sentences']

# dividing X, y into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                random_state = 42)

# extracting features
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
V_train_X = vectorizer.fit_transform(X_train)
V_test_X = vectorizer.transform(X_test)


# Import the scaler module
from sklearn import preprocessing
scaler = preprocessing.MaxAbsScaler ()
# Scale data
X_train_scaled = scaler.fit_transform(V_train_X)
x_test_scaled = scaler.transform(V_test_X)

# %%
 # training a DescisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(X_train_scaled, y_train)
dtree_predictions = dtree_model.predict(x_test_scaled)
 
# creating a confusion matrix
cm1 = confusion_matrix(y_test, dtree_predictions)
print('Classification Report Decision Tree')
print(classification_report(y_test, dtree_predictions))
# Out:
# Classification Report Decision Tree
#               precision    recall  f1-score   support
#
#           -1       0.35      0.47      0.40      1203
#            0       0.95      0.03      0.06      1266
#            1       0.41      0.75      0.53      2008
#            2       0.59      0.22      0.32      1273
#
#     accuracy                           0.41      5750
#    macro avg       0.58      0.36      0.33      5750
# weighted avg       0.56      0.41      0.35      5750

# %%
# training a linear SVM classifier
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(V_train_X, y_train)
svm_predictions = svm_model_linear.predict(V_test_X)
 
# model accuracy for V_test_X 
accuracy = svm_model_linear.score(V_test_X, y_test)
 
# creating a confusion matrix
cm2 = confusion_matrix(y_test, svm_predictions)

print('Classification Report SVM')
print(classification_report(y_test, svm_predictions))
# Out:
# Classification Report SVM
#               precision    recall  f1-score   support
#
#           -1       0.84      0.90      0.87      1203
#            0       0.77      0.73      0.75      1266
#            1       0.77      0.75      0.76      2008
#            2       0.81      0.82      0.82      1273
#
#     accuracy                           0.79      5750
#    macro avg       0.80      0.80      0.80      5750
# weighted avg       0.79      0.79      0.79      5750

# %%
rbf = SVC(kernel='rbf', gamma=0.5, C=0.1).fit(V_train_X, y_train)
poly = SVC(kernel='poly', degree=3, C=1).fit(V_train_X, y_train)

poly_pred = poly.predict(V_test_X)
rbf_pred = rbf.predict(V_test_X)
print('Classification Report poly_pred ')
print(classification_report(y_test, poly_pred))
# Out:
# Classification Report poly_pred
#               precision    recall  f1-score   support
#
#           -1       0.98      0.97      0.98      1203
#            0       0.98      0.82      0.89      1266
#            1       0.79      0.96      0.87      2008
#            2       0.95      0.79      0.86      1273
#
#     accuracy                           0.89      5750
#    macro avg       0.93      0.89      0.90      5750
# weighted avg       0.91      0.89      0.89      5750

# %%
print('Classification Report rbf_pred ')
print(classification_report(y_test, rbf_pred))
# Out:
# Classification Report rbf_pred
#               precision    recall  f1-score   support
#
#           -1       0.81      0.48      0.60      1203
#            0       0.72      0.25      0.37      1266
#            1       0.45      0.91      0.60      2008
#            2       0.82      0.34      0.48      1273
#
#     accuracy                           0.55      5750
#    macro avg       0.70      0.49      0.51      5750
# weighted avg       0.66      0.55      0.52      5750

# %%
# training a KNN classifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 7).fit(V_train_X, y_train)
 
# accuracy on V_test_X
accuracy = knn.score(V_test_X, y_test)
print(accuracy)
 
# creating a confusion matrix
knn_predictions = knn.predict(V_test_X)
cm3 = confusion_matrix(y_test, knn_predictions)

print('Classification Report KNN')
print(classification_report(y_test, knn_predictions))
# Out:
# 0.6466086956521739
# Classification Report KNN
#               precision    recall  f1-score   support
#
#           -1       0.64      0.81      0.71      1203
#            0       0.57      0.62      0.59      1266
#            1       0.70      0.53      0.61      2008
#            2       0.68      0.70      0.69      1273
#
#     accuracy                           0.65      5750
#    macro avg       0.65      0.67      0.65      5750
# weighted avg       0.65      0.65      0.64      5750

# %%
# training a Naive classifierBayes 
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(V_train_X.toarray(), y_train)
gnb_predictions = gnb.predict(V_test_X.toarray())
 
# accuracy on V_test_X
accuracy = gnb.score(V_test_X.toarray(), y_test)
print(accuracy)
 
# creating a confusion matrix
cm4 = confusion_matrix(y_test, gnb_predictions)


print('Classification Report Naive Bayes')
print(classification_report(y_test, gnb_predictions))
# Out:
# 0.6052173913043478
# Classification Report Naive Bayes
#               precision    recall  f1-score   support
#
#           -1       0.49      0.99      0.65      1203
#            0       0.70      0.58      0.64      1266
#            1       0.83      0.31      0.45      2008
#            2       0.62      0.73      0.67      1273
#
#     accuracy                           0.61      5750
#    macro avg       0.66      0.65      0.60      5750
# weighted avg       0.68      0.61      0.58      5750

# %%
# training a Naive classifierBayes 
from sklearn.naive_bayes import GaussianNB
sgnb = GaussianNB().fit(X_train_scaled.toarray(), y_train)
sgnb_predictions = sgnb.predict(V_test_X.toarray())
 
# accuracy on V_test_X
accuracy = sgnb.score(x_test_scaled.toarray(), y_test)
print(accuracy)
 
# creating a confusion matrix
cm4 = confusion_matrix(y_test, sgnb_predictions)


print('Classification Report Naive Bayes')
print(classification_report(y_test, sgnb_predictions))
# Out:
# 0.6031304347826087
# Classification Report Naive Bayes
#               precision    recall  f1-score   support
#
#           -1       0.48      0.99      0.65      1203
#            0       0.70      0.58      0.63      1266
#            1       0.83      0.31      0.45      2008
#            2       0.62      0.72      0.67      1273
#
#     accuracy                           0.60      5750
#    macro avg       0.66      0.65      0.60      5750
# weighted avg       0.68      0.60      0.58      5750

# %%
b

# %%
# accuracy on V_test_X
accuracy = gnb.score(pred_lr_vt, y_test)
print(accuracy)

# %%
print('Classification Report Linear logistics')
print(classification_report(y_test, pred_lr_vt))
# Out:
# Classification Report Linear logistics
#               precision    recall  f1-score   support
#
#           -1       0.84      0.85      0.85      1203
#            0       0.76      0.67      0.71      1266
#            1       0.73      0.77      0.75      2008
#            2       0.79      0.79      0.79      1273
#
#     accuracy                           0.77      5750
#    macro avg       0.78      0.77      0.77      5750
# weighted avg       0.77      0.77      0.77      5750

# %%
slm_vt = LogisticRegression(multi_class='ovr').fit(X_train_scaled, y_train)
spred_lr_vt = slm_vt.predict(x_test_scaled)
print('Classification Report Linear logistics')
print(classification_report(y_test,spred_lr_vt))
# Out:
# Classification Report Linear logistics
#               precision    recall  f1-score   support
#
#           -1       0.88      0.92      0.90      1203
#            0       0.79      0.75      0.77      1266
#            1       0.79      0.78      0.78      2008
#            2       0.81      0.84      0.82      1273
#
#     accuracy                           0.81      5750
#    macro avg       0.82      0.82      0.82      5750
# weighted avg       0.81      0.81      0.81      5750

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=100, random_state=42).fit(V_train_X, y_train)
forest_pred = forest.predict(x_test_scaled)
print('Classification Report Linear logistics')
print(classification_report(y_test, forest_pred))
# Out:
# Classification Report Linear logistics
#               precision    recall  f1-score   support
#
#           -1       0.94      0.93      0.93      1203
#            0       0.84      0.76      0.80      1266
#            1       0.78      0.80      0.79      2008
#            2       0.77      0.82      0.80      1273
#
#     accuracy                           0.82      5750
#    macro avg       0.83      0.83      0.83      5750
# weighted avg       0.83      0.82      0.82      5750

# %% [markdown]
# # Creating A pipeline for modelling

# %%
df.head()
# Out:
#    tweetid  sentiment
# 0   169760          2
# 1    35326          0
# 2   224985          1
# 3   476263          2
# 4   872928          1

# %%
# Seperate features and tagret variables
tX = clean_df['message']
ty = clean_df['sentiment']

# Split the train data to create validation dataset
tX_train, tX_test, ty_train, ty_test = train_test_split(tX, ty, test_size=0.20, random_state=42)

# %%
from sklearn.svm import LinearSVC

#Linear SVC:
lsvc = Pipeline([('tfidf', TfidfVectorizer()), ('clf', LinearSVC(class_weight='balanced'))])

# %%
# Linear SVC
lsvc.fit(tX_train, ty_train)
lsvc_y_predict = lsvc.predict(tX_test)
print('Classification Report Linear logistics')
print(classification_report(ty_test, lsvc_y_predict))
# Out:
# Classification Report Linear logistics
#               precision    recall  f1-score   support
#
#           -1       0.64      0.56      0.60       278
#            0       0.53      0.51      0.52       425
#            1       0.82      0.80      0.81      1755
#            2       0.73      0.83      0.77       706
#
#     accuracy                           0.74      3164
#    macro avg       0.68      0.67      0.68      3164
# weighted avg       0.74      0.74      0.74      3164

# %% [markdown]
# # Training with Sampled Data

# %%
sampled.shape
# Out:
# (23000, 8)

# %%
# Seperate features and tagret variables
sX = sampled['message']
sy = sampled['sentiment']

# Split the train data to create validation dataset
sX_train, sX_test, sy_train, sy_test = train_test_split(sX, sy, test_size=0.20, random_state=42)

# %%
# Linear SVC
lsvc.fit(sX_train, sy_train)
slsvc_y_predict = lsvc.predict(sX_test)
print('Classification Report Linear logistics')
print(classification_report(sy_test, slsvc_y_predict))
# Out:
# Classification Report Linear logistics
#               precision    recall  f1-score   support
#
#           -1       0.88      0.97      0.92       961
#            0       0.82      0.85      0.84      1003
#            1       0.88      0.75      0.81      1631
#            2       0.83      0.91      0.86      1005
#
#     accuracy                           0.85      4600
#    macro avg       0.85      0.87      0.86      4600
# weighted avg       0.86      0.85      0.85      4600

# %% [markdown]
# # Hyperparameter tuning

# %%
# Import Grid search for hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# number of folds to be tested on
nfolds = 2

# the values of c to check for
Cs = [0.001, 0.01, 0.1, 1, 10]

# the values of gamma
gammas = [0.001, 0.01, 0.1, 1]

# Creating the parameters dictionary
param_grid = {
    'C'     : Cs,
    'gamma' : gammas
    }

# Applying the grid search and comparing based on the f1 score
grid_SVM = GridSearchCV(SVC(kernel='linear'), param_grid, scoring='f1', cv=nfolds)
grid_SVM.fit(V_train_Xf, yf)

# Getting the best parameters of grid search
grid_SVM.best_params_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-229-67c5e2917789> in <module>
#      19 # Applying the grid search and comparing based on the f1 score
#      20 grid_SVM = GridSearchCV(SVC(kernel='linear'), param_grid, scoring='f1', cv=nfolds)
# ---> 21 grid_SVM.fit(V_train_Xf, yf)
#      22
#      23 # Getting the best parameters of grid search
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     836                     )
#     837
# --> 838                 out = parallel(
#     839                     delayed(_fit_and_score)(
#     840                         clone(base_estimator),
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     209     def __call__(self, *args, **kwargs):
#     210         with config_context(**self.config):
# --> 211             return self.function(*args, **kwargs)
#     212
#     213
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     701
#     702         fit_time = time.time() - start_time
# --> 703         test_scores = _score(estimator, X_test, y_test, scorer, error_score)
#     704         score_time = time.time() - start_time - fit_time
#     705         if return_train_score:
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\model_selection\_validation.py in _score(estimator, X_test, y_test, scorer, error_score)
#     760             scores = scorer(estimator, X_test)
#     761         else:
# --> 762             scores = scorer(estimator, X_test, y_test)
#     763     except Exception:
#     764         if error_score == "raise":
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_scorer.py in __call__(self, estimator, X, y_true, sample_weight)
#     214             Score function applied to prediction of estimator on X.
#     215         """
# --> 216         return self._score(
#     217             partial(_cached_call, None),
#     218             estimator,
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_scorer.py in _score(self, method_caller, estimator, X, y_true, sample_weight)
#     256         """
#     257
# --> 258         y_pred = method_caller(estimator, "predict", X)
#     259         if sample_weight is not None:
#     260             return self._sign * self._score_func(
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_scorer.py in _cached_call(cache, estimator, method, *args, **kwargs)
#      66     """Call estimator with method and args and kwargs."""
#      67     if cache is None:
# ---> 68         return getattr(estimator, method)(*args, **kwargs)
#      69
#      70     try:
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\svm\_base.py in predict(self, X)
#     789             y = np.argmax(self.decision_function(X), axis=1)
#     790         else:
# --> 791             y = super().predict(X)
#     792         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     793
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\svm\_base.py in predict(self, X)
#     414         X = self._validate_for_predict(X)
#     415         predict = self._sparse_predict if self._sparse else self._dense_predict
# --> 416         return predict(X)
#     417
#     418     def _dense_predict(self, X):
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\svm\_base.py in _sparse_predict(self, X)
#     460         C = 0.0  # C is not useful here
#     461
# --> 462         return libsvm_sparse.libsvm_sparse_predict(
#     463             X.data,
#     464             X.indices,
#
# KeyboardInterrupt:

# %%
grid_SVM.best_params_
# Out:
# {'C': 0.001, 'gamma': 0.001}

# %%
#rbf = SVC(kernel='rbf', gamma=0.001, C=0.001).fit(V_train_X, y_train)
poly = SVC(kernel='poly', degree=0.001, C=0.100).fit(V_train_Xf, yf)

poly_pred = poly.predict(V_test_X)
#rbf_pred = rbf.predict(V_test_X)
print('Classification Report poly_pred ')
print(classification_report(y_test, poly_pred))
# Out:
# Classification Report poly_pred
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00      1203
#            0       0.00      0.00      0.00      1266
#            1       0.35      1.00      0.52      2008
#            2       0.00      0.00      0.00      1273
#
#     accuracy                           0.35      5750
#    macro avg       0.09      0.25      0.13      5750
# weighted avg       0.12      0.35      0.18      5750

# %% [markdown]
# # Selecting Best Features

# %%
# Import the feature selector module
from sklearn import feature_selection
from sklearn.feature_selection import f_classif

# Set up selector, choosing score function and number of features to retain
selector_kbest = feature_selection.SelectKBest(score_func=f_classif, k=20)


# Transform (i.e.: run selection on) the training data
X_train_kbest = selector_kbest.fit_transform(V_train_X, y_train)

# Fit model to the transformed data
SVM_k_best = SVC(kernel='linear', degree=0.001, C=0.001).fit(X_train_kbest, y_train)


# Before generating predictions, we'll need to transform the test data the same way we did the train data
X_test_kbest = selector_kbest.transform(V_test_X)


# Generate predictions from var thresh model
pred_lm_kbest = SVM_k_best.predict(X_test_kbest)


#rbf_pred = rbf.predict(V_test_X)
print('Classification Report poly_pred ')
print(classification_report(y_test, pred_lm_kbest))

# %%
X_train_kbest.shape
# Out:
# (17250, 20)

# %%
# Fit model to the transformed data
SVM_k_best = SVC(kernel='poly', degree=0.001, C=0.001).fit(X_train_kbest, y_train)

# %%
# Before generating predictions, we'll need to transform the test data the same way we did the train data
X_test_kbest = selector_kbest.transform(V_test_X)

# Generate predictions from var thresh model
pred_lm_kbest = SVM_k_best.predict(X_test_kbest)

# %%
#rbf_pred = rbf.predict(V_test_X)
print('Classification Report poly_pred ')
print(classification_report(y_test, pred_lm_kbest))
# Out:
# Classification Report poly_pred
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00      1203
#            0       0.00      0.00      0.00      1266
#            1       0.35      1.00      0.52      2008
#            2       0.00      0.00      0.00      1273
#
#     accuracy                           0.35      5750
#    macro avg       0.09      0.25      0.13      5750
# weighted avg       0.12      0.35      0.18      5750

# %% [markdown]
# # making a Submission

# %%
# Traing the model with the entire data
yf = up_sampled['sentiment']
Xf = up_sampled['message']

# %%
X_testf = clean_df_test['message']

# %%
# extracting features
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer2 = TfidfVectorizer(ngram_range = (1,3))
V_train_Xf = vectorizer2.fit_transform(Xf)
V_test_Xf = vectorizer2.transform(X_testf)

# Import the scaler module
from sklearn import preprocessing
scaler = preprocessing.MaxAbsScaler()

# Scale data
X_Train_f = scaler.fit_transform(V_train_Xf)
X_Test_f = scaler.transform(V_test_Xf)

# %%
V_test_Xf.shape
# Out:
# (10546, 260796)

# %%
# training a linear SVM classifier
from sklearn.svm import SVC
svm_model_linear_f = SVC(kernel = 'linear', C = 1, gamma = 0.5).fit(V_train_Xf,yf)
final_preds = svm_model_linear_f.predict(V_test_Xf)

# %%
# training a Linear Logistics 
from sklearn.linear_model import LogisticRegression
slm_vt_f_o = LogisticRegression(multi_class='ovr').fit(X_Train_f, yf)
spred_lr_vt_f = slm_vt_f_o.predict(X_Test_f)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

nb_classifier_f = MultinomialNB(alpha = 0.5)
nb_classifier_f.fit(X_Train_f, yf)

fpred = nb_classifier_f.predict(X_Test_f)

# %%
import pickle
with open('vectorizer_3.pkl', 'wb') as fin:
    pickle.dump(vectorizer2, fin)

# %%
import pickle

# save the model to disk
model_name = ['SVC_linear', "Linear_LogisticsC", 'MultiNB']
models = [svm_model_linear_f, slm_vt_f_o, nb_classifier_f]
for i in range(len(models)):
        filename = model_name[i] + '_final_3.pkl'
        pickle.dump(models[i], open(filename, 'wb'))

# %%
preds = [final_preds, spred_lr_vt_f, fpred]
preds[0]
# Out:
# array([1, 1, 1, ..., 0, 0, 1], dtype=int64)

# %%
def submissions(preds): 
    
    
    model = ['SVC_linear', 'LogisticsRegression', 'MultinomialNB']
    
    for i in range(len(model)):
        daf = pd.DataFrame(preds[i], columns=['sentiment'])
        output = pd.DataFrame({"tweetid":df_test['tweetid']})
        final = output.join(daf)
        final_name = model[i] +"_finalise59.csv"
        final.to_csv(final_name, index=False)
        

    return final

# %%
df = submissions(preds)

# %%
df.head()
# Out:
#    tweetid  sentiment
# 0   169760          1
# 1    35326          1
# 2   224985          1
# 3   476263          1
# 4   872928          2

# %%
stri = 'mplio getã¢â‚¬â¦s that9808'
p = re.sub(r'[^a-z0-9 ]', r'', stri)
p
# Out:
# 'mplio gets that9808'
